# %% [markdown]
# # CSRNet
#
# This notebook is divided into 2 sections:
#
# 1. **Training using the authors' code**
#
#   We will first reuse the authors' PyTorch implementation, to compare its performance with our own implementation and various experiments we did, utilizing different optimizers, loss functions, and learning rates.
#
# 2.   **Transfer Learning**
#
#   Here, we perform Transfer Learning using a pre-trained CSRNet model. The objective is to examine whether a powerful yet general model, suitable for varying crowd sparsity, can perform as well as a more specific but less tuned model.
#
#   The weights that we will use are already part of a PyPi package called [csrnet](https://pypi.org/project/csrnet/#description) (Note: this package works only as a regressor). They are available to download from the following repo: https://github.com/pschaus/csrnet_pip/blob/main/csrnet.
#
#
# 3.   **Regressor**
#
#   Finally, we attempt to use the CSRNet as a feature extractor, and by adding dense layers, we aim to train a network for performing regression directly.

# %% [markdown]
# ## Imports
#
# **Run this**, since it's general for all the experiments.

# %% [markdown]
# Import needed modules:

# %%
import os
import shutil
import requests
from glob import glob
from tqdm import tqdm
from matplotlib import pyplot as plt, cm as cm
import numpy as np
import scipy.io as io
from scipy.ndimage import gaussian_filter
from scipy.spatial import KDTree
import cv2
import h5py
from sklearn.model_selection import train_test_split
import json
from google.colab import drive
import PIL.Image as Image
import torchvision.transforms.functional as F
from torchvision import datasets, transforms
import torch
from torch.optim import Adam
from torch.utils.data import Dataset, DataLoader
import argparse
from torch.nn import functional as F
import torch.nn as nn
from sklearn.metrics import mean_absolute_error, mean_squared_error
import time

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Downloading data and GT generation
#
# **Important**: Run this only the first time!

# %% [markdown]
# Before we clone the repository, we need to download the Mall dataset, and generate the ground truth density maps.

# %% [markdown]
# ### Download Mall Dataset
#
# We will download the dataset from this url: https://personal.ie.cuhk.edu.hk/~ccloy/downloads_mall_dataset.html
#
# **Important**: Run this only the first time!

# %%
# Define the URL of the zip file
url = 'https://personal.ie.cuhk.edu.hk/~ccloy/files/datasets/mall_dataset.zip'

# Define the destination path in Google Drive
destination_path = '/content/drive/MyDrive/CrowdCounting/Data/'
# mall_dataset folder is contained in the zip

# Create the destination directory if it doesn't exist
os.makedirs(destination_path, exist_ok=True)

# Download the file
response = requests.get(url, stream=True)
zip_path = os.path.join(destination_path, 'mall_dataset.zip')

with open(zip_path, 'wb') as f:
    shutil.copyfileobj(response.raw, f)

# Extract the contents of the zip file
shutil.unpack_archive(zip_path, destination_path)

# Clean up: remove the downloaded zip file
os.remove(zip_path)

# %% [markdown]
# Let's delete Thumbs.db from the frames folder.

# %%
directory_path = "/content/drive/MyDrive/CrowdCounting/Data/mall_dataset/frames/"

# List all files in the directory
file_list = os.listdir(directory_path)

# Check if "Thumbs.db" exists in the list
if "Thumbs.db" in file_list:
    # Construct the full file path
    thumbs_db_path = os.path.join(directory_path, "Thumbs.db")

    # Delete the file
    os.remove(thumbs_db_path)
    print("Thumbs.db deleted successfully.")
else:
    print("Thumbs.db not found in the directory.")
# Out:
# Thumbs.db not found in the directory.

# %% [markdown]
# ### Generate Density Maps
#
# Here we generate the ground truth density maps and store them to Google Drive.
#
# **Important**: Run this only the first time!

# %%
# Borrowed from the original author's code:
# https://github.com/leeyeehoo/CSRNet-pytorch/blob/master/make_dataset.ipynb
def gaussian_filter_density(ground_truth):
    '''Generates a density map using Gaussian filter transformation.'''
    density = np.zeros(ground_truth.shape, dtype=np.float32) # Initialize an empty density map with the same shape as the GT
    ground_truth_count = np.count_nonzero(ground_truth) # count of people in the image

    if ground_truth_count == 0: # no people in the image
        return density

    # Find out the K nearest neighbours for each non-zero point using a KDTree
    index_of_nonzero_elements = np.nonzero(ground_truth)
    points = np.array(list(zip(index_of_nonzero_elements[1].ravel(), index_of_nonzero_elements[0].ravel())))
    leafsize = 2048

    # build KDTree
    tree = KDTree(points.copy(), leafsize=leafsize)
    # query KDTree
    distances, _ = tree.query(points, k=4) # 3+1

    for i, point in enumerate(points): # for every person in the image
        point_2d = np.zeros(ground_truth.shape, dtype=np.float32)
        point_2d[point[1], point[0]] = 1.
        if ground_truth_count > 1:
            # sigma = beta * d_bar = 0.3 * (d1 + d2 + d3) / 3 = 0.1 * (d1 + d2 + d3)
            sigma = (distances[i][1] + distances[i][2] + distances[i][3]) * 0.1
        else:
            sigma = np.average(np.array(ground_truth.shape))/2./2. # case: 1 point (person)

        # Convolve with the gaussian filter
        density += gaussian_filter(point_2d, sigma, mode='constant')
    return density


def create_density_maps_mall(imgs_paths, head_positions_gt, save_path):

    for i, img_path in tqdm(enumerate(img_paths), total=len(img_paths)):
        img = plt.imread(img_path)

        ground_truth = head_positions_gt[i][0][0][0]
        # ground truth has rows = #num people.
        # each row is (x,y) representing the central pixel of a head in the image.

        # The following is done as per the original authors' code:
        # https://github.com/leeyeehoo/CSRNet-pytorch/blob/master/make_dataset.ipynb


        # Create a zero matrix of image size
        k = np.zeros((img.shape[0],img.shape[1]))

        # Generate hot encoded matrix of sparse matrix
        for j in range(len(ground_truth)):
            if int(ground_truth[j][1]) < img.shape[0] and int(ground_truth[j][0]) < img.shape[1]:
                k[int(ground_truth[j][1]), int(ground_truth[j][0])] = 1

        # Generate density map
        k = gaussian_filter_density(k)

        with h5py.File(img_path.replace('.jpg','.h5').replace('images','density_maps'), 'w') as hf:
            hf['density'] = k

# %%
mall_dataset_folder = '/content/drive/MyDrive/CrowdCounting/Data/mall_dataset/'
mall_imgs_folder = mall_dataset_folder + 'frames/'
img_paths = []
for img_path in glob(os.path.join(mall_imgs_folder, '*.jpg')):
  img_paths.append(img_path)
print(f'Number of images: {len(img_paths)}.\n')
# Out:
# Number of images: 2000.

# %%
mall_gt = io.loadmat(os.path.join(mall_dataset_folder, 'mall_gt.mat'))
mall_head_positions_gt = mall_gt['frame'][0]

# %%
save_path = '/content/drive/MyDrive/CrowdCounting/Data/mall_dataset/density_maps/'

# Create directory if it doesn't exist
if not os.path.exists(os.path.dirname(save_path)):
    os.makedirs(os.path.dirname(save_path))

create_density_maps_mall(img_paths, mall_head_positions_gt, save_path)
# Out:
# 100%|██████████| 2000/2000 [1:03:06<00:00,  1.89s/it]

# %%
import os
import shutil

# Paths to the directories
source_path = '/content/drive/MyDrive/CrowdCounting/Data/mall_dataset/frames/'
destination_path = '/content/drive/MyDrive/CrowdCounting/Data/mall_dataset/density_maps/'

# Create the destination directory if it doesn't exist
os.makedirs(destination_path, exist_ok=True)

# Loop through all files in the source directory
for file_name in os.listdir(source_path):
    if file_name.endswith('.h5'):  # Only select .h5 files
        source_file = os.path.join(source_path, file_name)
        destination_file = os.path.join(destination_path, file_name)

        # Move the file
        shutil.move(source_file, destination_file)
        print(f"Moved: {file_name}")

print("Completed moving all .h5 files!")
# Out:
# Moved: seq_001001.h5
# Moved: seq_001002.h5
# Moved: seq_001003.h5
# Moved: seq_001004.h5
# Moved: seq_001005.h5
# Moved: seq_001006.h5
# Moved: seq_001007.h5
# Moved: seq_001008.h5
# Moved: seq_001009.h5
# Moved: seq_001010.h5
# Moved: seq_001011.h5
# Moved: seq_001012.h5
# Moved: seq_001013.h5
# Moved: seq_001014.h5
# Moved: seq_001015.h5
# Moved: seq_001016.h5
# Moved: seq_001017.h5
# Moved: seq_001018.h5
# Moved: seq_001019.h5
# Moved: seq_001020.h5
# Moved: seq_001021.h5
# Moved: seq_001022.h5
# Moved: seq_001023.h5
# Moved: seq_001024.h5
# Moved: seq_001025.h5
# Moved: seq_001026.h5
# Moved: seq_001027.h5
# Moved: seq_001028.h5
# Moved: seq_001029.h5
# Moved: seq_001030.h5
# Moved: seq_001031.h5
# Moved: seq_001032.h5
# Moved: seq_001033.h5
# Moved: seq_001034.h5
# Moved: seq_001035.h5
# Moved: seq_001036.h5
# Moved: seq_001037.h5
# Moved: seq_001038.h5
# Moved: seq_001039.h5
# Moved: seq_001040.h5
# Moved: seq_001041.h5
# Moved: seq_001042.h5
# Moved: seq_001043.h5
# Moved: seq_001044.h5
# Moved: seq_001045.h5
# Moved: seq_001046.h5
# Moved: seq_001047.h5
# Moved: seq_001048.h5
# Moved: seq_001049.h5
# Moved: seq_001050.h5
# Moved: seq_001051.h5
# Moved: seq_001052.h5
# Moved: seq_001053.h5
# Moved: seq_001054.h5
# Moved: seq_001055.h5
# Moved: seq_001056.h5
# Moved: seq_001057.h5
# Moved: seq_001058.h5
# Moved: seq_001059.h5
# Moved: seq_001060.h5
# Moved: seq_001061.h5
# Moved: seq_001062.h5
# Moved: seq_001063.h5
# Moved: seq_001064.h5
# Moved: seq_001065.h5
# Moved: seq_001066.h5
# Moved: seq_001067.h5
# Moved: seq_001068.h5
# Moved: seq_001069.h5
# Moved: seq_001070.h5
# Moved: seq_001071.h5
# Moved: seq_001072.h5
# Moved: seq_001073.h5
# Moved: seq_001074.h5
# Moved: seq_001075.h5
# Moved: seq_001076.h5
# Moved: seq_001077.h5
# Moved: seq_001078.h5
# Moved: seq_001079.h5
# Moved: seq_001080.h5
# Moved: seq_001081.h5
# Moved: seq_001082.h5
# Moved: seq_001083.h5
# Moved: seq_001084.h5
# Moved: seq_001085.h5
# Moved: seq_001086.h5
# Moved: seq_001087.h5
# Moved: seq_001088.h5
# Moved: seq_001089.h5
# Moved: seq_001090.h5
# Moved: seq_001091.h5
# Moved: seq_001092.h5
# Moved: seq_001093.h5
# Moved: seq_001094.h5
# Moved: seq_001095.h5
# Moved: seq_001096.h5
# Moved: seq_001097.h5
# Moved: seq_001098.h5
# Moved: seq_001099.h5
# Moved: seq_001100.h5
# Moved: seq_001101.h5
# Moved: seq_001102.h5
# Moved: seq_001103.h5
# Moved: seq_001104.h5
# Moved: seq_001105.h5
# Moved: seq_001106.h5
# Moved: seq_001107.h5
# Moved: seq_001108.h5
# Moved: seq_001109.h5
# Moved: seq_001110.h5
# Moved: seq_001111.h5
# Moved: seq_001112.h5
# Moved: seq_001113.h5
# Moved: seq_001114.h5
# Moved: seq_001115.h5
# Moved: seq_001116.h5
# Moved: seq_001117.h5
# Moved: seq_001118.h5
# Moved: seq_001119.h5
# Moved: seq_001120.h5
# Moved: seq_001121.h5
# Moved: seq_001122.h5
# Moved: seq_001123.h5
# Moved: seq_001124.h5
# Moved: seq_001125.h5
# Moved: seq_001126.h5
# Moved: seq_001127.h5
# Moved: seq_001128.h5
# Moved: seq_001129.h5
# Moved: seq_001130.h5
# Moved: seq_001131.h5
# Moved: seq_001132.h5
# Moved: seq_001133.h5
# Moved: seq_001134.h5
# Moved: seq_001135.h5
# Moved: seq_001136.h5
# Moved: seq_001137.h5
# Moved: seq_001138.h5
# Moved: seq_001139.h5
# Moved: seq_001140.h5
# Moved: seq_001141.h5
# Moved: seq_001142.h5
# Moved: seq_001143.h5
# Moved: seq_001144.h5
# Moved: seq_001145.h5
# Moved: seq_001146.h5
# Moved: seq_001147.h5
# Moved: seq_001148.h5
# Moved: seq_001149.h5
# Moved: seq_001150.h5
# Moved: seq_001151.h5
# Moved: seq_001152.h5
# Moved: seq_001153.h5
# Moved: seq_001154.h5
# Moved: seq_001155.h5
# Moved: seq_001156.h5
# Moved: seq_001157.h5
# Moved: seq_001158.h5
# Moved: seq_001159.h5
# Moved: seq_001160.h5
# Moved: seq_001161.h5
# Moved: seq_001162.h5
# Moved: seq_001163.h5
# Moved: seq_001164.h5
# Moved: seq_001165.h5
# Moved: seq_001166.h5
# Moved: seq_001167.h5
# Moved: seq_001168.h5
# Moved: seq_001169.h5
# Moved: seq_001170.h5
# Moved: seq_001171.h5
# Moved: seq_001172.h5
# Moved: seq_001173.h5
# Moved: seq_001174.h5
# Moved: seq_001175.h5
# Moved: seq_001176.h5
# Moved: seq_001177.h5
# Moved: seq_001178.h5
# Moved: seq_001179.h5
# Moved: seq_001180.h5
# Moved: seq_001181.h5
# Moved: seq_001182.h5
# Moved: seq_001183.h5
# Moved: seq_001184.h5
# Moved: seq_001185.h5
# Moved: seq_001186.h5
# Moved: seq_001187.h5
# Moved: seq_001188.h5
# Moved: seq_001189.h5
# Moved: seq_001190.h5
# Moved: seq_001191.h5
# Moved: seq_001192.h5
# Moved: seq_001193.h5
# Moved: seq_001194.h5
# Moved: seq_001195.h5
# Moved: seq_001196.h5
# Moved: seq_001197.h5
# Moved: seq_001198.h5
# Moved: seq_001199.h5
# Moved: seq_001200.h5
# Moved: seq_001201.h5
# Moved: seq_001202.h5
# Moved: seq_001203.h5
# Moved: seq_001204.h5
# Moved: seq_001205.h5
# Moved: seq_001206.h5
# Moved: seq_001207.h5
# Moved: seq_001208.h5
# Moved: seq_001209.h5
# Moved: seq_001210.h5
# Moved: seq_001211.h5
# Moved: seq_001212.h5
# Moved: seq_001213.h5
# Moved: seq_001214.h5
# Moved: seq_001215.h5
# Moved: seq_001216.h5
# Moved: seq_001217.h5
# Moved: seq_001218.h5
# Moved: seq_001219.h5
# Moved: seq_001220.h5
# Moved: seq_001221.h5
# Moved: seq_001222.h5
# Moved: seq_001223.h5
# Moved: seq_001224.h5
# Moved: seq_001225.h5
# Moved: seq_001226.h5
# Moved: seq_001227.h5
# Moved: seq_001228.h5
# Moved: seq_001229.h5
# Moved: seq_001230.h5
# Moved: seq_001231.h5
# Moved: seq_001232.h5
# Moved: seq_001233.h5
# Moved: seq_001234.h5
# Moved: seq_001235.h5
# Moved: seq_001236.h5
# Moved: seq_001237.h5
# Moved: seq_001238.h5
# Moved: seq_001239.h5
# Moved: seq_001240.h5
# Moved: seq_001241.h5
# Moved: seq_001242.h5
# Moved: seq_001243.h5
# Moved: seq_001244.h5
# Moved: seq_001245.h5
# Moved: seq_001246.h5
# Moved: seq_001247.h5
# Moved: seq_001248.h5
# Moved: seq_001249.h5
# Moved: seq_001250.h5
# Moved: seq_001251.h5
# Moved: seq_001252.h5
# Moved: seq_001253.h5
# Moved: seq_001254.h5
# Moved: seq_001255.h5
# Moved: seq_001256.h5
# Moved: seq_001257.h5
# Moved: seq_001258.h5
# Moved: seq_001259.h5
# Moved: seq_001260.h5
# Moved: seq_001261.h5
# Moved: seq_001262.h5
# Moved: seq_001263.h5
# Moved: seq_001264.h5
# Moved: seq_001265.h5
# Moved: seq_001266.h5
# Moved: seq_001267.h5
# Moved: seq_001268.h5
# Moved: seq_001269.h5
# Moved: seq_001270.h5
# Moved: seq_001271.h5
# Moved: seq_001272.h5
# Moved: seq_001273.h5
# Moved: seq_001274.h5
# Moved: seq_001275.h5
# Moved: seq_001276.h5
# Moved: seq_001277.h5
# Moved: seq_001278.h5
# Moved: seq_001279.h5
# Moved: seq_001280.h5
# Moved: seq_001281.h5
# Moved: seq_001282.h5
# Moved: seq_001283.h5
# Moved: seq_001284.h5
# Moved: seq_001285.h5
# Moved: seq_001286.h5
# Moved: seq_001287.h5
# Moved: seq_001288.h5
# Moved: seq_001289.h5
# Moved: seq_001290.h5
# Moved: seq_001291.h5
# Moved: seq_001292.h5
# Moved: seq_001293.h5
# Moved: seq_001294.h5
# Moved: seq_001295.h5
# Moved: seq_001296.h5
# Moved: seq_001297.h5
# Moved: seq_001298.h5
# Moved: seq_001299.h5
# Moved: seq_001300.h5
# Moved: seq_001301.h5
# Moved: seq_001302.h5
# Moved: seq_001303.h5
# Moved: seq_001304.h5
# Moved: seq_001305.h5
# Moved: seq_001306.h5
# Moved: seq_001307.h5
# Moved: seq_001308.h5
# Moved: seq_001309.h5
# Moved: seq_001310.h5
# Moved: seq_001311.h5
# Moved: seq_001312.h5
# Moved: seq_001313.h5
# Moved: seq_001314.h5
# Moved: seq_001315.h5
# Moved: seq_001316.h5
# Moved: seq_001317.h5
# Moved: seq_001318.h5
# Moved: seq_001319.h5
# Moved: seq_001320.h5
# Moved: seq_001321.h5
# Moved: seq_001322.h5
# Moved: seq_001323.h5
# Moved: seq_001324.h5
# Moved: seq_001325.h5
# Moved: seq_001326.h5
# Moved: seq_001327.h5
# Moved: seq_001328.h5
# Moved: seq_001329.h5
# Moved: seq_001330.h5
# Moved: seq_001331.h5
# Moved: seq_001332.h5
# Moved: seq_001333.h5
# Moved: seq_001334.h5
# Moved: seq_001335.h5
# Moved: seq_001336.h5
# Moved: seq_001337.h5
# Moved: seq_001338.h5
# Moved: seq_001339.h5
# Moved: seq_001340.h5
# Moved: seq_001341.h5
# Moved: seq_001342.h5
# Moved: seq_001343.h5
# Moved: seq_001344.h5
# Moved: seq_001345.h5
# Moved: seq_001346.h5
# Moved: seq_001347.h5
# Moved: seq_001348.h5
# Moved: seq_001349.h5
# Moved: seq_001350.h5
# Moved: seq_001351.h5
# Moved: seq_001352.h5
# Moved: seq_001353.h5
# Moved: seq_001354.h5
# Moved: seq_001355.h5
# Moved: seq_001356.h5
# Moved: seq_001357.h5
# Moved: seq_001358.h5
# Moved: seq_001359.h5
# Moved: seq_001360.h5
# Moved: seq_001361.h5
# Moved: seq_001362.h5
# Moved: seq_001363.h5
# Moved: seq_001364.h5
# Moved: seq_001365.h5
# Moved: seq_001366.h5
# Moved: seq_001367.h5
# Moved: seq_001368.h5
# Moved: seq_001369.h5
# Moved: seq_001370.h5
# Moved: seq_001371.h5
# Moved: seq_001372.h5
# Moved: seq_001373.h5
# Moved: seq_001374.h5
# Moved: seq_001375.h5
# Moved: seq_001376.h5
# Moved: seq_001377.h5
# Moved: seq_001378.h5
# Moved: seq_001379.h5
# Moved: seq_001380.h5
# Moved: seq_001381.h5
# Moved: seq_001382.h5
# Moved: seq_001383.h5
# Moved: seq_001384.h5
# Moved: seq_001385.h5
# Moved: seq_001386.h5
# Moved: seq_001387.h5
# Moved: seq_001388.h5
# Moved: seq_001389.h5
# Moved: seq_001390.h5
# Moved: seq_001391.h5
# Moved: seq_001392.h5
# Moved: seq_001393.h5
# Moved: seq_001394.h5
# Moved: seq_001395.h5
# Moved: seq_001396.h5
# Moved: seq_001397.h5
# Moved: seq_001398.h5
# Moved: seq_001399.h5
# Moved: seq_001400.h5
# Moved: seq_001401.h5
# Moved: seq_001402.h5
# Moved: seq_001403.h5
# Moved: seq_001404.h5
# Moved: seq_001405.h5
# Moved: seq_001406.h5
# Moved: seq_001407.h5
# Moved: seq_001408.h5
# Moved: seq_001409.h5
# Moved: seq_001410.h5
# Moved: seq_001411.h5
# Moved: seq_001412.h5
# Moved: seq_001413.h5
# Moved: seq_001414.h5
# Moved: seq_001415.h5
# Moved: seq_001416.h5
# Moved: seq_001417.h5
# Moved: seq_001418.h5
# Moved: seq_001419.h5
# Moved: seq_001420.h5
# Moved: seq_001421.h5
# Moved: seq_001422.h5
# Moved: seq_001423.h5
# Moved: seq_001424.h5
# Moved: seq_001425.h5
# Moved: seq_001426.h5
# Moved: seq_001427.h5
# Moved: seq_001428.h5
# Moved: seq_001429.h5
# Moved: seq_001430.h5
# Moved: seq_001431.h5
# Moved: seq_001432.h5
# Moved: seq_001433.h5
# Moved: seq_001434.h5
# Moved: seq_001435.h5
# Moved: seq_001436.h5
# Moved: seq_001437.h5
# Moved: seq_001438.h5
# Moved: seq_001439.h5
# Moved: seq_001440.h5
# Moved: seq_001441.h5
# Moved: seq_001442.h5
# Moved: seq_001443.h5
# Moved: seq_001444.h5
# Moved: seq_001445.h5
# Moved: seq_001446.h5
# Moved: seq_001447.h5
# Moved: seq_001448.h5
# Moved: seq_001449.h5
# Moved: seq_001450.h5
# Moved: seq_001451.h5
# Moved: seq_001452.h5
# Moved: seq_001453.h5
# Moved: seq_001454.h5
# Moved: seq_001455.h5
# Moved: seq_001456.h5
# Moved: seq_001457.h5
# Moved: seq_001458.h5
# Moved: seq_001459.h5
# Moved: seq_001460.h5
# Moved: seq_001461.h5
# Moved: seq_001462.h5
# Moved: seq_001463.h5
# Moved: seq_001464.h5
# Moved: seq_001465.h5
# Moved: seq_001466.h5
# Moved: seq_001467.h5
# Moved: seq_001468.h5
# Moved: seq_001469.h5
# Moved: seq_001470.h5
# Moved: seq_001471.h5
# Moved: seq_001472.h5
# Moved: seq_001473.h5
# Moved: seq_001474.h5
# Moved: seq_001475.h5
# Moved: seq_001476.h5
# Moved: seq_001477.h5
# Moved: seq_001478.h5
# Moved: seq_001479.h5
# Moved: seq_001480.h5
# Moved: seq_001481.h5
# Moved: seq_001482.h5
# Moved: seq_001483.h5
# Moved: seq_001484.h5
# Moved: seq_001485.h5
# Moved: seq_001486.h5
# Moved: seq_001487.h5
# Moved: seq_001488.h5
# Moved: seq_001489.h5
# Moved: seq_001490.h5
# Moved: seq_001491.h5
# Moved: seq_001492.h5
# Moved: seq_001493.h5
# Moved: seq_001494.h5
# Moved: seq_001495.h5
# Moved: seq_001496.h5
# Moved: seq_001497.h5
# Moved: seq_001498.h5
# Moved: seq_001499.h5
# Moved: seq_001500.h5
# Moved: seq_001501.h5
# Moved: seq_001502.h5
# Moved: seq_001503.h5
# Moved: seq_001504.h5
# Moved: seq_001505.h5
# Moved: seq_001506.h5
# Moved: seq_001507.h5
# Moved: seq_001508.h5
# Moved: seq_001509.h5
# Moved: seq_001510.h5
# Moved: seq_001511.h5
# Moved: seq_001512.h5
# Moved: seq_001513.h5
# Moved: seq_001514.h5
# Moved: seq_001515.h5
# Moved: seq_001516.h5
# Moved: seq_001517.h5
# Moved: seq_001518.h5
# Moved: seq_001519.h5
# Moved: seq_001520.h5
# Moved: seq_001521.h5
# Moved: seq_001522.h5
# Moved: seq_001523.h5
# Moved: seq_001524.h5
# Moved: seq_001525.h5
# Moved: seq_001526.h5
# Moved: seq_001527.h5
# Moved: seq_001528.h5
# Moved: seq_001529.h5
# Moved: seq_001530.h5
# Moved: seq_001531.h5
# Moved: seq_001532.h5
# Moved: seq_001533.h5
# Moved: seq_001534.h5
# Moved: seq_001535.h5
# Moved: seq_001536.h5
# Moved: seq_001537.h5
# Moved: seq_001538.h5
# Moved: seq_001539.h5
# Moved: seq_001540.h5
# Moved: seq_001541.h5
# Moved: seq_001542.h5
# Moved: seq_001543.h5
# Moved: seq_001544.h5
# Moved: seq_001545.h5
# Moved: seq_001546.h5
# Moved: seq_001547.h5
# Moved: seq_001548.h5
# Moved: seq_001549.h5
# Moved: seq_001550.h5
# Moved: seq_001551.h5
# Moved: seq_001552.h5
# Moved: seq_001553.h5
# Moved: seq_001554.h5
# Moved: seq_001555.h5
# Moved: seq_001556.h5
# Moved: seq_001557.h5
# Moved: seq_001558.h5
# Moved: seq_001559.h5
# Moved: seq_001560.h5
# Moved: seq_001561.h5
# Moved: seq_001562.h5
# Moved: seq_001563.h5
# Moved: seq_001564.h5
# Moved: seq_001565.h5
# Moved: seq_001566.h5
# Moved: seq_001567.h5
# Moved: seq_001568.h5
# Moved: seq_001569.h5
# Moved: seq_001570.h5
# Moved: seq_001571.h5
# Moved: seq_001572.h5
# Moved: seq_001573.h5
# Moved: seq_001574.h5
# Moved: seq_001575.h5
# Moved: seq_001576.h5
# Moved: seq_001577.h5
# Moved: seq_001578.h5
# Moved: seq_001579.h5
# Moved: seq_001580.h5
# Moved: seq_001581.h5
# Moved: seq_001582.h5
# Moved: seq_001583.h5
# Moved: seq_001584.h5
# Moved: seq_001585.h5
# Moved: seq_001586.h5
# Moved: seq_001587.h5
# Moved: seq_001588.h5
# Moved: seq_001589.h5
# Moved: seq_001590.h5
# Moved: seq_001591.h5
# Moved: seq_001592.h5
# Moved: seq_001593.h5
# Moved: seq_001594.h5
# Moved: seq_001595.h5
# Moved: seq_001596.h5
# Moved: seq_001597.h5
# Moved: seq_001598.h5
# Moved: seq_001599.h5
# Moved: seq_001600.h5
# Moved: seq_001601.h5
# Moved: seq_001602.h5
# Moved: seq_001603.h5
# Moved: seq_001604.h5
# Moved: seq_001605.h5
# Moved: seq_001606.h5
# Moved: seq_001607.h5
# Moved: seq_001608.h5
# Moved: seq_001609.h5
# Moved: seq_001610.h5
# Moved: seq_001611.h5
# Moved: seq_001612.h5
# Moved: seq_001613.h5
# Moved: seq_001614.h5
# Moved: seq_001615.h5
# Moved: seq_001616.h5
# Moved: seq_001617.h5
# Moved: seq_001618.h5
# Moved: seq_001619.h5
# Moved: seq_001620.h5
# Moved: seq_001621.h5
# Moved: seq_001622.h5
# Moved: seq_001623.h5
# Moved: seq_001624.h5
# Moved: seq_001625.h5
# Moved: seq_001626.h5
# Moved: seq_001627.h5
# Moved: seq_001628.h5
# Moved: seq_001629.h5
# Moved: seq_001630.h5
# Moved: seq_001631.h5
# Moved: seq_001632.h5
# Moved: seq_001633.h5
# Moved: seq_001634.h5
# Moved: seq_001635.h5
# Moved: seq_001636.h5
# Moved: seq_001637.h5
# Moved: seq_001638.h5
# Moved: seq_001639.h5
# Moved: seq_001640.h5
# Moved: seq_001641.h5
# Moved: seq_001642.h5
# Moved: seq_001643.h5
# Moved: seq_001644.h5
# Moved: seq_001645.h5
# Moved: seq_001646.h5
# Moved: seq_001647.h5
# Moved: seq_001648.h5
# Moved: seq_001649.h5
# Moved: seq_001650.h5
# Moved: seq_001651.h5
# Moved: seq_001652.h5
# Moved: seq_001653.h5
# Moved: seq_001654.h5
# Moved: seq_001655.h5
# Moved: seq_001656.h5
# Moved: seq_001657.h5
# Moved: seq_001658.h5
# Moved: seq_001659.h5
# Moved: seq_001660.h5
# Moved: seq_001661.h5
# Moved: seq_001662.h5
# Moved: seq_001663.h5
# Moved: seq_001664.h5
# Moved: seq_001665.h5
# Moved: seq_001666.h5
# Moved: seq_001667.h5
# Moved: seq_001668.h5
# Moved: seq_001669.h5
# Moved: seq_001670.h5
# Moved: seq_001671.h5
# Moved: seq_001672.h5
# Moved: seq_001673.h5
# Moved: seq_001674.h5
# Moved: seq_001675.h5
# Moved: seq_001676.h5
# Moved: seq_001677.h5
# Moved: seq_001678.h5
# Moved: seq_001679.h5
# Moved: seq_001680.h5
# Moved: seq_001681.h5
# Moved: seq_001682.h5
# Moved: seq_001683.h5
# Moved: seq_001684.h5
# Moved: seq_001685.h5
# Moved: seq_001686.h5
# Moved: seq_001687.h5
# Moved: seq_001688.h5
# Moved: seq_001689.h5
# Moved: seq_001690.h5
# Moved: seq_001691.h5
# Moved: seq_001692.h5
# Moved: seq_001693.h5
# Moved: seq_001694.h5
# Moved: seq_001695.h5
# Moved: seq_001696.h5
# Moved: seq_001697.h5
# Moved: seq_001698.h5
# Moved: seq_001699.h5
# Moved: seq_001700.h5
# Moved: seq_001701.h5
# Moved: seq_001702.h5
# Moved: seq_001703.h5
# Moved: seq_001704.h5
# Moved: seq_001705.h5
# Moved: seq_001706.h5
# Moved: seq_001707.h5
# Moved: seq_001708.h5
# Moved: seq_001709.h5
# Moved: seq_001710.h5
# Moved: seq_001711.h5
# Moved: seq_001712.h5
# Moved: seq_001713.h5
# Moved: seq_001714.h5
# Moved: seq_001715.h5
# Moved: seq_001716.h5
# Moved: seq_001717.h5
# Moved: seq_001718.h5
# Moved: seq_001719.h5
# Moved: seq_001720.h5
# Moved: seq_001721.h5
# Moved: seq_001722.h5
# Moved: seq_001723.h5
# Moved: seq_001724.h5
# Moved: seq_001725.h5
# Moved: seq_001726.h5
# Moved: seq_001727.h5
# Moved: seq_001728.h5
# Moved: seq_001729.h5
# Moved: seq_001730.h5
# Moved: seq_001731.h5
# Moved: seq_001732.h5
# Moved: seq_001733.h5
# Moved: seq_001734.h5
# Moved: seq_001735.h5
# Moved: seq_001736.h5
# Moved: seq_001737.h5
# Moved: seq_001738.h5
# Moved: seq_001739.h5
# Moved: seq_001740.h5
# Moved: seq_001741.h5
# Moved: seq_001742.h5
# Moved: seq_001743.h5
# Moved: seq_001744.h5
# Moved: seq_001745.h5
# Moved: seq_001746.h5
# Moved: seq_001747.h5
# Moved: seq_001748.h5
# Moved: seq_001749.h5
# Moved: seq_001750.h5
# Moved: seq_001751.h5
# Moved: seq_001752.h5
# Moved: seq_001753.h5
# Moved: seq_001754.h5
# Moved: seq_001755.h5
# Moved: seq_001756.h5
# Moved: seq_001757.h5
# Moved: seq_001758.h5
# Moved: seq_001759.h5
# Moved: seq_001760.h5
# Moved: seq_001761.h5
# Moved: seq_001762.h5
# Moved: seq_001763.h5
# Moved: seq_001764.h5
# Moved: seq_001765.h5
# Moved: seq_001766.h5
# Moved: seq_001767.h5
# Moved: seq_001768.h5
# Moved: seq_001769.h5
# Moved: seq_001770.h5
# Moved: seq_001771.h5
# Moved: seq_001772.h5
# Moved: seq_001773.h5
# Moved: seq_001774.h5
# Moved: seq_001775.h5
# Moved: seq_001776.h5
# Moved: seq_001777.h5
# Moved: seq_001778.h5
# Moved: seq_001779.h5
# Moved: seq_001780.h5
# Moved: seq_001781.h5
# Moved: seq_001782.h5
# Moved: seq_001783.h5
# Moved: seq_001784.h5
# Moved: seq_001785.h5
# Moved: seq_001786.h5
# Moved: seq_001787.h5
# Moved: seq_001788.h5
# Moved: seq_001789.h5
# Moved: seq_001790.h5
# Moved: seq_001791.h5
# Moved: seq_001792.h5
# Moved: seq_001793.h5
# Moved: seq_001794.h5
# Moved: seq_001795.h5
# Moved: seq_001796.h5
# Moved: seq_001797.h5
# Moved: seq_001798.h5
# Moved: seq_001799.h5
# Moved: seq_001800.h5
# Moved: seq_001801.h5
# Moved: seq_001802.h5
# Moved: seq_001803.h5
# Moved: seq_001804.h5
# Moved: seq_001805.h5
# Moved: seq_001806.h5
# Moved: seq_001807.h5
# Moved: seq_001808.h5
# Moved: seq_001809.h5
# Moved: seq_001810.h5
# Moved: seq_001811.h5
# Moved: seq_001812.h5
# Moved: seq_001813.h5
# Moved: seq_001814.h5
# Moved: seq_001815.h5
# Moved: seq_001816.h5
# Moved: seq_001817.h5
# Moved: seq_001818.h5
# Moved: seq_001819.h5
# Moved: seq_001820.h5
# Moved: seq_001821.h5
# Moved: seq_001822.h5
# Moved: seq_001823.h5
# Moved: seq_001824.h5
# Moved: seq_001825.h5
# Moved: seq_001826.h5
# Moved: seq_001827.h5
# Moved: seq_001828.h5
# Moved: seq_001829.h5
# Moved: seq_001830.h5
# Moved: seq_001831.h5
# Moved: seq_001832.h5
# Moved: seq_001833.h5
# Moved: seq_001834.h5
# Moved: seq_001835.h5
# Moved: seq_001836.h5
# Moved: seq_001837.h5
# Moved: seq_001838.h5
# Moved: seq_001839.h5
# Moved: seq_001840.h5
# Moved: seq_001841.h5
# Moved: seq_001842.h5
# Moved: seq_001843.h5
# Moved: seq_001844.h5
# Moved: seq_001845.h5
# Moved: seq_001846.h5
# Moved: seq_001847.h5
# Moved: seq_001848.h5
# Moved: seq_001849.h5
# Moved: seq_001850.h5
# Moved: seq_001851.h5
# Moved: seq_001852.h5
# Moved: seq_001853.h5
# Moved: seq_001854.h5
# Moved: seq_001855.h5
# Moved: seq_001856.h5
# Moved: seq_001857.h5
# Moved: seq_001858.h5
# Moved: seq_001859.h5
# Moved: seq_001860.h5
# Moved: seq_001861.h5
# Moved: seq_001862.h5
# Moved: seq_001863.h5
# Moved: seq_001864.h5
# Moved: seq_001865.h5
# Moved: seq_001866.h5
# Moved: seq_001867.h5
# Moved: seq_001868.h5
# Moved: seq_001869.h5
# Moved: seq_001870.h5
# Moved: seq_001871.h5
# Moved: seq_001872.h5
# Moved: seq_001873.h5
# Moved: seq_001874.h5
# Moved: seq_001875.h5
# Moved: seq_001876.h5
# Moved: seq_001877.h5
# Moved: seq_001878.h5
# Moved: seq_001879.h5
# Moved: seq_001880.h5
# Moved: seq_001881.h5
# Moved: seq_001882.h5
# Moved: seq_001883.h5
# Moved: seq_001884.h5
# Moved: seq_001885.h5
# Moved: seq_001886.h5
# Moved: seq_001887.h5
# Moved: seq_001888.h5
# Moved: seq_001889.h5
# Moved: seq_001890.h5
# Moved: seq_001891.h5
# Moved: seq_001892.h5
# Moved: seq_001893.h5
# Moved: seq_001894.h5
# Moved: seq_001895.h5
# Moved: seq_001896.h5
# Moved: seq_001897.h5
# Moved: seq_001898.h5
# Moved: seq_001899.h5
# Moved: seq_001900.h5
# Moved: seq_001901.h5
# Moved: seq_001902.h5
# Moved: seq_001903.h5
# Moved: seq_001904.h5
# Moved: seq_001905.h5
# Moved: seq_001906.h5
# Moved: seq_001907.h5
# Moved: seq_001908.h5
# Moved: seq_001909.h5
# Moved: seq_001910.h5
# Moved: seq_001911.h5
# Moved: seq_001912.h5
# Moved: seq_001913.h5
# Moved: seq_001914.h5
# Moved: seq_001915.h5
# Moved: seq_001916.h5
# Moved: seq_001917.h5
# Moved: seq_001918.h5
# Moved: seq_001919.h5
# Moved: seq_001920.h5
# Moved: seq_001921.h5
# Moved: seq_001922.h5
# Moved: seq_001923.h5
# Moved: seq_001924.h5
# Moved: seq_001925.h5
# Moved: seq_001926.h5
# Moved: seq_001927.h5
# Moved: seq_001928.h5
# Moved: seq_001929.h5
# Moved: seq_001930.h5
# Moved: seq_001931.h5
# Moved: seq_001932.h5
# Moved: seq_001933.h5
# Moved: seq_001934.h5
# Moved: seq_001935.h5
# Moved: seq_001936.h5
# Moved: seq_001937.h5
# Moved: seq_001938.h5
# Moved: seq_001939.h5
# Moved: seq_001940.h5
# Moved: seq_001941.h5
# Moved: seq_001942.h5
# Moved: seq_001943.h5
# Moved: seq_001944.h5
# Moved: seq_001945.h5
# Moved: seq_001946.h5
# Moved: seq_001947.h5
# Moved: seq_001948.h5
# Moved: seq_001949.h5
# Moved: seq_001950.h5
# Moved: seq_001951.h5
# Moved: seq_001952.h5
# Moved: seq_001953.h5
# Moved: seq_001954.h5
# Moved: seq_001955.h5
# Moved: seq_001956.h5
# Moved: seq_001957.h5
# Moved: seq_001958.h5
# Moved: seq_001959.h5
# Moved: seq_001960.h5
# Moved: seq_001961.h5
# Moved: seq_001962.h5
# Moved: seq_001963.h5
# Moved: seq_001964.h5
# Moved: seq_001965.h5
# Moved: seq_001966.h5
# Moved: seq_001967.h5
# Moved: seq_001968.h5
# Moved: seq_001969.h5
# Moved: seq_001970.h5
# Moved: seq_001971.h5
# Moved: seq_001972.h5
# Moved: seq_001973.h5
# Moved: seq_001974.h5
# Moved: seq_001975.h5
# Moved: seq_001976.h5
# Moved: seq_001977.h5
# Moved: seq_001978.h5
# Moved: seq_001979.h5
# Moved: seq_001980.h5
# Moved: seq_001981.h5
# Moved: seq_001982.h5
# Moved: seq_001983.h5
# Moved: seq_001984.h5
# Moved: seq_001985.h5
# Moved: seq_001986.h5
# Moved: seq_001987.h5
# Moved: seq_001988.h5
# Moved: seq_001989.h5
# Moved: seq_001990.h5
# Moved: seq_001991.h5
# Moved: seq_001992.h5
# Moved: seq_001993.h5
# Moved: seq_001994.h5
# Moved: seq_001995.h5
# Moved: seq_001996.h5
# Moved: seq_001997.h5
# Moved: seq_001998.h5
# Moved: seq_001999.h5
# Moved: seq_002000.h5
# Moved: seq_000001.h5
# Moved: seq_000002.h5
# Moved: seq_000003.h5
# Moved: seq_000004.h5
# Moved: seq_000005.h5
# Moved: seq_000006.h5
# Moved: seq_000007.h5
# Moved: seq_000008.h5
# Moved: seq_000009.h5
# Moved: seq_000010.h5
# Moved: seq_000011.h5
# Moved: seq_000012.h5
# Moved: seq_000013.h5
# Moved: seq_000014.h5
# Moved: seq_000015.h5
# Moved: seq_000016.h5
# Moved: seq_000017.h5
# Moved: seq_000018.h5
# Moved: seq_000019.h5
# Moved: seq_000020.h5
# Moved: seq_000021.h5
# Moved: seq_000022.h5
# Moved: seq_000023.h5
# Moved: seq_000024.h5
# Moved: seq_000025.h5
# Moved: seq_000026.h5
# Moved: seq_000027.h5
# Moved: seq_000028.h5
# Moved: seq_000029.h5
# Moved: seq_000030.h5
# Moved: seq_000031.h5
# Moved: seq_000032.h5
# Moved: seq_000033.h5
# Moved: seq_000034.h5
# Moved: seq_000035.h5
# Moved: seq_000036.h5
# Moved: seq_000037.h5
# Moved: seq_000038.h5
# Moved: seq_000039.h5
# Moved: seq_000040.h5
# Moved: seq_000041.h5
# Moved: seq_000042.h5
# Moved: seq_000043.h5
# Moved: seq_000044.h5
# Moved: seq_000045.h5
# Moved: seq_000046.h5
# Moved: seq_000047.h5
# Moved: seq_000048.h5
# Moved: seq_000049.h5
# Moved: seq_000050.h5
# Moved: seq_000051.h5
# Moved: seq_000052.h5
# Moved: seq_000053.h5
# Moved: seq_000054.h5
# Moved: seq_000055.h5
# Moved: seq_000056.h5
# Moved: seq_000057.h5
# Moved: seq_000058.h5
# Moved: seq_000059.h5
# Moved: seq_000060.h5
# Moved: seq_000061.h5
# Moved: seq_000062.h5
# Moved: seq_000063.h5
# Moved: seq_000064.h5
# Moved: seq_000065.h5
# Moved: seq_000066.h5
# Moved: seq_000067.h5
# Moved: seq_000068.h5
# Moved: seq_000069.h5
# Moved: seq_000070.h5
# Moved: seq_000071.h5
# Moved: seq_000072.h5
# Moved: seq_000073.h5
# Moved: seq_000074.h5
# Moved: seq_000075.h5
# Moved: seq_000076.h5
# Moved: seq_000077.h5
# Moved: seq_000078.h5
# Moved: seq_000079.h5
# Moved: seq_000080.h5
# Moved: seq_000081.h5
# Moved: seq_000082.h5
# Moved: seq_000083.h5
# Moved: seq_000084.h5
# Moved: seq_000085.h5
# Moved: seq_000086.h5
# Moved: seq_000087.h5
# Moved: seq_000088.h5
# Moved: seq_000089.h5
# Moved: seq_000090.h5
# Moved: seq_000091.h5
# Moved: seq_000092.h5
# Moved: seq_000093.h5
# Moved: seq_000094.h5
# Moved: seq_000095.h5
# Moved: seq_000096.h5
# Moved: seq_000097.h5
# Moved: seq_000098.h5
# Moved: seq_000099.h5
# Moved: seq_000100.h5
# Moved: seq_000101.h5
# Moved: seq_000102.h5
# Moved: seq_000103.h5
# Moved: seq_000104.h5
# Moved: seq_000105.h5
# Moved: seq_000106.h5
# Moved: seq_000107.h5
# Moved: seq_000108.h5
# Moved: seq_000109.h5
# Moved: seq_000110.h5
# Moved: seq_000111.h5
# Moved: seq_000112.h5
# Moved: seq_000113.h5
# Moved: seq_000114.h5
# Moved: seq_000115.h5
# Moved: seq_000116.h5
# Moved: seq_000117.h5
# Moved: seq_000118.h5
# Moved: seq_000119.h5
# Moved: seq_000120.h5
# Moved: seq_000121.h5
# Moved: seq_000122.h5
# Moved: seq_000123.h5
# Moved: seq_000124.h5
# Moved: seq_000125.h5
# Moved: seq_000126.h5
# Moved: seq_000127.h5
# Moved: seq_000128.h5
# Moved: seq_000129.h5
# Moved: seq_000130.h5
# Moved: seq_000131.h5
# Moved: seq_000132.h5
# Moved: seq_000133.h5
# Moved: seq_000134.h5
# Moved: seq_000135.h5
# Moved: seq_000136.h5
# Moved: seq_000137.h5
# Moved: seq_000138.h5
# Moved: seq_000139.h5
# Moved: seq_000140.h5
# Moved: seq_000141.h5
# Moved: seq_000142.h5
# Moved: seq_000143.h5
# Moved: seq_000144.h5
# Moved: seq_000145.h5
# Moved: seq_000146.h5
# Moved: seq_000147.h5
# Moved: seq_000148.h5
# Moved: seq_000149.h5
# Moved: seq_000150.h5
# Moved: seq_000151.h5
# Moved: seq_000152.h5
# Moved: seq_000153.h5
# Moved: seq_000154.h5
# Moved: seq_000155.h5
# Moved: seq_000156.h5
# Moved: seq_000157.h5
# Moved: seq_000158.h5
# Moved: seq_000159.h5
# Moved: seq_000160.h5
# Moved: seq_000161.h5
# Moved: seq_000162.h5
# Moved: seq_000163.h5
# Moved: seq_000164.h5
# Moved: seq_000165.h5
# Moved: seq_000166.h5
# Moved: seq_000167.h5
# Moved: seq_000168.h5
# Moved: seq_000169.h5
# Moved: seq_000170.h5
# Moved: seq_000171.h5
# Moved: seq_000172.h5
# Moved: seq_000173.h5
# Moved: seq_000174.h5
# Moved: seq_000175.h5
# Moved: seq_000176.h5
# Moved: seq_000177.h5
# Moved: seq_000178.h5
# Moved: seq_000179.h5
# Moved: seq_000180.h5
# Moved: seq_000181.h5
# Moved: seq_000182.h5
# Moved: seq_000183.h5
# Moved: seq_000184.h5
# Moved: seq_000185.h5
# Moved: seq_000186.h5
# Moved: seq_000187.h5
# Moved: seq_000188.h5
# Moved: seq_000189.h5
# Moved: seq_000190.h5
# Moved: seq_000191.h5
# Moved: seq_000192.h5
# Moved: seq_000193.h5
# Moved: seq_000194.h5
# Moved: seq_000195.h5
# Moved: seq_000196.h5
# Moved: seq_000197.h5
# Moved: seq_000198.h5
# Moved: seq_000199.h5
# Moved: seq_000200.h5
# Moved: seq_000201.h5
# Moved: seq_000202.h5
# Moved: seq_000203.h5
# Moved: seq_000204.h5
# Moved: seq_000205.h5
# Moved: seq_000206.h5
# Moved: seq_000207.h5
# Moved: seq_000208.h5
# Moved: seq_000209.h5
# Moved: seq_000210.h5
# Moved: seq_000211.h5
# Moved: seq_000212.h5
# Moved: seq_000213.h5
# Moved: seq_000214.h5
# Moved: seq_000215.h5
# Moved: seq_000216.h5
# Moved: seq_000217.h5
# Moved: seq_000218.h5
# Moved: seq_000219.h5
# Moved: seq_000220.h5
# Moved: seq_000221.h5
# Moved: seq_000222.h5
# Moved: seq_000223.h5
# Moved: seq_000224.h5
# Moved: seq_000225.h5
# Moved: seq_000226.h5
# Moved: seq_000227.h5
# Moved: seq_000228.h5
# Moved: seq_000229.h5
# Moved: seq_000230.h5
# Moved: seq_000231.h5
# Moved: seq_000232.h5
# Moved: seq_000233.h5
# Moved: seq_000234.h5
# Moved: seq_000235.h5
# Moved: seq_000236.h5
# Moved: seq_000237.h5
# Moved: seq_000238.h5
# Moved: seq_000239.h5
# Moved: seq_000240.h5
# Moved: seq_000241.h5
# Moved: seq_000242.h5
# Moved: seq_000243.h5
# Moved: seq_000244.h5
# Moved: seq_000245.h5
# Moved: seq_000246.h5
# Moved: seq_000247.h5
# Moved: seq_000248.h5
# Moved: seq_000249.h5
# Moved: seq_000250.h5
# Moved: seq_000251.h5
# Moved: seq_000252.h5
# Moved: seq_000253.h5
# Moved: seq_000254.h5
# Moved: seq_000255.h5
# Moved: seq_000256.h5
# Moved: seq_000257.h5
# Moved: seq_000258.h5
# Moved: seq_000259.h5
# Moved: seq_000260.h5
# Moved: seq_000261.h5
# Moved: seq_000262.h5
# Moved: seq_000263.h5
# Moved: seq_000264.h5
# Moved: seq_000265.h5
# Moved: seq_000266.h5
# Moved: seq_000267.h5
# Moved: seq_000268.h5
# Moved: seq_000269.h5
# Moved: seq_000270.h5
# Moved: seq_000271.h5
# Moved: seq_000272.h5
# Moved: seq_000273.h5
# Moved: seq_000274.h5
# Moved: seq_000275.h5
# Moved: seq_000276.h5
# Moved: seq_000277.h5
# Moved: seq_000278.h5
# Moved: seq_000279.h5
# Moved: seq_000280.h5
# Moved: seq_000281.h5
# Moved: seq_000282.h5
# Moved: seq_000283.h5
# Moved: seq_000284.h5
# Moved: seq_000285.h5
# Moved: seq_000286.h5
# Moved: seq_000287.h5
# Moved: seq_000288.h5
# Moved: seq_000289.h5
# Moved: seq_000290.h5
# Moved: seq_000291.h5
# Moved: seq_000292.h5
# Moved: seq_000293.h5
# Moved: seq_000294.h5
# Moved: seq_000295.h5
# Moved: seq_000296.h5
# Moved: seq_000297.h5
# Moved: seq_000298.h5
# Moved: seq_000299.h5
# Moved: seq_000300.h5
# Moved: seq_000301.h5
# Moved: seq_000302.h5
# Moved: seq_000303.h5
# Moved: seq_000304.h5
# Moved: seq_000305.h5
# Moved: seq_000306.h5
# Moved: seq_000307.h5
# Moved: seq_000308.h5
# Moved: seq_000309.h5
# Moved: seq_000310.h5
# Moved: seq_000311.h5
# Moved: seq_000312.h5
# Moved: seq_000313.h5
# Moved: seq_000314.h5
# Moved: seq_000315.h5
# Moved: seq_000316.h5
# Moved: seq_000317.h5
# Moved: seq_000318.h5
# Moved: seq_000319.h5
# Moved: seq_000320.h5
# Moved: seq_000321.h5
# Moved: seq_000322.h5
# Moved: seq_000323.h5
# Moved: seq_000324.h5
# Moved: seq_000325.h5
# Moved: seq_000326.h5
# Moved: seq_000327.h5
# Moved: seq_000328.h5
# Moved: seq_000329.h5
# Moved: seq_000330.h5
# Moved: seq_000331.h5
# Moved: seq_000332.h5
# Moved: seq_000333.h5
# Moved: seq_000334.h5
# Moved: seq_000335.h5
# Moved: seq_000336.h5
# Moved: seq_000337.h5
# Moved: seq_000338.h5
# Moved: seq_000339.h5
# Moved: seq_000340.h5
# Moved: seq_000341.h5
# Moved: seq_000342.h5
# Moved: seq_000343.h5
# Moved: seq_000344.h5
# Moved: seq_000345.h5
# Moved: seq_000346.h5
# Moved: seq_000347.h5
# Moved: seq_000348.h5
# Moved: seq_000349.h5
# Moved: seq_000350.h5
# Moved: seq_000351.h5
# Moved: seq_000352.h5
# Moved: seq_000353.h5
# Moved: seq_000354.h5
# Moved: seq_000355.h5
# Moved: seq_000356.h5
# Moved: seq_000357.h5
# Moved: seq_000358.h5
# Moved: seq_000359.h5
# Moved: seq_000360.h5
# Moved: seq_000361.h5
# Moved: seq_000362.h5
# Moved: seq_000363.h5
# Moved: seq_000364.h5
# Moved: seq_000365.h5
# Moved: seq_000366.h5
# Moved: seq_000367.h5
# Moved: seq_000368.h5
# Moved: seq_000369.h5
# Moved: seq_000370.h5
# Moved: seq_000371.h5
# Moved: seq_000372.h5
# Moved: seq_000373.h5
# Moved: seq_000374.h5
# Moved: seq_000375.h5
# Moved: seq_000376.h5
# Moved: seq_000377.h5
# Moved: seq_000378.h5
# Moved: seq_000379.h5
# Moved: seq_000380.h5
# Moved: seq_000381.h5
# Moved: seq_000382.h5
# Moved: seq_000383.h5
# Moved: seq_000384.h5
# Moved: seq_000385.h5
# Moved: seq_000386.h5
# Moved: seq_000387.h5
# Moved: seq_000388.h5
# Moved: seq_000389.h5
# Moved: seq_000390.h5
# Moved: seq_000391.h5
# Moved: seq_000392.h5
# Moved: seq_000393.h5
# Moved: seq_000394.h5
# Moved: seq_000395.h5
# Moved: seq_000396.h5
# Moved: seq_000397.h5
# Moved: seq_000398.h5
# Moved: seq_000399.h5
# Moved: seq_000400.h5
# Moved: seq_000401.h5
# Moved: seq_000402.h5
# Moved: seq_000403.h5
# Moved: seq_000404.h5
# Moved: seq_000405.h5
# Moved: seq_000406.h5
# Moved: seq_000407.h5
# Moved: seq_000408.h5
# Moved: seq_000409.h5
# Moved: seq_000410.h5
# Moved: seq_000411.h5
# Moved: seq_000412.h5
# Moved: seq_000413.h5
# Moved: seq_000414.h5
# Moved: seq_000415.h5
# Moved: seq_000416.h5
# Moved: seq_000417.h5
# Moved: seq_000418.h5
# Moved: seq_000419.h5
# Moved: seq_000420.h5
# Moved: seq_000421.h5
# Moved: seq_000422.h5
# Moved: seq_000423.h5
# Moved: seq_000424.h5
# Moved: seq_000425.h5
# Moved: seq_000426.h5
# Moved: seq_000427.h5
# Moved: seq_000428.h5
# Moved: seq_000429.h5
# Moved: seq_000430.h5
# Moved: seq_000431.h5
# Moved: seq_000432.h5
# Moved: seq_000433.h5
# Moved: seq_000434.h5
# Moved: seq_000435.h5
# Moved: seq_000436.h5
# Moved: seq_000437.h5
# Moved: seq_000438.h5
# Moved: seq_000439.h5
# Moved: seq_000440.h5
# Moved: seq_000441.h5
# Moved: seq_000442.h5
# Moved: seq_000443.h5
# Moved: seq_000444.h5
# Moved: seq_000445.h5
# Moved: seq_000446.h5
# Moved: seq_000447.h5
# Moved: seq_000448.h5
# Moved: seq_000449.h5
# Moved: seq_000450.h5
# Moved: seq_000451.h5
# Moved: seq_000452.h5
# Moved: seq_000453.h5
# Moved: seq_000454.h5
# Moved: seq_000455.h5
# Moved: seq_000456.h5
# Moved: seq_000457.h5
# Moved: seq_000458.h5
# Moved: seq_000459.h5
# Moved: seq_000460.h5
# Moved: seq_000461.h5
# Moved: seq_000462.h5
# Moved: seq_000463.h5
# Moved: seq_000464.h5
# Moved: seq_000465.h5
# Moved: seq_000466.h5
# Moved: seq_000467.h5
# Moved: seq_000468.h5
# Moved: seq_000469.h5
# Moved: seq_000470.h5
# Moved: seq_000471.h5
# Moved: seq_000472.h5
# Moved: seq_000473.h5
# Moved: seq_000474.h5
# Moved: seq_000475.h5
# Moved: seq_000476.h5
# Moved: seq_000477.h5
# Moved: seq_000478.h5
# Moved: seq_000479.h5
# Moved: seq_000480.h5
# Moved: seq_000481.h5
# Moved: seq_000482.h5
# Moved: seq_000483.h5
# Moved: seq_000484.h5
# Moved: seq_000485.h5
# Moved: seq_000486.h5
# Moved: seq_000487.h5
# Moved: seq_000488.h5
# Moved: seq_000489.h5
# Moved: seq_000490.h5
# Moved: seq_000491.h5
# Moved: seq_000492.h5
# Moved: seq_000493.h5
# Moved: seq_000494.h5
# Moved: seq_000495.h5
# Moved: seq_000496.h5
# Moved: seq_000497.h5
# Moved: seq_000498.h5
# Moved: seq_000499.h5
# Moved: seq_000500.h5
# Moved: seq_000501.h5
# Moved: seq_000502.h5
# Moved: seq_000503.h5
# Moved: seq_000504.h5
# Moved: seq_000505.h5
# Moved: seq_000506.h5
# Moved: seq_000507.h5
# Moved: seq_000508.h5
# Moved: seq_000509.h5
# Moved: seq_000510.h5
# Moved: seq_000511.h5
# Moved: seq_000512.h5
# Moved: seq_000513.h5
# Moved: seq_000514.h5
# Moved: seq_000515.h5
# Moved: seq_000516.h5
# Moved: seq_000517.h5
# Moved: seq_000518.h5
# Moved: seq_000519.h5
# Moved: seq_000520.h5
# Moved: seq_000521.h5
# Moved: seq_000522.h5
# Moved: seq_000523.h5
# Moved: seq_000524.h5
# Moved: seq_000525.h5
# Moved: seq_000526.h5
# Moved: seq_000527.h5
# Moved: seq_000528.h5
# Moved: seq_000529.h5
# Moved: seq_000530.h5
# Moved: seq_000531.h5
# Moved: seq_000532.h5
# Moved: seq_000533.h5
# Moved: seq_000534.h5
# Moved: seq_000535.h5
# Moved: seq_000536.h5
# Moved: seq_000537.h5
# Moved: seq_000538.h5
# Moved: seq_000539.h5
# Moved: seq_000540.h5
# Moved: seq_000541.h5
# Moved: seq_000542.h5
# Moved: seq_000543.h5
# Moved: seq_000544.h5
# Moved: seq_000545.h5
# Moved: seq_000546.h5
# Moved: seq_000547.h5
# Moved: seq_000548.h5
# Moved: seq_000549.h5
# Moved: seq_000550.h5
# Moved: seq_000551.h5
# Moved: seq_000552.h5
# Moved: seq_000553.h5
# Moved: seq_000554.h5
# Moved: seq_000555.h5
# Moved: seq_000556.h5
# Moved: seq_000557.h5
# Moved: seq_000558.h5
# Moved: seq_000559.h5
# Moved: seq_000560.h5
# Moved: seq_000561.h5
# Moved: seq_000562.h5
# Moved: seq_000563.h5
# Moved: seq_000564.h5
# Moved: seq_000565.h5
# Moved: seq_000566.h5
# Moved: seq_000567.h5
# Moved: seq_000568.h5
# Moved: seq_000569.h5
# Moved: seq_000570.h5
# Moved: seq_000571.h5
# Moved: seq_000572.h5
# Moved: seq_000573.h5
# Moved: seq_000574.h5
# Moved: seq_000575.h5
# Moved: seq_000576.h5
# Moved: seq_000577.h5
# Moved: seq_000578.h5
# Moved: seq_000579.h5
# Moved: seq_000580.h5
# Moved: seq_000581.h5
# Moved: seq_000582.h5
# Moved: seq_000583.h5
# Moved: seq_000584.h5
# Moved: seq_000585.h5
# Moved: seq_000586.h5
# Moved: seq_000587.h5
# Moved: seq_000588.h5
# Moved: seq_000589.h5
# Moved: seq_000590.h5
# Moved: seq_000591.h5
# Moved: seq_000592.h5
# Moved: seq_000593.h5
# Moved: seq_000594.h5
# Moved: seq_000595.h5
# Moved: seq_000596.h5
# Moved: seq_000597.h5
# Moved: seq_000598.h5
# Moved: seq_000599.h5
# Moved: seq_000600.h5
# Moved: seq_000601.h5
# Moved: seq_000602.h5
# Moved: seq_000603.h5
# Moved: seq_000604.h5
# Moved: seq_000605.h5
# Moved: seq_000606.h5
# Moved: seq_000607.h5
# Moved: seq_000608.h5
# Moved: seq_000609.h5
# Moved: seq_000610.h5
# Moved: seq_000611.h5
# Moved: seq_000612.h5
# Moved: seq_000613.h5
# Moved: seq_000614.h5
# Moved: seq_000615.h5
# Moved: seq_000616.h5
# Moved: seq_000617.h5
# Moved: seq_000618.h5
# Moved: seq_000619.h5
# Moved: seq_000620.h5
# Moved: seq_000621.h5
# Moved: seq_000622.h5
# Moved: seq_000623.h5
# Moved: seq_000624.h5
# Moved: seq_000625.h5
# Moved: seq_000626.h5
# Moved: seq_000627.h5
# Moved: seq_000628.h5
# Moved: seq_000629.h5
# Moved: seq_000630.h5
# Moved: seq_000631.h5
# Moved: seq_000632.h5
# Moved: seq_000633.h5
# Moved: seq_000634.h5
# Moved: seq_000635.h5
# Moved: seq_000636.h5
# Moved: seq_000637.h5
# Moved: seq_000638.h5
# Moved: seq_000639.h5
# Moved: seq_000640.h5
# Moved: seq_000641.h5
# Moved: seq_000642.h5
# Moved: seq_000643.h5
# Moved: seq_000644.h5
# Moved: seq_000645.h5
# Moved: seq_000646.h5
# Moved: seq_000647.h5
# Moved: seq_000648.h5
# Moved: seq_000649.h5
# Moved: seq_000650.h5
# Moved: seq_000651.h5
# Moved: seq_000652.h5
# Moved: seq_000653.h5
# Moved: seq_000654.h5
# Moved: seq_000655.h5
# Moved: seq_000656.h5
# Moved: seq_000657.h5
# Moved: seq_000658.h5
# Moved: seq_000659.h5
# Moved: seq_000660.h5
# Moved: seq_000661.h5
# Moved: seq_000662.h5
# Moved: seq_000663.h5
# Moved: seq_000664.h5
# Moved: seq_000665.h5
# Moved: seq_000666.h5
# Moved: seq_000667.h5
# Moved: seq_000668.h5
# Moved: seq_000669.h5
# Moved: seq_000670.h5
# Moved: seq_000671.h5
# Moved: seq_000672.h5
# Moved: seq_000673.h5
# Moved: seq_000674.h5
# Moved: seq_000675.h5
# Moved: seq_000676.h5
# Moved: seq_000677.h5
# Moved: seq_000678.h5
# Moved: seq_000679.h5
# Moved: seq_000680.h5
# Moved: seq_000681.h5
# Moved: seq_000682.h5
# Moved: seq_000683.h5
# Moved: seq_000684.h5
# Moved: seq_000685.h5
# Moved: seq_000686.h5
# Moved: seq_000687.h5
# Moved: seq_000688.h5
# Moved: seq_000689.h5
# Moved: seq_000690.h5
# Moved: seq_000691.h5
# Moved: seq_000692.h5
# Moved: seq_000693.h5
# Moved: seq_000694.h5
# Moved: seq_000695.h5
# Moved: seq_000696.h5
# Moved: seq_000697.h5
# Moved: seq_000698.h5
# Moved: seq_000699.h5
# Moved: seq_000700.h5
# Moved: seq_000701.h5
# Moved: seq_000702.h5
# Moved: seq_000703.h5
# Moved: seq_000704.h5
# Moved: seq_000705.h5
# Moved: seq_000706.h5
# Moved: seq_000707.h5
# Moved: seq_000708.h5
# Moved: seq_000709.h5
# Moved: seq_000710.h5
# Moved: seq_000711.h5
# Moved: seq_000712.h5
# Moved: seq_000713.h5
# Moved: seq_000714.h5
# Moved: seq_000715.h5
# Moved: seq_000716.h5
# Moved: seq_000717.h5
# Moved: seq_000718.h5
# Moved: seq_000719.h5
# Moved: seq_000720.h5
# Moved: seq_000721.h5
# Moved: seq_000722.h5
# Moved: seq_000723.h5
# Moved: seq_000724.h5
# Moved: seq_000725.h5
# Moved: seq_000726.h5
# Moved: seq_000727.h5
# Moved: seq_000728.h5
# Moved: seq_000729.h5
# Moved: seq_000730.h5
# Moved: seq_000731.h5
# Moved: seq_000732.h5
# Moved: seq_000733.h5
# Moved: seq_000734.h5
# Moved: seq_000735.h5
# Moved: seq_000736.h5
# Moved: seq_000737.h5
# Moved: seq_000738.h5
# Moved: seq_000739.h5
# Moved: seq_000740.h5
# Moved: seq_000741.h5
# Moved: seq_000742.h5
# Moved: seq_000743.h5
# Moved: seq_000744.h5
# Moved: seq_000745.h5
# Moved: seq_000746.h5
# Moved: seq_000747.h5
# Moved: seq_000748.h5
# Moved: seq_000749.h5
# Moved: seq_000750.h5
# Moved: seq_000751.h5
# Moved: seq_000752.h5
# Moved: seq_000753.h5
# Moved: seq_000754.h5
# Moved: seq_000755.h5
# Moved: seq_000756.h5
# Moved: seq_000757.h5
# Moved: seq_000758.h5
# Moved: seq_000759.h5
# Moved: seq_000760.h5
# Moved: seq_000761.h5
# Moved: seq_000762.h5
# Moved: seq_000763.h5
# Moved: seq_000764.h5
# Moved: seq_000765.h5
# Moved: seq_000766.h5
# Moved: seq_000767.h5
# Moved: seq_000768.h5
# Moved: seq_000769.h5
# Moved: seq_000770.h5
# Moved: seq_000771.h5
# Moved: seq_000772.h5
# Moved: seq_000773.h5
# Moved: seq_000774.h5
# Moved: seq_000775.h5
# Moved: seq_000776.h5
# Moved: seq_000777.h5
# Moved: seq_000778.h5
# Moved: seq_000779.h5
# Moved: seq_000780.h5
# Moved: seq_000781.h5
# Moved: seq_000782.h5
# Moved: seq_000783.h5
# Moved: seq_000784.h5
# Moved: seq_000785.h5
# Moved: seq_000786.h5
# Moved: seq_000787.h5
# Moved: seq_000788.h5
# Moved: seq_000789.h5
# Moved: seq_000790.h5
# Moved: seq_000791.h5
# Moved: seq_000792.h5
# Moved: seq_000793.h5
# Moved: seq_000794.h5
# Moved: seq_000795.h5
# Moved: seq_000796.h5
# Moved: seq_000797.h5
# Moved: seq_000798.h5
# Moved: seq_000799.h5
# Moved: seq_000800.h5
# Moved: seq_000801.h5
# Moved: seq_000802.h5
# Moved: seq_000803.h5
# Moved: seq_000804.h5
# Moved: seq_000805.h5
# Moved: seq_000806.h5
# Moved: seq_000807.h5
# Moved: seq_000808.h5
# Moved: seq_000809.h5
# Moved: seq_000810.h5
# Moved: seq_000811.h5
# Moved: seq_000812.h5
# Moved: seq_000813.h5
# Moved: seq_000814.h5
# Moved: seq_000815.h5
# Moved: seq_000816.h5
# Moved: seq_000817.h5
# Moved: seq_000818.h5
# Moved: seq_000819.h5
# Moved: seq_000820.h5
# Moved: seq_000821.h5
# Moved: seq_000822.h5
# Moved: seq_000823.h5
# Moved: seq_000824.h5
# Moved: seq_000825.h5
# Moved: seq_000826.h5
# Moved: seq_000827.h5
# Moved: seq_000828.h5
# Moved: seq_000829.h5
# Moved: seq_000830.h5
# Moved: seq_000831.h5
# Moved: seq_000832.h5
# Moved: seq_000833.h5
# Moved: seq_000834.h5
# Moved: seq_000835.h5
# Moved: seq_000836.h5
# Moved: seq_000837.h5
# Moved: seq_000838.h5
# Moved: seq_000839.h5
# Moved: seq_000840.h5
# Moved: seq_000841.h5
# Moved: seq_000842.h5
# Moved: seq_000843.h5
# Moved: seq_000844.h5
# Moved: seq_000845.h5
# Moved: seq_000846.h5
# Moved: seq_000847.h5
# Moved: seq_000848.h5
# Moved: seq_000849.h5
# Moved: seq_000850.h5
# Moved: seq_000851.h5
# Moved: seq_000852.h5
# Moved: seq_000853.h5
# Moved: seq_000854.h5
# Moved: seq_000855.h5
# Moved: seq_000856.h5
# Moved: seq_000857.h5
# Moved: seq_000858.h5
# Moved: seq_000859.h5
# Moved: seq_000860.h5
# Moved: seq_000861.h5
# Moved: seq_000862.h5
# Moved: seq_000863.h5
# Moved: seq_000864.h5
# Moved: seq_000865.h5
# Moved: seq_000866.h5
# Moved: seq_000867.h5
# Moved: seq_000868.h5
# Moved: seq_000869.h5
# Moved: seq_000870.h5
# Moved: seq_000871.h5
# Moved: seq_000872.h5
# Moved: seq_000873.h5
# Moved: seq_000874.h5
# Moved: seq_000875.h5
# Moved: seq_000876.h5
# Moved: seq_000877.h5
# Moved: seq_000878.h5
# Moved: seq_000879.h5
# Moved: seq_000880.h5
# Moved: seq_000881.h5
# Moved: seq_000882.h5
# Moved: seq_000883.h5
# Moved: seq_000884.h5
# Moved: seq_000885.h5
# Moved: seq_000886.h5
# Moved: seq_000887.h5
# Moved: seq_000888.h5
# Moved: seq_000889.h5
# Moved: seq_000890.h5
# Moved: seq_000891.h5
# Moved: seq_000892.h5
# Moved: seq_000893.h5
# Moved: seq_000894.h5
# Moved: seq_000895.h5
# Moved: seq_000896.h5
# Moved: seq_000897.h5
# Moved: seq_000898.h5
# Moved: seq_000899.h5
# Moved: seq_000900.h5
# Moved: seq_000901.h5
# Moved: seq_000902.h5
# Moved: seq_000903.h5
# Moved: seq_000904.h5
# Moved: seq_000905.h5
# Moved: seq_000906.h5
# Moved: seq_000907.h5
# Moved: seq_000908.h5
# Moved: seq_000909.h5
# Moved: seq_000910.h5
# Moved: seq_000911.h5
# Moved: seq_000912.h5
# Moved: seq_000913.h5
# Moved: seq_000914.h5
# Moved: seq_000915.h5
# Moved: seq_000916.h5
# Moved: seq_000917.h5
# Moved: seq_000918.h5
# Moved: seq_000919.h5
# Moved: seq_000920.h5
# Moved: seq_000921.h5
# Moved: seq_000922.h5
# Moved: seq_000923.h5
# Moved: seq_000924.h5
# Moved: seq_000925.h5
# Moved: seq_000926.h5
# Moved: seq_000927.h5
# Moved: seq_000928.h5
# Moved: seq_000929.h5
# Moved: seq_000930.h5
# Moved: seq_000931.h5
# Moved: seq_000932.h5
# Moved: seq_000933.h5
# Moved: seq_000934.h5
# Moved: seq_000935.h5
# Moved: seq_000936.h5
# Moved: seq_000937.h5
# Moved: seq_000938.h5
# Moved: seq_000939.h5
# Moved: seq_000940.h5
# Moved: seq_000941.h5
# Moved: seq_000942.h5
# Moved: seq_000943.h5
# Moved: seq_000944.h5
# Moved: seq_000945.h5
# Moved: seq_000946.h5
# Moved: seq_000947.h5
# Moved: seq_000948.h5
# Moved: seq_000949.h5
# Moved: seq_000950.h5
# Moved: seq_000951.h5
# Moved: seq_000952.h5
# Moved: seq_000953.h5
# Moved: seq_000954.h5
# Moved: seq_000955.h5
# Moved: seq_000956.h5
# Moved: seq_000957.h5
# Moved: seq_000958.h5
# Moved: seq_000959.h5
# Moved: seq_000960.h5
# Moved: seq_000961.h5
# Moved: seq_000962.h5
# Moved: seq_000963.h5
# Moved: seq_000964.h5
# Moved: seq_000965.h5
# Moved: seq_000966.h5
# Moved: seq_000967.h5
# Moved: seq_000968.h5
# Moved: seq_000969.h5
# Moved: seq_000970.h5
# Moved: seq_000971.h5
# Moved: seq_000972.h5
# Moved: seq_000973.h5
# Moved: seq_000974.h5
# Moved: seq_000975.h5
# Moved: seq_000976.h5
# Moved: seq_000977.h5
# Moved: seq_000978.h5
# Moved: seq_000979.h5
# Moved: seq_000980.h5
# Moved: seq_000981.h5
# Moved: seq_000982.h5
# Moved: seq_000983.h5
# Moved: seq_000984.h5
# Moved: seq_000985.h5
# Moved: seq_000986.h5
# Moved: seq_000987.h5
# Moved: seq_000988.h5
# Moved: seq_000989.h5
# Moved: seq_000990.h5
# Moved: seq_000991.h5
# Moved: seq_000992.h5
# Moved: seq_000993.h5
# Moved: seq_000994.h5
# Moved: seq_000995.h5
# Moved: seq_000996.h5
# Moved: seq_000997.h5
# Moved: seq_000998.h5
# Moved: seq_000999.h5
# Moved: seq_001000.h5
# Completed moving all .h5 files!

# %% [markdown]
# Display some:

# %%
path_images = '/content/drive/MyDrive/CrowdCounting/Data/mall_dataset/frames/'
path_density_maps = '/content/drive/MyDrive/CrowdCounting/Data/mall_dataset/density_maps/'

to_print = 5
plt.figure(figsize=(6, 3 * to_print))

for i, (img_name, den_name) in enumerate(zip(os.listdir(path = path_images), os.listdir(path = path_density_maps))):
    if i == to_print:
      break
    img = cv2.cvtColor(cv2.imread(path_images + img_name), cv2.COLOR_BGR2RGB)
    ds_map = h5py.File(path_density_maps + den_name)
    ds_map = np.asarray(ds_map['density'])

    plt.subplot(to_print, 2, i * 2 + 1)
    plt.axis("off")
    plt.imshow(img)
    plt.subplot(to_print, 2, (i+1) * 2)
    plt.axis("off")
    plt.imshow(ds_map, cmap = cm.jet)

# %% [markdown]
# ## CSRNet implementation
#
# **Run this**, since it's general for all the experiments.

# %%
# Code borrowed from:
# https://github.com/leeyeehoo/CSRNet-pytorch/blob/master/model.py.

def load_net(fname, net):
    with h5py.File(fname, 'r') as h5f:
        for k, v in net.state_dict().items():
            param = torch.from_numpy(np.asarray(h5f[k]))
            v.copy_(param)

def make_layers(cfg, in_channels = 3, batch_norm = False, dilation = False):
    if dilation:
        d_rate = 2
    else:
        d_rate = 1
    layers = []
    for v in cfg:
        if v == 'M':
            layers += [nn.MaxPool2d(kernel_size = 2, stride = 2)]
        else:
            conv2d = nn.Conv2d(in_channels, v, kernel_size = 3, padding = d_rate,dilation = d_rate)
            if batch_norm:
                layers += [conv2d, nn.BatchNorm2d(v), nn.ReLU(inplace=True)]
            else:
                layers += [conv2d, nn.ReLU(inplace=True)]
            in_channels = v
    return nn.Sequential(*layers)

class CSRNet(nn.Module):
    def __init__(self):
        super(CSRNet, self).__init__()
        self.seen = 0
        self.frontend_feat = [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512]
        self.backend_feat = [512, 512, 512, 256, 128, 64]
        self.frontend = make_layers(self.frontend_feat)
        self.backend = make_layers(self.backend_feat, in_channels=512, dilation=True)
        self.output_layer = nn.Conv2d(64, 1, kernel_size=1)
        # load vgg16 weights on the frontend (transfer learning)

    def forward(self, x):
        x = self.frontend(x)
        x = self.backend(x)
        x = self.output_layer(x)
        return x

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.normal_(m.weight, std=0.01)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)

def load_data(img_path):
    img = Image.open(img_path).convert('RGB')
    return img

# %% [markdown]
# ## Load data and Train-val-test split
#
# **Run this**, since it's general for all the experiments.

# %%
# Load images and density maps
path_dataset = '/content/drive/MyDrive/CrowdCounting/Data/mall_dataset/frames/'

img_names = sorted([file for file in os.listdir(path=path_dataset) if file.lower().endswith('.jpg')])
den_names = sorted([file for file in os.listdir(path=path_dataset) if file.lower().endswith('.h5')])

random_state = 42

# Train_val - test split:
test_proportion = 0.2
train_val_img_names, test_img_names = train_test_split(img_names, test_size=test_proportion, random_state=random_state)
train_val_den_names, test_den_names = train_test_split(den_names, test_size=test_proportion, random_state=random_state)

# Train - val split
val_proportion = 0.1
train_img_names, val_img_names = train_test_split(train_val_img_names, test_size=val_proportion, random_state=random_state)
train_den_names, val_den_names = train_test_split(train_val_den_names, test_size=val_proportion, random_state=random_state)

# %%
mall_dataset_folder = '/content/drive/MyDrive/CrowdCounting/Data/mall_dataset/'

mall_gt = io.loadmat(os.path.join(mall_dataset_folder, 'mall_gt.mat'))
mall_head_positions_gt = mall_gt['frame'][0]

num_heads_list = []
for gt in mall_head_positions_gt:
  n_heads = len(gt[0][0][0])
  num_heads_list.append(n_heads)

test_indices = [img_names.index(name) for name in test_img_names]
Test_labels = [num_heads_list[idx] for idx in test_indices]

print(f'{len(Test_labels)} test targets loaded.')
# Out:
# 400 test targets loaded.

# %% [markdown]
# ## (1) Training using the authors' code
#
# Here we clone the **official PyTorch implementation of CSRNet**, and use it to train on a smaller portion of the Mall dataset.
#
# > https://github.com/leeyeehoo/CSRNet-pytorch

# %% [markdown]
# ### Train-val-test split
#
# We do this in order to generate .json files and store them to Google Drive.
#
# **Important**: Run this only the first time!

# %% [markdown]
# For some reason, the code expects both the density maps and original images to be in the same folder, so let's move them:

# %%
old_path = '/content/drive/MyDrive/CrowdCounting/Data/mall_dataset/density_maps'
new_path = '/content/drive/MyDrive/CrowdCounting/Data/mall_dataset/frames/'

# Ensure the destination folder exists; create it if necessary
os.makedirs(new_path, exist_ok=True)

all_files = os.listdir(old_path)

h5_files = [file for file in all_files if file.endswith('.h5')]

# Move each .h5 file to the new path
for h5_file in h5_files:
    source_file_path = os.path.join(old_path, h5_file)
    destination_file_path = os.path.join(new_path, h5_file)
    shutil.move(source_file_path, destination_file_path)

print("Files moved successfully.")
# Out:
# Files moved successfully.

# %% [markdown]
# Create json files for just the train, val and test images. For the density maps it's not needed - this is handled in code.
#
# **Important:** Since the code does data augmentation and uses SGD (batch_size=1), it is very slow. Therefore, just for our experimental purposes we will keep a small portion of the dataset.
#
# As we can see below, for 243 train images we obtain 243 * 4 = 972 training samples. If we were to keep the whole dataset, we would obtain 1440 * 4 = 5760 training samples.

# %%
# Load images and density maps
path_dataset = '/content/drive/MyDrive/CrowdCounting/Data/mall_dataset/frames/'

img_names = sorted([file for file in os.listdir(path=path_dataset) if file.lower().endswith('.jpg')])
den_names = sorted([file for file in os.listdir(path=path_dataset) if file.lower().endswith('.h5')])

random_state = 42

# Train_val - test split:
test_proportion = 0.1
train_val_img_names, test_img_names = train_test_split(img_names, test_size=test_proportion, random_state=random_state)
train_val_den_names, test_den_names = train_test_split(den_names, test_size=test_proportion, random_state=random_state)

# Train - val split
val_proportion = 0.2
train_img_names, val_img_names = train_test_split(train_val_img_names, test_size=val_proportion, random_state=random_state)
train_den_names, val_den_names = train_test_split(train_val_den_names, test_size=val_proportion, random_state=random_state)

train_img_names = [os.path.join(path_dataset, img) for img in train_img_names]
val_img_names = [os.path.join(path_dataset, img) for img in val_img_names]
test_img_names = [os.path.join(path_dataset, img) for img in test_img_names]
# train_den_names = [os.path.join(path_dataset, img) for img in train_den_names]
# val_den_names = [os.path.join(path_dataset, img) for img in val_den_names]
# test_den_names = [os.path.join(path_dataset, img) for img in test_den_names]

print('Size of the whole dataset:', len(img_names))

print('Size of the train dataset:', len(train_img_names))
print('Size of the val dataset:', len(val_img_names))
print('Size of the test dataset:', len(test_img_names))
print()

json_save_path = '/content/drive/MyDrive/CrowdCounting/Data/mall_dataset/'

# Save lists as JSON
def save_json(file_paths, file_name):
    json_file_path = os.path.join(json_save_path, f'{file_name}.json')
    with open(json_file_path, 'w') as json_file:
        json.dump(file_paths, json_file)
    print(f"File paths for {file_name} saved to {json_file_path}.")

save_json(train_img_names, 'train_img')
save_json(val_img_names, 'val_img')
save_json(test_img_names, 'test_img')
# save_json(train_den_names, 'train_den')
# save_json(val_den_names, 'val_den')
# save_json(test_den_names, 'test_den')

proportion_of_images_to_keep = 0.15
if proportion_of_images_to_keep < 1:
  train_img_names_reduced = train_img_names[:int(len(train_img_names) * proportion_of_images_to_keep)]
  val_img_names_reduced = val_img_names[:int(len(val_img_names) * proportion_of_images_to_keep)]
  print()
  print('Size of the reduced train dataset:', len(train_img_names_reduced))
  print('Size of the reduced val dataset:', len(val_img_names_reduced))
  print('Size of the test dataset:', len(test_img_names), " -> The test set remains the same.")
  print()
  save_json(train_img_names_reduced, 'train_img_reduced')
  save_json(val_img_names_reduced, 'val_img_reduced')
# Test stays the same.
# Out:
# Size of the whole dataset: 2000
# Size of the train dataset: 1440
# Size of the val dataset: 360
# Size of the test dataset: 200
#
# File paths for train_img saved to /content/drive/MyDrive/CrowdCounting/Data/mall_dataset/train_img.json.
# File paths for val_img saved to /content/drive/MyDrive/CrowdCounting/Data/mall_dataset/val_img.json.
# File paths for test_img saved to /content/drive/MyDrive/CrowdCounting/Data/mall_dataset/test_img.json.
#
# Size of the reduced train dataset: 216
# Size of the reduced val dataset: 54
# Size of the test dataset: 200  -> The test set remains the same.
#
# File paths for train_img_reduced saved to /content/drive/MyDrive/CrowdCounting/Data/mall_dataset/train_img_reduced.json.
# File paths for val_img_reduced saved to /content/drive/MyDrive/CrowdCounting/Data/mall_dataset/val_img_reduced.json.

# %% [markdown]
# ### Cloning and code modifications
#
# **Important**: This is to be done just the first time.

# %%
# !git clone https://github.com/leeyeehoo/CSRNet-pytorch.git
# Out:
# Cloning into 'CSRNet-pytorch'...
# remote: Enumerating objects: 86, done.
# remote: Total 86 (delta 0), reused 0 (delta 0), pack-reused 86 (from 1)
# Receiving objects: 100% (86/86), 622.25 KiB | 25.93 MiB/s, done.
# Resolving deltas: 100% (47/47), done.

# %%
# %cd CSRNet-pytorch
# Out:
# /content/CSRNet-pytorch

# %%
# %ls
# Out:
# dataset.py          part_A_test.json            part_B_train.json           utils.py
# image.py            part_A_train.json           part_B_train_with_val.json  val.ipynb
# make_dataset.ipynb  part_A_train_with_val.json  part_B_val.json
# make_model.ipynb    part_A_val.json             README.md
# model.py            part_B_test.json            train.py

# %% [markdown]
# The following changes are needed:
#
# * model.py:
#
#         xrange -> range
#         list(self.frontend.state_dict().items())[i][1].data[:] = list(mod.state_dict().items())[i][1].data[:]
#
# * image.py
#
#         target = cv2.resize(target,(target.shape[1]//8,target.shape[0]//8),interpolation = cv2.INTER_CUBIC)*64
#
# * train.py
#
#         device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#         Add device to global variables in main.
#         .cuda() -> to(device)
#         torch.manual_seed(args.seed)
#         os.environ['CUDA_VISIBLE_DEVICES'] = args.gpu -> if torch.cuda.is_available(): device = torch.device("cuda:" + args.gpu)
#
# Finally, **modify the number of epochs**. The code uses 400, but that is too much for a free version of Colab. We set epochs to a lower number (**20**) to be somewhat consistent with our own CSRNet implementation. We didn't use 40, because this code was much slower.

# %% [markdown]
# Finally we save the modified file to our Google Drive, to avoid having to download and modify the code over and over again.

# %%
# %cp -a /content/CSRNet-pytorch /content/drive/MyDrive/CrowdCounting/CSRNet-pytorch
print('Folder copied successfully.')
# Out:
# Folder copied successfully.

# %%
# %ls /content/drive/MyDrive/CrowdCounting/CSRNet-pytorch
# Out:
# CSRNet-pytorch/     model.py                    part_B_test.json            README.md
# dataset.py          part_A_test.json            part_B_train.json           train.py
# image.py            part_A_train.json           part_B_train_with_val.json  utils.py
# make_dataset.ipynb  part_A_train_with_val.json  part_B_val.json             val.ipynb
# make_model.ipynb    part_A_val.json             __pycache__/

# %% [markdown]
# ### Training

# %%
# %cd /content/drive/MyDrive/CrowdCounting/CSRNet-pytorch/
# Out:
# /content/drive/MyDrive/CrowdCounting/CSRNet-pytorch

# %%
# %ls
# Out:
# CSRNet-pytorch/     model.py                    part_B_test.json            README.md
# dataset.py          part_A_test.json            part_B_train.json           train.py
# image.py            part_A_train.json           part_B_train_with_val.json  utils.py
# make_dataset.ipynb  part_A_train_with_val.json  part_B_val.json             val.ipynb
# make_model.ipynb    part_A_val.json             __pycache__/

# %%
# !python train.py /content/drive/MyDrive/CrowdCounting/Data/mall_dataset/train_img_reduced.json /content/drive/MyDrive/CrowdCounting/Data/mall_dataset/val_img_reduced.json 0 no_pretrain_
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/_reduction.py:51: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# epoch 0, processed 0 samples, lr 0.0000001000
# Epoch: [0][0/864]	Time 5.759 (5.759)	Data 4.411 (4.411)	Loss 3.2366 (3.2366)
# Epoch: [0][30/864]	Time 2.170 (1.668)	Data 2.079 (1.558)	Loss 2.4926 (2.7683)
# Epoch: [0][60/864]	Time 1.484 (1.601)	Data 1.426 (1.517)	Loss 6.6768 (2.5935)
# Epoch: [0][90/864]	Time 1.534 (1.443)	Data 1.489 (1.362)	Loss 1.8488 (2.5039)
# Epoch: [0][120/864]	Time 0.161 (1.374)	Data 0.015 (1.295)	Loss 1.6018 (2.3902)
# Epoch: [0][150/864]	Time 1.311 (1.325)	Data 1.265 (1.241)	Loss 3.3932 (2.4536)
# Epoch: [0][180/864]	Time 0.164 (1.246)	Data 0.014 (1.160)	Loss 1.3360 (2.4472)
# Epoch: [0][210/864]	Time 0.169 (1.182)	Data 0.015 (1.092)	Loss 3.2084 (2.4356)
# Epoch: [0][240/864]	Time 0.168 (1.134)	Data 0.019 (1.042)	Loss 1.5371 (2.4275)
# Epoch: [0][270/864]	Time 0.171 (1.091)	Data 0.015 (0.997)	Loss 0.9656 (2.3420)
# Epoch: [0][300/864]	Time 0.170 (1.038)	Data 0.015 (0.941)	Loss 2.3027 (2.3510)
# Epoch: [0][330/864]	Time 0.172 (0.991)	Data 0.015 (0.890)	Loss 0.8086 (2.3661)
# Epoch: [0][360/864]	Time 0.170 (0.941)	Data 0.016 (0.838)	Loss 0.8100 (2.3756)
# Epoch: [0][390/864]	Time 0.169 (0.907)	Data 0.015 (0.801)	Loss 2.3220 (2.3557)
# Epoch: [0][420/864]	Time 0.171 (0.871)	Data 0.015 (0.763)	Loss 4.4392 (2.3524)
# Epoch: [0][450/864]	Time 1.700 (0.834)	Data 1.655 (0.724)	Loss 4.8184 (2.3854)
# Epoch: [0][480/864]	Time 0.170 (0.802)	Data 0.019 (0.689)	Loss 3.0676 (2.4042)
# Epoch: [0][510/864]	Time 0.171 (0.767)	Data 0.014 (0.653)	Loss 2.2495 (2.4134)
# Epoch: [0][540/864]	Time 0.170 (0.737)	Data 0.018 (0.621)	Loss 3.2422 (2.4026)
# Epoch: [0][570/864]	Time 0.169 (0.716)	Data 0.016 (0.597)	Loss 2.4600 (2.3958)
# Epoch: [0][600/864]	Time 0.173 (0.688)	Data 0.017 (0.568)	Loss 3.4435 (2.3820)
# Epoch: [0][630/864]	Time 0.169 (0.672)	Data 0.016 (0.550)	Loss 3.0042 (2.3770)
# Epoch: [0][660/864]	Time 0.169 (0.649)	Data 0.016 (0.526)	Loss 1.1872 (2.3617)
# Epoch: [0][690/864]	Time 0.172 (0.628)	Data 0.016 (0.504)	Loss 2.2731 (2.3569)
# Epoch: [0][720/864]	Time 0.173 (0.609)	Data 0.014 (0.484)	Loss 2.3189 (2.3488)
# Epoch: [0][750/864]	Time 0.171 (0.592)	Data 0.015 (0.465)	Loss 0.6926 (2.3435)
# Epoch: [0][780/864]	Time 0.171 (0.576)	Data 0.015 (0.448)	Loss 1.5372 (2.3339)
# Epoch: [0][810/864]	Time 0.168 (0.561)	Data 0.018 (0.432)	Loss 1.7313 (2.3399)
# Epoch: [0][840/864]	Time 0.170 (0.547)	Data 0.016 (0.417)	Loss 1.9964 (2.3444)
# begin test
#  * MAE 5.623
#  * best MAE 5.623
# epoch 1, processed 864 samples, lr 0.0000001000
# Epoch: [1][0/864]	Time 0.111 (0.111)	Data 0.020 (0.020)	Loss 3.8062 (3.8062)
# Epoch: [1][30/864]	Time 0.166 (0.166)	Data 0.014 (0.017)	Loss 1.1960 (1.9608)
# Epoch: [1][60/864]	Time 0.168 (0.167)	Data 0.019 (0.017)	Loss 3.7763 (2.0223)
# Epoch: [1][90/864]	Time 0.170 (0.168)	Data 0.019 (0.018)	Loss 1.1098 (2.0304)
# Epoch: [1][120/864]	Time 0.171 (0.168)	Data 0.014 (0.017)	Loss 1.1122 (2.1300)
# Epoch: [1][150/864]	Time 0.173 (0.169)	Data 0.015 (0.017)	Loss 1.9963 (2.2323)
# Epoch: [1][180/864]	Time 0.174 (0.170)	Data 0.017 (0.017)	Loss 3.0040 (2.2731)
# Epoch: [1][210/864]	Time 0.173 (0.170)	Data 0.015 (0.017)	Loss 2.5070 (2.3327)
# Epoch: [1][240/864]	Time 0.176 (0.171)	Data 0.014 (0.017)	Loss 2.9619 (2.3916)
# Epoch: [1][270/864]	Time 0.172 (0.171)	Data 0.014 (0.017)	Loss 2.6094 (2.3514)
# Epoch: [1][300/864]	Time 0.169 (0.171)	Data 0.014 (0.017)	Loss 2.0841 (2.3091)
# Epoch: [1][330/864]	Time 0.168 (0.171)	Data 0.017 (0.017)	Loss 3.9533 (2.3148)
# Epoch: [1][360/864]	Time 0.168 (0.171)	Data 0.015 (0.017)	Loss 2.3305 (2.3040)
# Epoch: [1][390/864]	Time 0.170 (0.171)	Data 0.015 (0.017)	Loss 1.7362 (2.3212)
# Epoch: [1][420/864]	Time 0.169 (0.170)	Data 0.019 (0.017)	Loss 0.8172 (2.3231)
# Epoch: [1][450/864]	Time 0.169 (0.170)	Data 0.015 (0.017)	Loss 2.9674 (2.2955)
# Epoch: [1][480/864]	Time 0.168 (0.170)	Data 0.018 (0.017)	Loss 1.3811 (2.3050)
# Epoch: [1][510/864]	Time 0.168 (0.170)	Data 0.017 (0.017)	Loss 2.3958 (2.3211)
# Epoch: [1][540/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 2.2718 (2.3273)
# Epoch: [1][570/864]	Time 0.168 (0.170)	Data 0.015 (0.016)	Loss 2.0741 (2.3346)
# Epoch: [1][600/864]	Time 0.171 (0.170)	Data 0.014 (0.017)	Loss 4.7125 (2.3496)
# Epoch: [1][630/864]	Time 0.171 (0.170)	Data 0.015 (0.017)	Loss 2.8819 (2.3463)
# Epoch: [1][660/864]	Time 0.171 (0.170)	Data 0.017 (0.016)	Loss 2.2265 (2.3567)
# Epoch: [1][690/864]	Time 0.172 (0.170)	Data 0.015 (0.016)	Loss 0.4765 (2.3489)
# Epoch: [1][720/864]	Time 0.172 (0.170)	Data 0.016 (0.016)	Loss 3.3521 (2.3413)
# Epoch: [1][750/864]	Time 0.172 (0.170)	Data 0.017 (0.016)	Loss 1.0988 (2.3294)
# Epoch: [1][780/864]	Time 0.169 (0.170)	Data 0.015 (0.016)	Loss 4.8840 (2.3315)
# Epoch: [1][810/864]	Time 0.171 (0.170)	Data 0.015 (0.016)	Loss 1.3648 (2.3487)
# Epoch: [1][840/864]	Time 0.170 (0.170)	Data 0.018 (0.016)	Loss 1.0257 (2.3380)
# begin test
#  * MAE 5.526
#  * best MAE 5.526
# epoch 2, processed 1728 samples, lr 0.0000001000
# Epoch: [2][0/864]	Time 0.062 (0.062)	Data 0.015 (0.015)	Loss 4.4344 (4.4344)
# Epoch: [2][30/864]	Time 0.169 (0.166)	Data 0.021 (0.017)	Loss 3.4100 (2.1831)
# Epoch: [2][60/864]	Time 0.169 (0.167)	Data 0.015 (0.017)	Loss 1.1953 (2.4317)
# Epoch: [2][90/864]	Time 0.168 (0.168)	Data 0.025 (0.017)	Loss 1.0078 (2.3074)
# Epoch: [2][120/864]	Time 0.169 (0.168)	Data 0.015 (0.017)	Loss 1.7174 (2.2254)
# Epoch: [2][150/864]	Time 0.169 (0.169)	Data 0.015 (0.017)	Loss 1.8514 (2.2657)
# Epoch: [2][180/864]	Time 0.170 (0.169)	Data 0.017 (0.017)	Loss 2.8266 (2.3798)
# Epoch: [2][210/864]	Time 0.169 (0.169)	Data 0.014 (0.017)	Loss 1.3171 (2.3613)
# Epoch: [2][240/864]	Time 0.171 (0.169)	Data 0.015 (0.017)	Loss 3.7741 (2.3665)
# Epoch: [2][270/864]	Time 0.170 (0.169)	Data 0.017 (0.016)	Loss 0.9604 (2.3791)
# Epoch: [2][300/864]	Time 0.169 (0.169)	Data 0.015 (0.016)	Loss 5.4848 (2.3425)
# Epoch: [2][330/864]	Time 0.168 (0.169)	Data 0.015 (0.016)	Loss 2.9577 (2.3249)
# Epoch: [2][360/864]	Time 0.171 (0.169)	Data 0.017 (0.016)	Loss 1.3427 (2.2915)
# Epoch: [2][390/864]	Time 0.170 (0.169)	Data 0.014 (0.016)	Loss 2.9277 (2.3035)
# Epoch: [2][420/864]	Time 0.170 (0.169)	Data 0.014 (0.016)	Loss 0.8840 (2.3068)
# Epoch: [2][450/864]	Time 0.171 (0.170)	Data 0.015 (0.016)	Loss 1.4429 (2.2968)
# Epoch: [2][480/864]	Time 0.171 (0.170)	Data 0.015 (0.016)	Loss 0.6242 (2.2814)
# Epoch: [2][510/864]	Time 0.169 (0.170)	Data 0.017 (0.016)	Loss 3.8055 (2.2734)
# Epoch: [2][540/864]	Time 0.170 (0.170)	Data 0.015 (0.016)	Loss 1.5990 (2.2872)
# Epoch: [2][570/864]	Time 0.170 (0.170)	Data 0.015 (0.016)	Loss 0.8065 (2.2761)
# Epoch: [2][600/864]	Time 0.175 (0.170)	Data 0.019 (0.016)	Loss 1.4244 (2.2990)
# Epoch: [2][630/864]	Time 0.170 (0.170)	Data 0.015 (0.016)	Loss 1.2736 (2.3070)
# Epoch: [2][660/864]	Time 0.171 (0.170)	Data 0.015 (0.016)	Loss 1.5852 (2.3199)
# Epoch: [2][690/864]	Time 0.169 (0.170)	Data 0.017 (0.016)	Loss 1.8782 (2.3440)
# Epoch: [2][720/864]	Time 0.170 (0.170)	Data 0.014 (0.016)	Loss 1.7730 (2.3282)
# Epoch: [2][750/864]	Time 0.170 (0.170)	Data 0.016 (0.016)	Loss 0.9709 (2.3338)
# Epoch: [2][780/864]	Time 0.171 (0.170)	Data 0.015 (0.016)	Loss 1.5907 (2.3348)
# Epoch: [2][810/864]	Time 0.170 (0.170)	Data 0.014 (0.016)	Loss 1.3804 (2.3449)
# Epoch: [2][840/864]	Time 0.171 (0.170)	Data 0.017 (0.016)	Loss 2.6196 (2.3283)
# begin test
#  * MAE 5.703
#  * best MAE 5.526
# epoch 3, processed 2592 samples, lr 0.0000001000
# Epoch: [3][0/864]	Time 0.080 (0.080)	Data 0.033 (0.033)	Loss 3.1341 (3.1341)
# Epoch: [3][30/864]	Time 0.169 (0.167)	Data 0.015 (0.016)	Loss 2.1073 (2.4342)
# Epoch: [3][60/864]	Time 0.171 (0.168)	Data 0.015 (0.020)	Loss 2.6289 (2.3408)
# Epoch: [3][90/864]	Time 0.169 (0.169)	Data 0.016 (0.018)	Loss 3.2396 (2.2439)
# Epoch: [3][120/864]	Time 0.172 (0.169)	Data 0.018 (0.018)	Loss 2.3188 (2.3280)
# Epoch: [3][150/864]	Time 0.170 (0.169)	Data 0.015 (0.018)	Loss 3.8449 (2.2972)
# Epoch: [3][180/864]	Time 0.169 (0.169)	Data 0.015 (0.017)	Loss 8.5610 (2.3716)
# Epoch: [3][210/864]	Time 0.169 (0.169)	Data 0.036 (0.017)	Loss 3.7007 (2.3511)
# Epoch: [3][240/864]	Time 0.170 (0.169)	Data 0.014 (0.017)	Loss 1.5316 (2.3836)
# Epoch: [3][270/864]	Time 0.170 (0.169)	Data 0.014 (0.017)	Loss 1.8292 (2.3804)
# Epoch: [3][300/864]	Time 0.170 (0.169)	Data 0.017 (0.017)	Loss 3.8471 (2.3690)
# Epoch: [3][330/864]	Time 0.170 (0.169)	Data 0.015 (0.017)	Loss 1.3367 (2.3610)
# Epoch: [3][360/864]	Time 0.172 (0.169)	Data 0.014 (0.017)	Loss 0.4227 (2.3665)
# Epoch: [3][390/864]	Time 0.170 (0.169)	Data 0.014 (0.017)	Loss 1.4131 (2.3580)
# Epoch: [3][420/864]	Time 0.171 (0.169)	Data 0.015 (0.017)	Loss 1.5867 (2.3660)
# Epoch: [3][450/864]	Time 0.168 (0.169)	Data 0.017 (0.017)	Loss 2.7517 (2.3611)
# Epoch: [3][480/864]	Time 0.170 (0.169)	Data 0.016 (0.017)	Loss 1.4301 (2.3616)
# Epoch: [3][510/864]	Time 0.168 (0.169)	Data 0.014 (0.017)	Loss 4.7052 (2.3606)
# Epoch: [3][540/864]	Time 0.169 (0.169)	Data 0.018 (0.017)	Loss 2.3640 (2.3537)
# Epoch: [3][570/864]	Time 0.170 (0.169)	Data 0.016 (0.017)	Loss 1.1847 (2.3507)
# Epoch: [3][600/864]	Time 0.169 (0.169)	Data 0.015 (0.016)	Loss 1.1582 (2.3579)
# Epoch: [3][630/864]	Time 0.169 (0.169)	Data 0.016 (0.017)	Loss 1.0788 (2.3496)
# Epoch: [3][660/864]	Time 0.172 (0.169)	Data 0.015 (0.016)	Loss 1.7356 (2.3777)
# Epoch: [3][690/864]	Time 0.170 (0.169)	Data 0.014 (0.016)	Loss 2.4548 (2.3847)
# Epoch: [3][720/864]	Time 0.170 (0.170)	Data 0.015 (0.016)	Loss 0.9656 (2.3676)
# Epoch: [3][750/864]	Time 0.170 (0.170)	Data 0.014 (0.016)	Loss 1.3147 (2.3501)
# Epoch: [3][780/864]	Time 0.171 (0.170)	Data 0.018 (0.016)	Loss 1.1927 (2.3425)
# Epoch: [3][810/864]	Time 0.170 (0.170)	Data 0.014 (0.016)	Loss 3.6436 (2.3348)
# Epoch: [3][840/864]	Time 0.169 (0.170)	Data 0.016 (0.016)	Loss 3.4404 (2.3256)
# begin test
#  * MAE 5.492
#  * best MAE 5.492
# epoch 4, processed 3456 samples, lr 0.0000001000
# Epoch: [4][0/864]	Time 0.065 (0.065)	Data 0.014 (0.014)	Loss 8.5618 (8.5618)
# Epoch: [4][30/864]	Time 0.169 (0.167)	Data 0.014 (0.018)	Loss 2.1903 (2.6373)
# Epoch: [4][60/864]	Time 0.170 (0.168)	Data 0.017 (0.018)	Loss 2.3187 (2.5638)
# Epoch: [4][90/864]	Time 0.170 (0.169)	Data 0.015 (0.019)	Loss 1.8526 (2.4409)
# Epoch: [4][120/864]	Time 0.169 (0.169)	Data 0.014 (0.018)	Loss 1.3275 (2.5569)
# Epoch: [4][150/864]	Time 0.170 (0.169)	Data 0.018 (0.018)	Loss 1.1061 (2.4392)
# Epoch: [4][180/864]	Time 0.171 (0.169)	Data 0.015 (0.018)	Loss 1.0782 (2.4289)
# Epoch: [4][210/864]	Time 0.169 (0.169)	Data 0.014 (0.017)	Loss 1.1053 (2.3887)
# Epoch: [4][240/864]	Time 0.170 (0.169)	Data 0.015 (0.018)	Loss 1.7164 (2.3763)
# Epoch: [4][270/864]	Time 0.171 (0.170)	Data 0.014 (0.018)	Loss 0.6511 (2.3578)
# Epoch: [4][300/864]	Time 0.169 (0.170)	Data 0.016 (0.018)	Loss 3.4069 (2.3993)
# Epoch: [4][330/864]	Time 0.169 (0.170)	Data 0.014 (0.017)	Loss 0.7192 (2.3948)
# Epoch: [4][360/864]	Time 0.171 (0.170)	Data 0.014 (0.017)	Loss 0.4734 (2.3542)
# Epoch: [4][390/864]	Time 0.170 (0.170)	Data 0.017 (0.017)	Loss 1.4971 (2.3389)
# Epoch: [4][420/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 2.9079 (2.3718)
# Epoch: [4][450/864]	Time 0.169 (0.170)	Data 0.014 (0.017)	Loss 1.8950 (2.3569)
# Epoch: [4][480/864]	Time 0.168 (0.170)	Data 0.018 (0.017)	Loss 1.9694 (2.3378)
# Epoch: [4][510/864]	Time 0.169 (0.170)	Data 0.015 (0.017)	Loss 3.9451 (2.3125)
# Epoch: [4][540/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 3.8673 (2.3026)
# Epoch: [4][570/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 1.6853 (2.3090)
# Epoch: [4][600/864]	Time 0.169 (0.170)	Data 0.015 (0.017)	Loss 1.2012 (2.3172)
# Epoch: [4][630/864]	Time 0.171 (0.170)	Data 0.017 (0.017)	Loss 1.1074 (2.3225)
# Epoch: [4][660/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 3.0083 (2.3337)
# Epoch: [4][690/864]	Time 0.170 (0.170)	Data 0.016 (0.017)	Loss 1.4948 (2.3399)
# Epoch: [4][720/864]	Time 0.172 (0.170)	Data 0.018 (0.017)	Loss 1.6038 (2.3510)
# Epoch: [4][750/864]	Time 0.170 (0.170)	Data 0.016 (0.017)	Loss 3.8393 (2.3385)
# Epoch: [4][780/864]	Time 0.169 (0.170)	Data 0.015 (0.017)	Loss 3.7450 (2.3259)
# Epoch: [4][810/864]	Time 0.167 (0.170)	Data 0.018 (0.017)	Loss 3.8397 (2.3305)
# Epoch: [4][840/864]	Time 0.169 (0.170)	Data 0.014 (0.017)	Loss 2.1033 (2.3266)
# begin test
#  * MAE 5.471
#  * best MAE 5.471
# epoch 5, processed 4320 samples, lr 0.0000001000
# Epoch: [5][0/864]	Time 0.074 (0.074)	Data 0.026 (0.026)	Loss 1.8779 (1.8779)
# Epoch: [5][30/864]	Time 0.169 (0.167)	Data 0.015 (0.016)	Loss 0.4214 (2.4236)
# Epoch: [5][60/864]	Time 0.162 (0.168)	Data 0.019 (0.016)	Loss 4.4982 (2.5010)
# Epoch: [5][90/864]	Time 0.170 (0.169)	Data 0.014 (0.018)	Loss 1.3780 (2.3350)
# Epoch: [5][120/864]	Time 0.170 (0.169)	Data 0.014 (0.018)	Loss 5.0658 (2.3558)
# Epoch: [5][150/864]	Time 0.170 (0.169)	Data 0.017 (0.017)	Loss 3.8291 (2.4044)
# Epoch: [5][180/864]	Time 0.170 (0.169)	Data 0.017 (0.017)	Loss 2.3027 (2.4128)
# Epoch: [5][210/864]	Time 0.169 (0.169)	Data 0.015 (0.017)	Loss 2.5007 (2.4632)
# Epoch: [5][240/864]	Time 0.174 (0.170)	Data 0.017 (0.017)	Loss 3.1317 (2.4479)
# Epoch: [5][270/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 0.8804 (2.4430)
# Epoch: [5][300/864]	Time 0.169 (0.170)	Data 0.014 (0.017)	Loss 1.3144 (2.3888)
# Epoch: [5][330/864]	Time 0.171 (0.170)	Data 0.016 (0.017)	Loss 0.4691 (2.3605)
# Epoch: [5][360/864]	Time 0.171 (0.170)	Data 0.014 (0.017)	Loss 3.4058 (2.3560)
# Epoch: [5][390/864]	Time 0.169 (0.170)	Data 0.017 (0.017)	Loss 1.5392 (2.3578)
# Epoch: [5][420/864]	Time 0.171 (0.170)	Data 0.014 (0.017)	Loss 4.8118 (2.3724)
# Epoch: [5][450/864]	Time 0.169 (0.170)	Data 0.014 (0.017)	Loss 2.0707 (2.3395)
# Epoch: [5][480/864]	Time 0.168 (0.170)	Data 0.017 (0.017)	Loss 2.1058 (2.3280)
# Epoch: [5][510/864]	Time 0.169 (0.170)	Data 0.014 (0.017)	Loss 1.2105 (2.3208)
# Epoch: [5][540/864]	Time 0.169 (0.170)	Data 0.016 (0.017)	Loss 0.6492 (2.3111)
# Epoch: [5][570/864]	Time 0.170 (0.170)	Data 0.018 (0.017)	Loss 1.8341 (2.3074)
# Epoch: [5][600/864]	Time 0.169 (0.170)	Data 0.015 (0.017)	Loss 1.7145 (2.3100)
# Epoch: [5][630/864]	Time 0.169 (0.170)	Data 0.015 (0.017)	Loss 2.9044 (2.3050)
# Epoch: [5][660/864]	Time 0.169 (0.170)	Data 0.019 (0.017)	Loss 3.1192 (2.3103)
# Epoch: [5][690/864]	Time 0.171 (0.170)	Data 0.014 (0.017)	Loss 2.9601 (2.3041)
# Epoch: [5][720/864]	Time 0.172 (0.170)	Data 0.015 (0.017)	Loss 2.0012 (2.3072)
# Epoch: [5][750/864]	Time 0.170 (0.170)	Data 0.016 (0.017)	Loss 1.1294 (2.3277)
# Epoch: [5][780/864]	Time 0.171 (0.170)	Data 0.014 (0.017)	Loss 2.8864 (2.3210)
# Epoch: [5][810/864]	Time 0.171 (0.170)	Data 0.018 (0.017)	Loss 4.4284 (2.3358)
# Epoch: [5][840/864]	Time 0.170 (0.170)	Data 0.020 (0.017)	Loss 1.4386 (2.3382)
# begin test
#  * MAE 5.456
#  * best MAE 5.456
# epoch 6, processed 5184 samples, lr 0.0000001000
# Epoch: [6][0/864]	Time 0.072 (0.072)	Data 0.025 (0.025)	Loss 2.0785 (2.0785)
# Epoch: [6][30/864]	Time 0.169 (0.167)	Data 0.015 (0.019)	Loss 1.9710 (2.3736)
# Epoch: [6][60/864]	Time 0.168 (0.168)	Data 0.015 (0.017)	Loss 3.0055 (2.6738)
# Epoch: [6][90/864]	Time 0.173 (0.169)	Data 0.017 (0.017)	Loss 1.4938 (2.4974)
# Epoch: [6][120/864]	Time 0.170 (0.169)	Data 0.015 (0.019)	Loss 2.9599 (2.4514)
# Epoch: [6][150/864]	Time 0.169 (0.169)	Data 0.016 (0.018)	Loss 3.2997 (2.4326)
# Epoch: [6][180/864]	Time 0.169 (0.170)	Data 0.021 (0.018)	Loss 2.3593 (2.3619)
# Epoch: [6][210/864]	Time 0.170 (0.170)	Data 0.014 (0.018)	Loss 1.0001 (2.3550)
# Epoch: [6][240/864]	Time 0.171 (0.170)	Data 0.016 (0.018)	Loss 1.1899 (2.3312)
# Epoch: [6][270/864]	Time 0.172 (0.170)	Data 0.018 (0.018)	Loss 1.4974 (2.3244)
# Epoch: [6][300/864]	Time 0.169 (0.170)	Data 0.013 (0.017)	Loss 1.3732 (2.3288)
# Epoch: [6][330/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 2.0817 (2.3241)
# Epoch: [6][360/864]	Time 0.169 (0.170)	Data 0.014 (0.017)	Loss 1.5374 (2.3583)
# Epoch: [6][390/864]	Time 0.171 (0.170)	Data 0.014 (0.017)	Loss 6.1977 (2.3697)
# Epoch: [6][420/864]	Time 0.170 (0.170)	Data 0.018 (0.017)	Loss 1.7137 (2.3732)
# Epoch: [6][450/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 2.1491 (2.3719)
# Epoch: [6][480/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 1.0107 (2.3658)
# Epoch: [6][510/864]	Time 0.171 (0.170)	Data 0.020 (0.017)	Loss 1.9313 (2.3554)
# Epoch: [6][540/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 3.9433 (2.3214)
# Epoch: [6][570/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 1.5626 (2.3054)
# Epoch: [6][600/864]	Time 0.170 (0.170)	Data 0.020 (0.017)	Loss 1.4967 (2.3145)
# Epoch: [6][630/864]	Time 0.171 (0.170)	Data 0.016 (0.017)	Loss 2.3508 (2.3128)
# Epoch: [6][660/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 1.5966 (2.2984)
# Epoch: [6][690/864]	Time 0.169 (0.170)	Data 0.014 (0.017)	Loss 0.4255 (2.3057)
# Epoch: [6][720/864]	Time 0.170 (0.170)	Data 0.016 (0.017)	Loss 4.6977 (2.3156)
# Epoch: [6][750/864]	Time 0.171 (0.170)	Data 0.017 (0.017)	Loss 2.0711 (2.3245)
# Epoch: [6][780/864]	Time 0.171 (0.170)	Data 0.015 (0.017)	Loss 1.7679 (2.3356)
# Epoch: [6][810/864]	Time 0.170 (0.170)	Data 0.018 (0.017)	Loss 1.4205 (2.3300)
# Epoch: [6][840/864]	Time 0.170 (0.170)	Data 0.017 (0.017)	Loss 1.2292 (2.3281)
# begin test
#  * MAE 5.444
#  * best MAE 5.444
# epoch 7, processed 6048 samples, lr 0.0000001000
# Epoch: [7][0/864]	Time 0.066 (0.066)	Data 0.015 (0.015)	Loss 1.7678 (1.7678)
# Epoch: [7][30/864]	Time 0.171 (0.166)	Data 0.036 (0.017)	Loss 1.5305 (2.4454)
# Epoch: [7][60/864]	Time 0.166 (0.168)	Data 0.025 (0.017)	Loss 1.3586 (2.2958)
# Epoch: [7][90/864]	Time 0.173 (0.168)	Data 0.015 (0.017)	Loss 1.4925 (2.2067)
# Epoch: [7][120/864]	Time 0.170 (0.169)	Data 0.018 (0.018)	Loss 1.8740 (2.2260)
# Epoch: [7][150/864]	Time 0.169 (0.169)	Data 0.016 (0.018)	Loss 1.8904 (2.1960)
# Epoch: [7][180/864]	Time 0.170 (0.169)	Data 0.015 (0.018)	Loss 2.2985 (2.2587)
# Epoch: [7][210/864]	Time 0.170 (0.169)	Data 0.015 (0.018)	Loss 1.0118 (2.2975)
# Epoch: [7][240/864]	Time 0.170 (0.169)	Data 0.015 (0.018)	Loss 2.3260 (2.3087)
# Epoch: [7][270/864]	Time 0.171 (0.170)	Data 0.017 (0.017)	Loss 4.4292 (2.2972)
# Epoch: [7][300/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 1.3539 (2.2722)
# Epoch: [7][330/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 2.0798 (2.2701)
# Epoch: [7][360/864]	Time 0.172 (0.170)	Data 0.018 (0.017)	Loss 3.8526 (2.2429)
# Epoch: [7][390/864]	Time 0.169 (0.170)	Data 0.041 (0.017)	Loss 3.2308 (2.2371)
# Epoch: [7][420/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 2.2996 (2.2418)
# Epoch: [7][450/864]	Time 0.170 (0.170)	Data 0.019 (0.017)	Loss 4.6319 (2.2558)
# Epoch: [7][480/864]	Time 0.171 (0.170)	Data 0.016 (0.017)	Loss 3.6754 (2.2730)
# Epoch: [7][510/864]	Time 0.169 (0.170)	Data 0.015 (0.017)	Loss 2.5664 (2.2648)
# Epoch: [7][540/864]	Time 0.167 (0.170)	Data 0.015 (0.017)	Loss 8.5521 (2.2833)
# Epoch: [7][570/864]	Time 0.166 (0.170)	Data 0.041 (0.017)	Loss 1.6912 (2.2670)
# Epoch: [7][600/864]	Time 0.168 (0.170)	Data 0.017 (0.017)	Loss 1.8472 (2.2513)
# Epoch: [7][630/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 1.1890 (2.2748)
# Epoch: [7][660/864]	Time 0.169 (0.170)	Data 0.014 (0.017)	Loss 2.3458 (2.2935)
# Epoch: [7][690/864]	Time 0.170 (0.170)	Data 0.018 (0.017)	Loss 0.3876 (2.3028)
# Epoch: [7][720/864]	Time 0.169 (0.170)	Data 0.014 (0.017)	Loss 3.7918 (2.2997)
# Epoch: [7][750/864]	Time 0.170 (0.170)	Data 0.016 (0.017)	Loss 1.6226 (2.3019)
# Epoch: [7][780/864]	Time 0.173 (0.170)	Data 0.019 (0.017)	Loss 2.0973 (2.3095)
# Epoch: [7][810/864]	Time 0.170 (0.170)	Data 0.016 (0.017)	Loss 3.6933 (2.3170)
# Epoch: [7][840/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 2.4604 (2.3211)
# begin test
#  * MAE 5.578
#  * best MAE 5.444
# epoch 8, processed 6912 samples, lr 0.0000001000
# Epoch: [8][0/864]	Time 0.062 (0.062)	Data 0.015 (0.015)	Loss 1.9629 (1.9629)
# Epoch: [8][30/864]	Time 0.169 (0.178)	Data 0.016 (0.031)	Loss 3.6918 (2.3055)
# Epoch: [8][60/864]	Time 0.183 (0.174)	Data 0.051 (0.025)	Loss 1.1900 (2.2693)
# Epoch: [8][90/864]	Time 0.170 (0.173)	Data 0.014 (0.023)	Loss 1.3258 (2.3651)
# Epoch: [8][120/864]	Time 0.169 (0.172)	Data 0.015 (0.021)	Loss 1.3542 (2.4412)
# Epoch: [8][150/864]	Time 0.170 (0.172)	Data 0.015 (0.020)	Loss 1.1522 (2.4214)
# Epoch: [8][180/864]	Time 0.171 (0.171)	Data 0.015 (0.020)	Loss 2.3862 (2.4405)
# Epoch: [8][210/864]	Time 0.169 (0.171)	Data 0.017 (0.019)	Loss 2.2091 (2.4485)
# Epoch: [8][240/864]	Time 0.170 (0.171)	Data 0.015 (0.019)	Loss 1.3190 (2.4357)
# Epoch: [8][270/864]	Time 0.169 (0.171)	Data 0.015 (0.019)	Loss 1.5243 (2.4460)
# Epoch: [8][300/864]	Time 0.171 (0.171)	Data 0.018 (0.018)	Loss 8.5528 (2.4247)
# Epoch: [8][330/864]	Time 0.169 (0.171)	Data 0.014 (0.018)	Loss 1.1526 (2.4023)
# Epoch: [8][360/864]	Time 0.170 (0.171)	Data 0.018 (0.018)	Loss 3.0809 (2.3813)
# Epoch: [8][390/864]	Time 0.170 (0.170)	Data 0.016 (0.018)	Loss 3.6734 (2.3923)
# Epoch: [8][420/864]	Time 0.171 (0.170)	Data 0.016 (0.018)	Loss 2.3542 (2.3493)
# Epoch: [8][450/864]	Time 0.168 (0.170)	Data 0.017 (0.018)	Loss 3.1233 (2.3615)
# Epoch: [8][480/864]	Time 0.169 (0.170)	Data 0.015 (0.018)	Loss 3.0220 (2.3515)
# Epoch: [8][510/864]	Time 0.171 (0.170)	Data 0.015 (0.018)	Loss 0.7133 (2.3199)
# Epoch: [8][540/864]	Time 0.170 (0.170)	Data 0.017 (0.018)	Loss 1.7653 (2.3245)
# Epoch: [8][570/864]	Time 0.169 (0.170)	Data 0.015 (0.018)	Loss 1.3518 (2.3150)
# Epoch: [8][600/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 2.6101 (2.3164)
# Epoch: [8][630/864]	Time 0.170 (0.170)	Data 0.018 (0.018)	Loss 1.8403 (2.3159)
# Epoch: [8][660/864]	Time 0.169 (0.170)	Data 0.014 (0.017)	Loss 1.6895 (2.3063)
# Epoch: [8][690/864]	Time 0.171 (0.170)	Data 0.015 (0.017)	Loss 1.5793 (2.3141)
# Epoch: [8][720/864]	Time 0.169 (0.170)	Data 0.015 (0.017)	Loss 3.0545 (2.3105)
# Epoch: [8][750/864]	Time 0.171 (0.170)	Data 0.015 (0.017)	Loss 1.8835 (2.2930)
# Epoch: [8][780/864]	Time 0.169 (0.170)	Data 0.018 (0.017)	Loss 0.7972 (2.3082)
# Epoch: [8][810/864]	Time 0.171 (0.170)	Data 0.014 (0.017)	Loss 4.9685 (2.3273)
# Epoch: [8][840/864]	Time 0.172 (0.170)	Data 0.015 (0.017)	Loss 1.4185 (2.3229)
# begin test
#  * MAE 5.582
#  * best MAE 5.444
# epoch 9, processed 7776 samples, lr 0.0000001000
# Epoch: [9][0/864]	Time 0.065 (0.065)	Data 0.019 (0.019)	Loss 1.6765 (1.6765)
# Epoch: [9][30/864]	Time 0.169 (0.167)	Data 0.015 (0.016)	Loss 2.3401 (2.3790)
# Epoch: [9][60/864]	Time 0.170 (0.168)	Data 0.017 (0.016)	Loss 1.4041 (2.2534)
# Epoch: [9][90/864]	Time 0.170 (0.169)	Data 0.014 (0.019)	Loss 3.1965 (2.2841)
# Epoch: [9][120/864]	Time 0.169 (0.169)	Data 0.015 (0.018)	Loss 1.9278 (2.4840)
# Epoch: [9][150/864]	Time 0.169 (0.169)	Data 0.018 (0.018)	Loss 6.0873 (2.4845)
# Epoch: [9][180/864]	Time 0.168 (0.169)	Data 0.015 (0.018)	Loss 5.4751 (2.4611)
# Epoch: [9][210/864]	Time 0.169 (0.169)	Data 0.014 (0.018)	Loss 2.9978 (2.4236)
# Epoch: [9][240/864]	Time 0.168 (0.169)	Data 0.050 (0.018)	Loss 1.5578 (2.3629)
# Epoch: [9][270/864]	Time 0.169 (0.169)	Data 0.015 (0.017)	Loss 1.3552 (2.3453)
# Epoch: [9][300/864]	Time 0.170 (0.169)	Data 0.014 (0.017)	Loss 5.0638 (2.3090)
# Epoch: [9][330/864]	Time 0.168 (0.170)	Data 0.017 (0.017)	Loss 3.6299 (2.2798)
# Epoch: [9][360/864]	Time 0.169 (0.170)	Data 0.014 (0.017)	Loss 3.6874 (2.3112)
# Epoch: [9][390/864]	Time 0.169 (0.170)	Data 0.020 (0.017)	Loss 4.9642 (2.3204)
# Epoch: [9][420/864]	Time 0.169 (0.170)	Data 0.045 (0.017)	Loss 2.3244 (2.3270)
# Epoch: [9][450/864]	Time 0.168 (0.170)	Data 0.015 (0.017)	Loss 1.4526 (2.3615)
# Epoch: [9][480/864]	Time 0.170 (0.170)	Data 0.017 (0.017)	Loss 0.8259 (2.3817)
# Epoch: [9][510/864]	Time 0.169 (0.170)	Data 0.015 (0.017)	Loss 1.1616 (2.3653)
# Epoch: [9][540/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 1.2543 (2.3477)
# Epoch: [9][570/864]	Time 0.169 (0.170)	Data 0.018 (0.017)	Loss 1.4028 (2.3627)
# Epoch: [9][600/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 1.9744 (2.3493)
# Epoch: [9][630/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 1.4177 (2.3451)
# Epoch: [9][660/864]	Time 0.167 (0.170)	Data 0.019 (0.017)	Loss 1.8847 (2.3487)
# Epoch: [9][690/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 2.6848 (2.3417)
# Epoch: [9][720/864]	Time 0.173 (0.170)	Data 0.019 (0.017)	Loss 1.4003 (2.3289)
# Epoch: [9][750/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 1.2487 (2.3246)
# Epoch: [9][780/864]	Time 0.169 (0.170)	Data 0.013 (0.017)	Loss 3.9339 (2.3173)
# Epoch: [9][810/864]	Time 0.171 (0.170)	Data 0.017 (0.017)	Loss 1.4916 (2.3320)
# Epoch: [9][840/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 3.1045 (2.3214)
# begin test
#  * MAE 5.467
#  * best MAE 5.444
# epoch 10, processed 8640 samples, lr 0.0000001000
# Epoch: [10][0/864]	Time 0.064 (0.064)	Data 0.017 (0.017)	Loss 1.9266 (1.9266)
# Epoch: [10][30/864]	Time 0.169 (0.171)	Data 0.015 (0.025)	Loss 3.9295 (2.3871)
# Epoch: [10][60/864]	Time 0.170 (0.171)	Data 0.021 (0.021)	Loss 1.6750 (2.2670)
# Epoch: [10][90/864]	Time 0.170 (0.170)	Data 0.018 (0.020)	Loss 2.0980 (2.2768)
# Epoch: [10][120/864]	Time 0.170 (0.170)	Data 0.015 (0.020)	Loss 0.4671 (2.3701)
# Epoch: [10][150/864]	Time 0.170 (0.170)	Data 0.015 (0.019)	Loss 8.5451 (2.4266)
# Epoch: [10][180/864]	Time 0.169 (0.170)	Data 0.025 (0.019)	Loss 4.4859 (2.4403)
# Epoch: [10][210/864]	Time 0.171 (0.170)	Data 0.015 (0.018)	Loss 2.8958 (2.3876)
# Epoch: [10][240/864]	Time 0.171 (0.170)	Data 0.016 (0.018)	Loss 3.0114 (2.3448)
# Epoch: [10][270/864]	Time 0.171 (0.170)	Data 0.014 (0.018)	Loss 1.2437 (2.3506)
# Epoch: [10][300/864]	Time 0.169 (0.170)	Data 0.014 (0.018)	Loss 1.1476 (2.3589)
# Epoch: [10][330/864]	Time 0.169 (0.170)	Data 0.018 (0.018)	Loss 1.7069 (2.3511)
# Epoch: [10][360/864]	Time 0.170 (0.170)	Data 0.015 (0.018)	Loss 2.2927 (2.3546)
# Epoch: [10][390/864]	Time 0.169 (0.170)	Data 0.015 (0.017)	Loss 1.0961 (2.3471)
# Epoch: [10][420/864]	Time 0.169 (0.170)	Data 0.017 (0.017)	Loss 3.7367 (2.3385)
# Epoch: [10][450/864]	Time 0.171 (0.170)	Data 0.016 (0.017)	Loss 3.9304 (2.3436)
# Epoch: [10][480/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 1.4154 (2.3865)
# Epoch: [10][510/864]	Time 0.171 (0.170)	Data 0.018 (0.017)	Loss 1.1850 (2.3641)
# Epoch: [10][540/864]	Time 0.169 (0.170)	Data 0.014 (0.017)	Loss 1.3139 (2.3644)
# Epoch: [10][570/864]	Time 0.168 (0.170)	Data 0.015 (0.017)	Loss 0.7127 (2.3648)
# Epoch: [10][600/864]	Time 0.168 (0.170)	Data 0.016 (0.017)	Loss 0.6985 (2.3478)
# Epoch: [10][630/864]	Time 0.169 (0.170)	Data 0.014 (0.017)	Loss 1.3492 (2.3469)
# Epoch: [10][660/864]	Time 0.170 (0.170)	Data 0.018 (0.017)	Loss 0.6858 (2.3366)
# Epoch: [10][690/864]	Time 0.169 (0.170)	Data 0.016 (0.017)	Loss 3.3603 (2.3650)
# Epoch: [10][720/864]	Time 0.168 (0.170)	Data 0.016 (0.017)	Loss 4.5238 (2.3537)
# Epoch: [10][750/864]	Time 0.170 (0.170)	Data 0.018 (0.017)	Loss 0.6271 (2.3484)
# Epoch: [10][780/864]	Time 0.168 (0.170)	Data 0.016 (0.017)	Loss 1.0958 (2.3486)
# Epoch: [10][810/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 0.9479 (2.3400)
# Epoch: [10][840/864]	Time 0.171 (0.170)	Data 0.018 (0.017)	Loss 2.3359 (2.3300)
# begin test
#  * MAE 5.432
#  * best MAE 5.432
# epoch 11, processed 9504 samples, lr 0.0000001000
# Epoch: [11][0/864]	Time 0.060 (0.060)	Data 0.014 (0.014)	Loss 4.3530 (4.3530)
# Epoch: [11][30/864]	Time 0.171 (0.167)	Data 0.018 (0.018)	Loss 1.3523 (2.1877)
# Epoch: [11][60/864]	Time 0.171 (0.168)	Data 0.014 (0.017)	Loss 2.3181 (2.3571)
# Epoch: [11][90/864]	Time 0.171 (0.169)	Data 0.014 (0.017)	Loss 2.2978 (2.2964)
# Epoch: [11][120/864]	Time 0.170 (0.169)	Data 0.039 (0.018)	Loss 3.1135 (2.2478)
# Epoch: [11][150/864]	Time 0.170 (0.169)	Data 0.016 (0.018)	Loss 3.1131 (2.2792)
# Epoch: [11][180/864]	Time 0.171 (0.170)	Data 0.017 (0.017)	Loss 3.5120 (2.2604)
# Epoch: [11][210/864]	Time 0.170 (0.170)	Data 0.015 (0.018)	Loss 1.5192 (2.3131)
# Epoch: [11][240/864]	Time 0.170 (0.170)	Data 0.016 (0.017)	Loss 1.4131 (2.3432)
# Epoch: [11][270/864]	Time 0.170 (0.170)	Data 0.018 (0.017)	Loss 1.8660 (2.3627)
# Epoch: [11][300/864]	Time 0.169 (0.170)	Data 0.014 (0.017)	Loss 4.7938 (2.3404)
# Epoch: [11][330/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 1.9249 (2.3171)
# Epoch: [11][360/864]	Time 0.168 (0.170)	Data 0.024 (0.017)	Loss 1.2173 (2.3163)
# Epoch: [11][390/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 3.7538 (2.3280)
# Epoch: [11][420/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 2.0887 (2.3223)
# Epoch: [11][450/864]	Time 0.168 (0.170)	Data 0.015 (0.017)	Loss 1.8107 (2.3237)
# Epoch: [11][480/864]	Time 0.171 (0.170)	Data 0.044 (0.017)	Loss 3.2847 (2.3175)
# Epoch: [11][510/864]	Time 0.169 (0.170)	Data 0.017 (0.017)	Loss 3.3891 (2.3137)
# Epoch: [11][540/864]	Time 0.168 (0.170)	Data 0.015 (0.017)	Loss 1.1567 (2.3116)
# Epoch: [11][570/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 3.0488 (2.3193)
# Epoch: [11][600/864]	Time 0.170 (0.170)	Data 0.019 (0.017)	Loss 3.6853 (2.3078)
# Epoch: [11][630/864]	Time 0.171 (0.170)	Data 0.015 (0.017)	Loss 3.1919 (2.2969)
# Epoch: [11][660/864]	Time 0.169 (0.170)	Data 0.043 (0.017)	Loss 4.4844 (2.3145)
# Epoch: [11][690/864]	Time 0.169 (0.170)	Data 0.018 (0.017)	Loss 2.0682 (2.3092)
# Epoch: [11][720/864]	Time 0.169 (0.170)	Data 0.016 (0.017)	Loss 3.0128 (2.3401)
# Epoch: [11][750/864]	Time 0.169 (0.170)	Data 0.015 (0.017)	Loss 1.3584 (2.3152)
# Epoch: [11][780/864]	Time 0.171 (0.170)	Data 0.014 (0.017)	Loss 1.9591 (2.3213)
# Epoch: [11][810/864]	Time 0.168 (0.170)	Data 0.014 (0.017)	Loss 2.8641 (2.3176)
# Epoch: [11][840/864]	Time 0.172 (0.170)	Data 0.017 (0.017)	Loss 6.6356 (2.3232)
# begin test
#  * MAE 5.595
#  * best MAE 5.432
# epoch 12, processed 10368 samples, lr 0.0000001000
# Epoch: [12][0/864]	Time 0.078 (0.078)	Data 0.031 (0.031)	Loss 1.8356 (1.8356)
# Epoch: [12][30/864]	Time 0.170 (0.167)	Data 0.014 (0.016)	Loss 3.0123 (2.5762)
# Epoch: [12][60/864]	Time 0.170 (0.168)	Data 0.015 (0.017)	Loss 2.3781 (2.4691)
# Epoch: [12][90/864]	Time 0.168 (0.169)	Data 0.015 (0.017)	Loss 1.8420 (2.4480)
# Epoch: [12][120/864]	Time 0.170 (0.169)	Data 0.016 (0.017)	Loss 0.9139 (2.4882)
# Epoch: [12][150/864]	Time 0.168 (0.169)	Data 0.014 (0.017)	Loss 3.7515 (2.4836)
# Epoch: [12][180/864]	Time 0.170 (0.169)	Data 0.014 (0.017)	Loss 1.8743 (2.3865)
# Epoch: [12][210/864]	Time 0.167 (0.169)	Data 0.021 (0.017)	Loss 3.8267 (2.3509)
# Epoch: [12][240/864]	Time 0.170 (0.169)	Data 0.015 (0.017)	Loss 3.9258 (2.3736)
# Epoch: [12][270/864]	Time 0.170 (0.169)	Data 0.014 (0.017)	Loss 1.8108 (2.3521)
# Epoch: [12][300/864]	Time 0.169 (0.169)	Data 0.018 (0.017)	Loss 3.8611 (2.3550)
# Epoch: [12][330/864]	Time 0.169 (0.169)	Data 0.015 (0.017)	Loss 1.0837 (2.3019)
# Epoch: [12][360/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 1.7581 (2.2954)
# Epoch: [12][390/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 3.0096 (2.2800)
# Epoch: [12][420/864]	Time 0.169 (0.170)	Data 0.015 (0.017)	Loss 0.4614 (2.2673)
# Epoch: [12][450/864]	Time 0.169 (0.170)	Data 0.020 (0.017)	Loss 2.1268 (2.2567)
# Epoch: [12][480/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 2.4857 (2.2565)
# Epoch: [12][510/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 4.9606 (2.2623)
# Epoch: [12][540/864]	Time 0.170 (0.170)	Data 0.017 (0.017)	Loss 3.8080 (2.2758)
# Epoch: [12][570/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 2.2007 (2.2974)
# Epoch: [12][600/864]	Time 0.169 (0.170)	Data 0.015 (0.017)	Loss 4.1108 (2.2954)
# Epoch: [12][630/864]	Time 0.168 (0.170)	Data 0.018 (0.017)	Loss 3.7748 (2.3233)
# Epoch: [12][660/864]	Time 0.166 (0.170)	Data 0.018 (0.017)	Loss 2.6417 (2.3022)
# Epoch: [12][690/864]	Time 0.169 (0.170)	Data 0.014 (0.017)	Loss 0.7994 (2.2891)
# Epoch: [12][720/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 1.3925 (2.2827)
# Epoch: [12][750/864]	Time 0.169 (0.170)	Data 0.016 (0.017)	Loss 2.5568 (2.2928)
# Epoch: [12][780/864]	Time 0.171 (0.170)	Data 0.017 (0.017)	Loss 2.6156 (2.2848)
# Epoch: [12][810/864]	Time 0.169 (0.170)	Data 0.014 (0.017)	Loss 3.0993 (2.2999)
# Epoch: [12][840/864]	Time 0.167 (0.170)	Data 0.014 (0.017)	Loss 1.8767 (2.3119)
# begin test
#  * MAE 5.662
#  * best MAE 5.432
# epoch 13, processed 11232 samples, lr 0.0000001000
# Epoch: [13][0/864]	Time 0.088 (0.088)	Data 0.042 (0.042)	Loss 1.4861 (1.4861)
# Epoch: [13][30/864]	Time 0.171 (0.168)	Data 0.016 (0.020)	Loss 2.4386 (2.5642)
# Epoch: [13][60/864]	Time 0.169 (0.169)	Data 0.017 (0.018)	Loss 4.6913 (2.5479)
# Epoch: [13][90/864]	Time 0.170 (0.169)	Data 0.014 (0.019)	Loss 3.4183 (2.3588)
# Epoch: [13][120/864]	Time 0.168 (0.169)	Data 0.015 (0.018)	Loss 1.4512 (2.2454)
# Epoch: [13][150/864]	Time 0.170 (0.170)	Data 0.017 (0.018)	Loss 2.9128 (2.2099)
# Epoch: [13][180/864]	Time 0.170 (0.170)	Data 0.016 (0.018)	Loss 1.7564 (2.2598)
# Epoch: [13][210/864]	Time 0.172 (0.170)	Data 0.015 (0.017)	Loss 1.3553 (2.2427)
# Epoch: [13][240/864]	Time 0.170 (0.170)	Data 0.020 (0.018)	Loss 1.8616 (2.2716)
# Epoch: [13][270/864]	Time 0.169 (0.170)	Data 0.016 (0.017)	Loss 1.3446 (2.2784)
# Epoch: [13][300/864]	Time 0.169 (0.170)	Data 0.015 (0.017)	Loss 1.3161 (2.2560)
# Epoch: [13][330/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 1.1816 (2.2436)
# Epoch: [13][360/864]	Time 0.169 (0.170)	Data 0.014 (0.017)	Loss 2.8895 (2.2394)
# Epoch: [13][390/864]	Time 0.170 (0.170)	Data 0.017 (0.017)	Loss 3.9261 (2.2669)
# Epoch: [13][420/864]	Time 0.167 (0.170)	Data 0.014 (0.017)	Loss 2.4325 (2.2470)
# Epoch: [13][450/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 2.4816 (2.2377)
# Epoch: [13][480/864]	Time 0.171 (0.170)	Data 0.017 (0.017)	Loss 3.1150 (2.2341)
# Epoch: [13][510/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 1.1795 (2.2646)
# Epoch: [13][540/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 2.6007 (2.3140)
# Epoch: [13][570/864]	Time 0.169 (0.170)	Data 0.018 (0.017)	Loss 1.2178 (2.3081)
# Epoch: [13][600/864]	Time 0.169 (0.170)	Data 0.014 (0.017)	Loss 1.6978 (2.2955)
# Epoch: [13][630/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 3.9176 (2.2926)
# Epoch: [13][660/864]	Time 0.168 (0.170)	Data 0.014 (0.017)	Loss 3.0115 (2.2981)
# Epoch: [13][690/864]	Time 0.171 (0.170)	Data 0.016 (0.017)	Loss 2.2017 (2.3140)
# Epoch: [13][720/864]	Time 0.170 (0.170)	Data 0.017 (0.017)	Loss 0.9663 (2.3281)
# Epoch: [13][750/864]	Time 0.169 (0.170)	Data 0.015 (0.017)	Loss 1.2488 (2.3127)
# Epoch: [13][780/864]	Time 0.169 (0.170)	Data 0.015 (0.017)	Loss 1.1443 (2.3218)
# Epoch: [13][810/864]	Time 0.169 (0.170)	Data 0.019 (0.017)	Loss 2.7335 (2.3094)
# Epoch: [13][840/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 3.8558 (2.3110)
# begin test
#  * MAE 5.354
#  * best MAE 5.354
# epoch 14, processed 12096 samples, lr 0.0000001000
# Epoch: [14][0/864]	Time 0.070 (0.070)	Data 0.021 (0.021)	Loss 0.4587 (0.4587)
# Epoch: [14][30/864]	Time 0.168 (0.166)	Data 0.015 (0.017)	Loss 4.8550 (2.0503)
# Epoch: [14][60/864]	Time 0.171 (0.168)	Data 0.014 (0.016)	Loss 2.0551 (2.2163)
# Epoch: [14][90/864]	Time 0.182 (0.169)	Data 0.036 (0.018)	Loss 4.5051 (2.5134)
# Epoch: [14][120/864]	Time 0.170 (0.169)	Data 0.015 (0.017)	Loss 1.1117 (2.4483)
# Epoch: [14][150/864]	Time 0.171 (0.169)	Data 0.016 (0.017)	Loss 2.2932 (2.4106)
# Epoch: [14][180/864]	Time 0.169 (0.169)	Data 0.015 (0.017)	Loss 2.2470 (2.3736)
# Epoch: [14][210/864]	Time 0.171 (0.170)	Data 0.015 (0.017)	Loss 0.6198 (2.3679)
# Epoch: [14][240/864]	Time 0.170 (0.170)	Data 0.017 (0.017)	Loss 1.8722 (2.3242)
# Epoch: [14][270/864]	Time 0.171 (0.170)	Data 0.014 (0.017)	Loss 1.8333 (2.2827)
# Epoch: [14][300/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 4.6069 (2.3227)
# Epoch: [14][330/864]	Time 0.170 (0.170)	Data 0.017 (0.017)	Loss 1.9199 (2.3203)
# Epoch: [14][360/864]	Time 0.168 (0.170)	Data 0.015 (0.017)	Loss 3.0371 (2.3262)
# Epoch: [14][390/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 1.5655 (2.3387)
# Epoch: [14][420/864]	Time 0.170 (0.170)	Data 0.026 (0.017)	Loss 1.9471 (2.3471)
# Epoch: [14][450/864]	Time 0.169 (0.170)	Data 0.015 (0.017)	Loss 2.9878 (2.3105)
# Epoch: [14][480/864]	Time 0.169 (0.170)	Data 0.017 (0.017)	Loss 3.3682 (2.2993)
# Epoch: [14][510/864]	Time 0.169 (0.170)	Data 0.014 (0.017)	Loss 2.5873 (2.2999)
# Epoch: [14][540/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 2.4130 (2.2989)
# Epoch: [14][570/864]	Time 0.169 (0.170)	Data 0.017 (0.017)	Loss 1.4107 (2.3257)
# Epoch: [14][600/864]	Time 0.169 (0.170)	Data 0.014 (0.017)	Loss 1.4154 (2.3112)
# Epoch: [14][630/864]	Time 0.170 (0.170)	Data 0.017 (0.017)	Loss 1.2637 (2.2921)
# Epoch: [14][660/864]	Time 0.168 (0.170)	Data 0.017 (0.017)	Loss 3.8139 (2.2825)
# Epoch: [14][690/864]	Time 0.169 (0.170)	Data 0.015 (0.017)	Loss 4.6917 (2.2911)
# Epoch: [14][720/864]	Time 0.170 (0.170)	Data 0.016 (0.017)	Loss 3.0037 (2.3033)
# Epoch: [14][750/864]	Time 0.170 (0.170)	Data 0.019 (0.017)	Loss 0.9378 (2.2918)
# Epoch: [14][780/864]	Time 0.170 (0.170)	Data 0.016 (0.017)	Loss 2.9750 (2.2982)
# Epoch: [14][810/864]	Time 0.171 (0.170)	Data 0.015 (0.017)	Loss 1.2123 (2.3031)
# Epoch: [14][840/864]	Time 0.169 (0.170)	Data 0.014 (0.017)	Loss 1.8311 (2.2992)
# begin test
#  * MAE 5.412
#  * best MAE 5.354
# epoch 15, processed 12960 samples, lr 0.0000001000
# Epoch: [15][0/864]	Time 0.111 (0.111)	Data 0.062 (0.062)	Loss 3.8277 (3.8277)
# Epoch: [15][30/864]	Time 0.171 (0.168)	Data 0.018 (0.019)	Loss 3.9113 (2.5695)
# Epoch: [15][60/864]	Time 0.170 (0.169)	Data 0.014 (0.018)	Loss 2.0604 (2.5571)
# Epoch: [15][90/864]	Time 0.170 (0.169)	Data 0.014 (0.017)	Loss 0.9511 (2.5373)
# Epoch: [15][120/864]	Time 0.171 (0.169)	Data 0.015 (0.018)	Loss 3.0334 (2.3970)
# Epoch: [15][150/864]	Time 0.168 (0.169)	Data 0.015 (0.017)	Loss 2.3074 (2.3308)
# Epoch: [15][180/864]	Time 0.170 (0.170)	Data 0.017 (0.017)	Loss 3.9163 (2.3524)
# Epoch: [15][210/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 3.0060 (2.3381)
# Epoch: [15][240/864]	Time 0.169 (0.170)	Data 0.015 (0.017)	Loss 8.3805 (2.3604)
# Epoch: [15][270/864]	Time 0.170 (0.170)	Data 0.021 (0.017)	Loss 1.6563 (2.3657)
# Epoch: [15][300/864]	Time 0.171 (0.170)	Data 0.015 (0.017)	Loss 2.0854 (2.3375)
# Epoch: [15][330/864]	Time 0.169 (0.170)	Data 0.015 (0.017)	Loss 1.8631 (2.3220)
# Epoch: [15][360/864]	Time 0.170 (0.170)	Data 0.018 (0.017)	Loss 3.0899 (2.3117)
# Epoch: [15][390/864]	Time 0.169 (0.170)	Data 0.014 (0.017)	Loss 1.0536 (2.3223)
# Epoch: [15][420/864]	Time 0.171 (0.170)	Data 0.014 (0.017)	Loss 0.6891 (2.3530)
# Epoch: [15][450/864]	Time 0.169 (0.170)	Data 0.014 (0.017)	Loss 2.1483 (2.3552)
# Epoch: [15][480/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 1.8699 (2.3623)
# Epoch: [15][510/864]	Time 0.170 (0.170)	Data 0.017 (0.017)	Loss 4.5033 (2.3518)
# Epoch: [15][540/864]	Time 0.169 (0.170)	Data 0.015 (0.017)	Loss 1.8547 (2.3459)
# Epoch: [15][570/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 1.2522 (2.3450)
# Epoch: [15][600/864]	Time 0.169 (0.170)	Data 0.018 (0.017)	Loss 2.0605 (2.3368)
# Epoch: [15][630/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 1.8544 (2.3173)
# Epoch: [15][660/864]	Time 0.168 (0.170)	Data 0.014 (0.017)	Loss 1.2459 (2.3349)
# Epoch: [15][690/864]	Time 0.174 (0.170)	Data 0.019 (0.017)	Loss 4.6841 (2.3484)
# Epoch: [15][720/864]	Time 0.168 (0.170)	Data 0.014 (0.017)	Loss 1.3844 (2.3529)
# Epoch: [15][750/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 1.6591 (2.3474)
# Epoch: [15][780/864]	Time 0.169 (0.170)	Data 0.015 (0.017)	Loss 3.0313 (2.3387)
# Epoch: [15][810/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 1.5442 (2.3203)
# Epoch: [15][840/864]	Time 0.172 (0.170)	Data 0.018 (0.017)	Loss 3.7937 (2.3143)
# begin test
#  * MAE 5.369
#  * best MAE 5.354
# epoch 16, processed 13824 samples, lr 0.0000001000
# Epoch: [16][0/864]	Time 0.068 (0.068)	Data 0.021 (0.021)	Loss 1.3464 (1.3464)
# Epoch: [16][30/864]	Time 0.169 (0.167)	Data 0.014 (0.016)	Loss 1.8150 (2.5800)
# Epoch: [16][60/864]	Time 0.169 (0.168)	Data 0.016 (0.017)	Loss 1.9177 (2.6759)
# Epoch: [16][90/864]	Time 0.171 (0.169)	Data 0.015 (0.017)	Loss 1.5549 (2.5038)
# Epoch: [16][120/864]	Time 0.170 (0.169)	Data 0.017 (0.017)	Loss 2.3228 (2.4594)
# Epoch: [16][150/864]	Time 0.171 (0.169)	Data 0.014 (0.017)	Loss 1.1386 (2.4456)
# Epoch: [16][180/864]	Time 0.172 (0.169)	Data 0.014 (0.017)	Loss 3.3718 (2.3973)
# Epoch: [16][210/864]	Time 0.167 (0.169)	Data 0.017 (0.017)	Loss 1.9745 (2.3532)
# Epoch: [16][240/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 1.5553 (2.3415)
# Epoch: [16][270/864]	Time 0.169 (0.170)	Data 0.015 (0.017)	Loss 1.2445 (2.3461)
# Epoch: [16][300/864]	Time 0.171 (0.170)	Data 0.020 (0.017)	Loss 3.0648 (2.3505)
# Epoch: [16][330/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 3.7945 (2.3474)
# Epoch: [16][360/864]	Time 0.170 (0.170)	Data 0.014 (0.016)	Loss 0.9892 (2.3169)
# Epoch: [16][390/864]	Time 0.170 (0.170)	Data 0.016 (0.017)	Loss 3.0014 (2.3010)
# Epoch: [16][420/864]	Time 0.171 (0.170)	Data 0.015 (0.017)	Loss 1.7934 (2.3148)
# Epoch: [16][450/864]	Time 0.171 (0.170)	Data 0.018 (0.017)	Loss 1.5168 (2.3352)
# Epoch: [16][480/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 3.6653 (2.3536)
# Epoch: [16][510/864]	Time 0.171 (0.170)	Data 0.015 (0.017)	Loss 2.2677 (2.3688)
# Epoch: [16][540/864]	Time 0.171 (0.170)	Data 0.046 (0.017)	Loss 3.9232 (2.3835)
# Epoch: [16][570/864]	Time 0.171 (0.170)	Data 0.015 (0.017)	Loss 1.8579 (2.3593)
# Epoch: [16][600/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 1.6512 (2.3551)
# Epoch: [16][630/864]	Time 0.170 (0.170)	Data 0.025 (0.017)	Loss 3.1114 (2.3484)
# Epoch: [16][660/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 2.6017 (2.3541)
# Epoch: [16][690/864]	Time 0.169 (0.170)	Data 0.014 (0.017)	Loss 2.0484 (2.3359)
# Epoch: [16][720/864]	Time 0.169 (0.170)	Data 0.015 (0.017)	Loss 1.2576 (2.3319)
# Epoch: [16][750/864]	Time 0.171 (0.170)	Data 0.014 (0.017)	Loss 3.4027 (2.3121)
# Epoch: [16][780/864]	Time 0.170 (0.170)	Data 0.018 (0.017)	Loss 1.1644 (2.3062)
# Epoch: [16][810/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 1.9695 (2.3168)
# Epoch: [16][840/864]	Time 0.171 (0.170)	Data 0.015 (0.017)	Loss 2.2091 (2.3074)
# begin test
#  * MAE 5.264
#  * best MAE 5.264
# epoch 17, processed 14688 samples, lr 0.0000001000
# Epoch: [17][0/864]	Time 0.067 (0.067)	Data 0.019 (0.019)	Loss 3.0861 (3.0861)
# Epoch: [17][30/864]	Time 0.170 (0.166)	Data 0.015 (0.016)	Loss 0.7870 (2.2430)
# Epoch: [17][60/864]	Time 0.172 (0.168)	Data 0.036 (0.016)	Loss 1.5051 (2.1501)
# Epoch: [17][90/864]	Time 0.173 (0.169)	Data 0.014 (0.018)	Loss 2.5884 (2.1371)
# Epoch: [17][120/864]	Time 0.170 (0.169)	Data 0.014 (0.018)	Loss 0.7317 (2.1436)
# Epoch: [17][150/864]	Time 0.170 (0.169)	Data 0.018 (0.018)	Loss 2.9994 (2.1996)
# Epoch: [17][180/864]	Time 0.172 (0.169)	Data 0.014 (0.017)	Loss 2.6278 (2.1766)
# Epoch: [17][210/864]	Time 0.171 (0.169)	Data 0.015 (0.017)	Loss 1.3915 (2.2317)
# Epoch: [17][240/864]	Time 0.169 (0.169)	Data 0.016 (0.017)	Loss 1.5489 (2.2301)
# Epoch: [17][270/864]	Time 0.171 (0.170)	Data 0.015 (0.017)	Loss 0.8549 (2.2493)
# Epoch: [17][300/864]	Time 0.169 (0.170)	Data 0.019 (0.017)	Loss 1.8252 (2.2539)
# Epoch: [17][330/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 2.2364 (2.2255)
# Epoch: [17][360/864]	Time 0.171 (0.170)	Data 0.036 (0.017)	Loss 4.4862 (2.2536)
# Epoch: [17][390/864]	Time 0.172 (0.170)	Data 0.016 (0.017)	Loss 3.9028 (2.2398)
# Epoch: [17][420/864]	Time 0.170 (0.170)	Data 0.016 (0.017)	Loss 1.3039 (2.2392)
# Epoch: [17][450/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 3.0831 (2.2259)
# Epoch: [17][480/864]	Time 0.170 (0.170)	Data 0.018 (0.017)	Loss 3.7541 (2.2605)
# Epoch: [17][510/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 3.0838 (2.2607)
# Epoch: [17][540/864]	Time 0.171 (0.170)	Data 0.016 (0.017)	Loss 0.9726 (2.2595)
# Epoch: [17][570/864]	Time 0.170 (0.170)	Data 0.016 (0.017)	Loss 1.2033 (2.2516)
# Epoch: [17][600/864]	Time 0.168 (0.170)	Data 0.016 (0.017)	Loss 2.9969 (2.2745)
# Epoch: [17][630/864]	Time 0.170 (0.170)	Data 0.017 (0.017)	Loss 3.9132 (2.2525)
# Epoch: [17][660/864]	Time 0.169 (0.170)	Data 0.015 (0.017)	Loss 1.4952 (2.2507)
# Epoch: [17][690/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 2.1867 (2.2571)
# Epoch: [17][720/864]	Time 0.171 (0.170)	Data 0.018 (0.017)	Loss 4.6155 (2.2630)
# Epoch: [17][750/864]	Time 0.171 (0.170)	Data 0.016 (0.017)	Loss 4.4710 (2.2717)
# Epoch: [17][780/864]	Time 0.169 (0.170)	Data 0.015 (0.017)	Loss 3.0607 (2.2765)
# Epoch: [17][810/864]	Time 0.170 (0.170)	Data 0.018 (0.017)	Loss 1.8254 (2.2967)
# Epoch: [17][840/864]	Time 0.168 (0.170)	Data 0.015 (0.017)	Loss 3.7274 (2.3027)
# begin test
#  * MAE 5.349
#  * best MAE 5.264
# epoch 18, processed 15552 samples, lr 0.0000001000
# Epoch: [18][0/864]	Time 0.134 (0.134)	Data 0.082 (0.082)	Loss 1.9177 (1.9177)
# Epoch: [18][30/864]	Time 0.171 (0.175)	Data 0.014 (0.027)	Loss 3.5818 (2.0686)
# Epoch: [18][60/864]	Time 0.171 (0.172)	Data 0.022 (0.022)	Loss 0.9287 (2.1447)
# Epoch: [18][90/864]	Time 0.169 (0.172)	Data 0.017 (0.021)	Loss 1.8819 (2.2691)
# Epoch: [18][120/864]	Time 0.170 (0.171)	Data 0.014 (0.019)	Loss 0.9406 (2.2779)
# Epoch: [18][150/864]	Time 0.169 (0.171)	Data 0.021 (0.019)	Loss 3.1072 (2.2774)
# Epoch: [18][180/864]	Time 0.171 (0.171)	Data 0.015 (0.019)	Loss 1.9656 (2.2603)
# Epoch: [18][210/864]	Time 0.170 (0.171)	Data 0.016 (0.018)	Loss 1.9333 (2.2441)
# Epoch: [18][240/864]	Time 0.170 (0.170)	Data 0.017 (0.018)	Loss 1.1697 (2.2267)
# Epoch: [18][270/864]	Time 0.170 (0.170)	Data 0.014 (0.018)	Loss 4.4716 (2.2559)
# Epoch: [18][300/864]	Time 0.171 (0.170)	Data 0.014 (0.018)	Loss 1.4363 (2.2380)
# Epoch: [18][330/864]	Time 0.172 (0.170)	Data 0.018 (0.018)	Loss 1.2525 (2.2122)
# Epoch: [18][360/864]	Time 0.169 (0.170)	Data 0.015 (0.018)	Loss 1.2333 (2.1950)
# Epoch: [18][390/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 2.0462 (2.1845)
# Epoch: [18][420/864]	Time 0.169 (0.170)	Data 0.020 (0.018)	Loss 2.9160 (2.2110)
# Epoch: [18][450/864]	Time 0.170 (0.170)	Data 0.016 (0.017)	Loss 3.3286 (2.2249)
# Epoch: [18][480/864]	Time 0.169 (0.170)	Data 0.019 (0.017)	Loss 1.3338 (2.2340)
# Epoch: [18][510/864]	Time 0.169 (0.170)	Data 0.019 (0.017)	Loss 1.7001 (2.2372)
# Epoch: [18][540/864]	Time 0.170 (0.170)	Data 0.016 (0.017)	Loss 2.4564 (2.2382)
# Epoch: [18][570/864]	Time 0.170 (0.170)	Data 0.019 (0.017)	Loss 1.8146 (2.2234)
# Epoch: [18][600/864]	Time 0.171 (0.170)	Data 0.015 (0.017)	Loss 1.8543 (2.2319)
# Epoch: [18][630/864]	Time 0.169 (0.170)	Data 0.015 (0.017)	Loss 3.8169 (2.2357)
# Epoch: [18][660/864]	Time 0.170 (0.170)	Data 0.018 (0.017)	Loss 0.6916 (2.2348)
# Epoch: [18][690/864]	Time 0.169 (0.170)	Data 0.015 (0.017)	Loss 4.4883 (2.2579)
# Epoch: [18][720/864]	Time 0.171 (0.170)	Data 0.015 (0.017)	Loss 3.8946 (2.2616)
# Epoch: [18][750/864]	Time 0.171 (0.170)	Data 0.017 (0.017)	Loss 3.1067 (2.2701)
# Epoch: [18][780/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 2.8388 (2.2783)
# Epoch: [18][810/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 1.1656 (2.2829)
# Epoch: [18][840/864]	Time 0.169 (0.170)	Data 0.014 (0.017)	Loss 2.7173 (2.2825)
# begin test
#  * MAE 5.243
#  * best MAE 5.243
# epoch 19, processed 16416 samples, lr 0.0000001000
# Epoch: [19][0/864]	Time 0.063 (0.063)	Data 0.016 (0.016)	Loss 0.8964 (0.8964)
# Epoch: [19][30/864]	Time 0.171 (0.166)	Data 0.016 (0.021)	Loss 1.7971 (2.0985)
# Epoch: [19][60/864]	Time 0.170 (0.168)	Data 0.015 (0.018)	Loss 2.1989 (2.0772)
# Epoch: [19][90/864]	Time 0.171 (0.168)	Data 0.019 (0.018)	Loss 1.3081 (2.0846)
# Epoch: [19][120/864]	Time 0.171 (0.169)	Data 0.015 (0.020)	Loss 1.0397 (2.1391)
# Epoch: [19][150/864]	Time 0.170 (0.169)	Data 0.015 (0.019)	Loss 2.1980 (2.1486)
# Epoch: [19][180/864]	Time 0.169 (0.169)	Data 0.048 (0.019)	Loss 0.9853 (2.1464)
# Epoch: [19][210/864]	Time 0.168 (0.169)	Data 0.016 (0.018)	Loss 2.3086 (2.1724)
# Epoch: [19][240/864]	Time 0.171 (0.170)	Data 0.016 (0.018)	Loss 1.5383 (2.2408)
# Epoch: [19][270/864]	Time 0.172 (0.170)	Data 0.017 (0.018)	Loss 0.6916 (2.2043)
# Epoch: [19][300/864]	Time 0.171 (0.170)	Data 0.014 (0.018)	Loss 1.2478 (2.1919)
# Epoch: [19][330/864]	Time 0.168 (0.170)	Data 0.016 (0.018)	Loss 3.6459 (2.1869)
# Epoch: [19][360/864]	Time 0.170 (0.170)	Data 0.016 (0.018)	Loss 4.7541 (2.2340)
# Epoch: [19][390/864]	Time 0.168 (0.170)	Data 0.014 (0.018)	Loss 1.2064 (2.2221)
# Epoch: [19][420/864]	Time 0.170 (0.170)	Data 0.020 (0.017)	Loss 1.8755 (2.2289)
# Epoch: [19][450/864]	Time 0.168 (0.170)	Data 0.015 (0.017)	Loss 0.9340 (2.2035)
# Epoch: [19][480/864]	Time 0.169 (0.170)	Data 0.016 (0.017)	Loss 0.6078 (2.2258)
# Epoch: [19][510/864]	Time 0.171 (0.170)	Data 0.017 (0.017)	Loss 1.6813 (2.2412)
# Epoch: [19][540/864]	Time 0.169 (0.170)	Data 0.015 (0.017)	Loss 4.4555 (2.2527)
# Epoch: [19][570/864]	Time 0.168 (0.170)	Data 0.015 (0.017)	Loss 1.5345 (2.2833)
# Epoch: [19][600/864]	Time 0.167 (0.170)	Data 0.027 (0.017)	Loss 4.8274 (2.2977)
# Epoch: [19][630/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 1.3073 (2.2784)
# Epoch: [19][660/864]	Time 0.168 (0.170)	Data 0.016 (0.017)	Loss 1.2316 (2.2686)
# Epoch: [19][690/864]	Time 0.169 (0.170)	Data 0.014 (0.017)	Loss 1.2923 (2.2697)
# Epoch: [19][720/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 2.1761 (2.2801)
# Epoch: [19][750/864]	Time 0.168 (0.170)	Data 0.017 (0.017)	Loss 5.4583 (2.2838)
# Epoch: [19][780/864]	Time 0.171 (0.170)	Data 0.016 (0.017)	Loss 4.0044 (2.2632)
# Epoch: [19][810/864]	Time 0.171 (0.170)	Data 0.015 (0.017)	Loss 1.0687 (2.2667)
# Epoch: [19][840/864]	Time 0.169 (0.170)	Data 0.016 (0.017)	Loss 4.4647 (2.2916)
# begin test
#  * MAE 5.183
#  * best MAE 5.183
# epoch 20, processed 17280 samples, lr 0.0000001000
# Epoch: [20][0/864]	Time 0.552 (0.552)	Data 0.505 (0.505)	Loss 2.5691 (2.5691)
# Epoch: [20][30/864]	Time 0.169 (0.182)	Data 0.020 (0.031)	Loss 2.8324 (2.2909)
# Epoch: [20][60/864]	Time 0.165 (0.176)	Data 0.016 (0.024)	Loss 1.2775 (2.4261)
# Epoch: [20][90/864]	Time 0.169 (0.174)	Data 0.020 (0.022)	Loss 2.0455 (2.4190)
# Epoch: [20][120/864]	Time 0.172 (0.173)	Data 0.019 (0.021)	Loss 5.0016 (2.4265)
# Epoch: [20][150/864]	Time 0.169 (0.172)	Data 0.015 (0.020)	Loss 1.2376 (2.4255)
# Epoch: [20][180/864]	Time 0.171 (0.172)	Data 0.014 (0.019)	Loss 4.4543 (2.3363)
# Epoch: [20][210/864]	Time 0.171 (0.172)	Data 0.014 (0.019)	Loss 0.6888 (2.3310)
# Epoch: [20][240/864]	Time 0.169 (0.171)	Data 0.015 (0.019)	Loss 1.0618 (2.2955)
# Epoch: [20][270/864]	Time 0.170 (0.171)	Data 0.017 (0.018)	Loss 1.2302 (2.2539)
# Epoch: [20][300/864]	Time 0.168 (0.171)	Data 0.014 (0.018)	Loss 3.3171 (2.2901)
# Epoch: [20][330/864]	Time 0.168 (0.171)	Data 0.015 (0.018)	Loss 1.1802 (2.3197)
# Epoch: [20][360/864]	Time 0.169 (0.171)	Data 0.018 (0.018)	Loss 3.6495 (2.2830)
# Epoch: [20][390/864]	Time 0.169 (0.171)	Data 0.015 (0.018)	Loss 1.1599 (2.2966)
# Epoch: [20][420/864]	Time 0.169 (0.171)	Data 0.013 (0.018)	Loss 2.9815 (2.2923)
# Epoch: [20][450/864]	Time 0.171 (0.171)	Data 0.018 (0.018)	Loss 3.4715 (2.2982)
# Epoch: [20][480/864]	Time 0.168 (0.171)	Data 0.015 (0.018)	Loss 2.1278 (2.2966)
# Epoch: [20][510/864]	Time 0.169 (0.171)	Data 0.014 (0.017)	Loss 4.6717 (2.3004)
# Epoch: [20][540/864]	Time 0.170 (0.171)	Data 0.015 (0.018)	Loss 2.8315 (2.3173)
# Epoch: [20][570/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 3.7306 (2.3027)
# Epoch: [20][600/864]	Time 0.168 (0.170)	Data 0.045 (0.017)	Loss 1.9562 (2.2925)
# Epoch: [20][630/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 3.8009 (2.3213)
# Epoch: [20][660/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 1.7992 (2.3239)
# Epoch: [20][690/864]	Time 0.170 (0.170)	Data 0.016 (0.017)	Loss 1.9074 (2.3278)
# Epoch: [20][720/864]	Time 0.170 (0.170)	Data 0.015 (0.017)	Loss 1.1577 (2.3146)
# Epoch: [20][750/864]	Time 0.169 (0.170)	Data 0.015 (0.017)	Loss 1.2901 (2.2987)
# Epoch: [20][780/864]	Time 0.170 (0.170)	Data 0.017 (0.017)	Loss 1.5692 (2.3014)
# Epoch: [20][810/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 1.4777 (2.2949)
# Epoch: [20][840/864]	Time 0.170 (0.170)	Data 0.014 (0.017)	Loss 2.3994 (2.2916)
# begin test
#  * MAE 5.230
#  * best MAE 5.183
# epoch 21, processed 18144 samples, lr 0.0000001000
# Epoch: [21][0/864]	Time 0.094 (0.094)	Data 0.047 (0.047)	Loss 2.8532 (2.8532)
# Epoch: [21][30/864]	Time 0.170 (0.168)	Data 0.016 (0.016)	Loss 4.8186 (2.2631)
# Epoch: [21][60/864]	Time 0.169 (0.169)	Data 0.017 (0.016)	Loss 2.0345 (2.1497)
# Epoch: [21][90/864]	Time 0.169 (0.169)	Data 0.017 (0.017)	Loss 1.0659 (2.0771)
# Epoch: [21][120/864]	Time 0.171 (0.169)	Data 0.015 (0.017)	Loss 1.0299 (2.1222)
# Epoch: [21][150/864]	Time 0.170 (0.170)	Data 0.016 (0.017)	Loss 3.8108 (2.1495)
# Epoch: [21][180/864]	Time 0.169 (0.170)	Data 0.015 (0.017)	Loss 1.6787 (2.1475)
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/CrowdCounting/CSRNet-pytorch/train.py", line 230, in <module>
#     main()
#   File "/content/drive/MyDrive/CrowdCounting/CSRNet-pytorch/train.py", line 92, in main
#     train(train_list, model, criterion, optimizer, epoch)
#   File "/content/drive/MyDrive/CrowdCounting/CSRNet-pytorch/train.py", line 141, in train
#     target = target.type(torch.FloatTensor).unsqueeze(0).cuda()
# KeyboardInterrupt

# %%
# %ls
# Out:
# CSRNet-pytorch/     no_pretrain_checkpoint.pth.tar  part_B_test.json            train.py
# dataset.py          no_pretrain_model_best.pth.tar  part_B_train.json           utils.py
# image.py            part_A_test.json                part_B_train_with_val.json  val.ipynb
# make_dataset.ipynb  part_A_train.json               part_B_val.json
# make_model.ipynb    part_A_train_with_val.json      __pycache__/
# model.py            part_A_val.json                 README.md

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/CrowdCounting/CSRNet-pytorch'

# %%
import os
print(os.path.exists('/content/drive/MyDrive/CrowdCounting/CSRNet-pytorch/no_pretrain_checkpoint.pth.tar'))
# Out:
# True

# %%
import os
import shutil

# Define source paths, new file names, and destination folder (in Google Drive)
source_paths = ["/content/drive/MyDrive/CrowdCounting/CSRNet-pytorch/no_pretrain_checkpoint.pth.tar", "/content/drive/MyDrive/CrowdCounting/CSRNet-pytorch/no_pretrain_model_best.pth.tar"]
new_names = ["mall_dataset_authors_code_no_pretrain_checkpoint.pth.tar", "mall_dataset_authors_code_no_pretrain_best_model.pth.tar"]
destination_folder = "/content/drive/MyDrive/CrowdCounting/Models/"

# Create the destination directory if it doesn't exist
os.makedirs(destination_folder, exist_ok=True) # This line ensures the directory exists

# Copy and rename files to Google Drive
for source_path, new_name in zip(source_paths, new_names):
    destination_path = os.path.join(destination_folder, new_name)
    shutil.copy(source_path, destination_path)

print("Files renamed and moved to Google Drive.")
# Out:
# Files renamed and moved to Google Drive.

# %% [markdown]
# ### Testing
#
# Let's see how the model trained on a small portion of the training dataset performs on the test set.

# %%
# Define the path to the JSON file
json_file_path = "/content/drive/MyDrive/CrowdCounting/Data/mall_dataset/test_img.json"

# Load the JSON file
with open(json_file_path, 'r') as file:
    test_paths = json.load(file)

print(len(test_paths))
# Out:
# 200

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/CrowdCounting/CSRNet-pytorch'

# %%
from model import CSRNet

destination_folder = "/content/drive/MyDrive/CrowdCounting/Models/"
best_model_path = os.path.join(destination_folder, 'mall_dataset_authors_code_no_pretrain_checkpoint.pth.tar')

model = CSRNet()

checkpoint = torch.load(best_model_path)
model.load_state_dict(checkpoint['state_dict'])

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])
# Out:
# <ipython-input-41-79335140038f>:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(best_model_path)

# %%
import torch
print(torch.cuda.is_available())  # Phải trả về True
print(torch.cuda.get_device_name(0))  # Hiển thị tên GPU
# Out:
# True
# Tesla T4

# %%
import os
import shutil

# Paths to the directories
source_path = '/content/drive/MyDrive/CrowdCounting/Data/mall_dataset/density_maps/'
destination_path = '/content/drive/MyDrive/CrowdCounting/Data/mall_dataset/frames/'

# Create the destination directory if it doesn't exist
os.makedirs(destination_path, exist_ok=True)

# Loop through all .h5 files in the source directory
for file_name in os.listdir(source_path):
    if file_name.endswith('.h5'):  # Only select .h5 files
        source_file = os.path.join(source_path, file_name)
        destination_file = os.path.join(destination_path, file_name)

        # Copy the file (keeping the original in source_path)
        shutil.copy(source_file, destination_file)
        print(f"Copied: {file_name}")

print("Completed copying all .h5 files back to frames!")
# Out:
# Copied: seq_001001.h5
# Copied: seq_001002.h5
# Copied: seq_001003.h5
# Copied: seq_001004.h5
# Copied: seq_001005.h5
# Copied: seq_001006.h5
# Copied: seq_001007.h5
# Copied: seq_001008.h5
# Copied: seq_001009.h5
# Copied: seq_001010.h5
# Copied: seq_001011.h5
# Copied: seq_001012.h5
# Copied: seq_001013.h5
# Copied: seq_001014.h5
# Copied: seq_001015.h5
# Copied: seq_001016.h5
# Copied: seq_001017.h5
# Copied: seq_001018.h5
# Copied: seq_001019.h5
# Copied: seq_001020.h5
# Copied: seq_001021.h5
# Copied: seq_001022.h5
# Copied: seq_001023.h5
# Copied: seq_001024.h5
# Copied: seq_001025.h5
# Copied: seq_001026.h5
# Copied: seq_001027.h5
# Copied: seq_001028.h5
# Copied: seq_001029.h5
# Copied: seq_001030.h5
# Copied: seq_001031.h5
# Copied: seq_001032.h5
# Copied: seq_001033.h5
# Copied: seq_001034.h5
# Copied: seq_001035.h5
# Copied: seq_001036.h5
# Copied: seq_001037.h5
# Copied: seq_001038.h5
# Copied: seq_001039.h5
# Copied: seq_001040.h5
# Copied: seq_001041.h5
# Copied: seq_001042.h5
# Copied: seq_001043.h5
# Copied: seq_001044.h5
# Copied: seq_001045.h5
# Copied: seq_001046.h5
# Copied: seq_001047.h5
# Copied: seq_001048.h5
# Copied: seq_001049.h5
# Copied: seq_001050.h5
# Copied: seq_001051.h5
# Copied: seq_001052.h5
# Copied: seq_001053.h5
# Copied: seq_001054.h5
# Copied: seq_001055.h5
# Copied: seq_001056.h5
# Copied: seq_001057.h5
# Copied: seq_001058.h5
# Copied: seq_001059.h5
# Copied: seq_001060.h5
# Copied: seq_001061.h5
# Copied: seq_001062.h5
# Copied: seq_001063.h5
# Copied: seq_001064.h5
# Copied: seq_001065.h5
# Copied: seq_001066.h5
# Copied: seq_001067.h5
# Copied: seq_001068.h5
# Copied: seq_001069.h5
# Copied: seq_001070.h5
# Copied: seq_001071.h5
# Copied: seq_001072.h5
# Copied: seq_001073.h5
# Copied: seq_001074.h5
# Copied: seq_001075.h5
# Copied: seq_001076.h5
# Copied: seq_001077.h5
# Copied: seq_001078.h5
# Copied: seq_001079.h5
# Copied: seq_001080.h5
# Copied: seq_001081.h5
# Copied: seq_001082.h5
# Copied: seq_001083.h5
# Copied: seq_001084.h5
# Copied: seq_001085.h5
# Copied: seq_001086.h5
# Copied: seq_001087.h5
# Copied: seq_001088.h5
# Copied: seq_001089.h5
# Copied: seq_001090.h5
# Copied: seq_001091.h5
# Copied: seq_001092.h5
# Copied: seq_001093.h5
# Copied: seq_001094.h5
# Copied: seq_001095.h5
# Copied: seq_001096.h5
# Copied: seq_001097.h5
# Copied: seq_001098.h5
# Copied: seq_001099.h5
# Copied: seq_001100.h5
# Copied: seq_001101.h5
# Copied: seq_001102.h5
# Copied: seq_001103.h5
# Copied: seq_001104.h5
# Copied: seq_001105.h5
# Copied: seq_001106.h5
# Copied: seq_001107.h5
# Copied: seq_001108.h5
# Copied: seq_001109.h5
# Copied: seq_001110.h5
# Copied: seq_001111.h5
# Copied: seq_001112.h5
# Copied: seq_001113.h5
# Copied: seq_001114.h5
# Copied: seq_001115.h5
# Copied: seq_001116.h5
# Copied: seq_001117.h5
# Copied: seq_001118.h5
# Copied: seq_001119.h5
# Copied: seq_001120.h5
# Copied: seq_001121.h5
# Copied: seq_001122.h5
# Copied: seq_001123.h5
# Copied: seq_001124.h5
# Copied: seq_001125.h5
# Copied: seq_001126.h5
# Copied: seq_001127.h5
# Copied: seq_001128.h5
# Copied: seq_001129.h5
# Copied: seq_001130.h5
# Copied: seq_001131.h5
# Copied: seq_001132.h5
# Copied: seq_001133.h5
# Copied: seq_001134.h5
# Copied: seq_001135.h5
# Copied: seq_001136.h5
# Copied: seq_001137.h5
# Copied: seq_001138.h5
# Copied: seq_001139.h5
# Copied: seq_001140.h5
# Copied: seq_001141.h5
# Copied: seq_001142.h5
# Copied: seq_001143.h5
# Copied: seq_001144.h5
# Copied: seq_001145.h5
# Copied: seq_001146.h5
# Copied: seq_001147.h5
# Copied: seq_001148.h5
# Copied: seq_001149.h5
# Copied: seq_001150.h5
# Copied: seq_001151.h5
# Copied: seq_001152.h5
# Copied: seq_001153.h5
# Copied: seq_001154.h5
# Copied: seq_001155.h5
# Copied: seq_001156.h5
# Copied: seq_001157.h5
# Copied: seq_001158.h5
# Copied: seq_001159.h5
# Copied: seq_001160.h5
# Copied: seq_001161.h5
# Copied: seq_001162.h5
# Copied: seq_001163.h5
# Copied: seq_001164.h5
# Copied: seq_001165.h5
# Copied: seq_001166.h5
# Copied: seq_001167.h5
# Copied: seq_001168.h5
# Copied: seq_001169.h5
# Copied: seq_001170.h5
# Copied: seq_001171.h5
# Copied: seq_001172.h5
# Copied: seq_001173.h5
# Copied: seq_001174.h5
# Copied: seq_001175.h5
# Copied: seq_001176.h5
# Copied: seq_001177.h5
# Copied: seq_001178.h5
# Copied: seq_001179.h5
# Copied: seq_001180.h5
# Copied: seq_001181.h5
# Copied: seq_001182.h5
# Copied: seq_001183.h5
# Copied: seq_001184.h5
# Copied: seq_001185.h5
# Copied: seq_001186.h5
# Copied: seq_001187.h5
# Copied: seq_001188.h5
# Copied: seq_001189.h5
# Copied: seq_001190.h5
# Copied: seq_001191.h5
# Copied: seq_001192.h5
# Copied: seq_001193.h5
# Copied: seq_001194.h5
# Copied: seq_001195.h5
# Copied: seq_001196.h5
# Copied: seq_001197.h5
# Copied: seq_001198.h5
# Copied: seq_001199.h5
# Copied: seq_001200.h5
# Copied: seq_001201.h5
# Copied: seq_001202.h5
# Copied: seq_001203.h5
# Copied: seq_001204.h5
# Copied: seq_001205.h5
# Copied: seq_001206.h5
# Copied: seq_001207.h5
# Copied: seq_001208.h5
# Copied: seq_001209.h5
# Copied: seq_001210.h5
# Copied: seq_001211.h5
# Copied: seq_001212.h5
# Copied: seq_001213.h5
# Copied: seq_001214.h5
# Copied: seq_001215.h5
# Copied: seq_001216.h5
# Copied: seq_001217.h5
# Copied: seq_001218.h5
# Copied: seq_001219.h5
# Copied: seq_001220.h5
# Copied: seq_001221.h5
# Copied: seq_001222.h5
# Copied: seq_001223.h5
# Copied: seq_001224.h5
# Copied: seq_001225.h5
# Copied: seq_001226.h5
# Copied: seq_001227.h5
# Copied: seq_001228.h5
# Copied: seq_001229.h5
# Copied: seq_001230.h5
# Copied: seq_001231.h5
# Copied: seq_001232.h5
# Copied: seq_001233.h5
# Copied: seq_001234.h5
# Copied: seq_001235.h5
# Copied: seq_001236.h5
# Copied: seq_001237.h5
# Copied: seq_001238.h5
# Copied: seq_001239.h5
# Copied: seq_001240.h5
# Copied: seq_001241.h5
# Copied: seq_001242.h5
# Copied: seq_001243.h5
# Copied: seq_001244.h5
# Copied: seq_001245.h5
# Copied: seq_001246.h5
# Copied: seq_001247.h5
# Copied: seq_001248.h5
# Copied: seq_001249.h5
# Copied: seq_001250.h5
# Copied: seq_001251.h5
# Copied: seq_001252.h5
# Copied: seq_001253.h5
# Copied: seq_001254.h5
# Copied: seq_001255.h5
# Copied: seq_001256.h5
# Copied: seq_001257.h5
# Copied: seq_001258.h5
# Copied: seq_001259.h5
# Copied: seq_001260.h5
# Copied: seq_001261.h5
# Copied: seq_001262.h5
# Copied: seq_001263.h5
# Copied: seq_001264.h5
# Copied: seq_001265.h5
# Copied: seq_001266.h5
# Copied: seq_001267.h5
# Copied: seq_001268.h5
# Copied: seq_001269.h5
# Copied: seq_001270.h5
# Copied: seq_001271.h5
# Copied: seq_001272.h5
# Copied: seq_001273.h5
# Copied: seq_001274.h5
# Copied: seq_001275.h5
# Copied: seq_001276.h5
# Copied: seq_001277.h5
# Copied: seq_001278.h5
# Copied: seq_001279.h5
# Copied: seq_001280.h5
# Copied: seq_001281.h5
# Copied: seq_001282.h5
# Copied: seq_001283.h5
# Copied: seq_001284.h5
# Copied: seq_001285.h5
# Copied: seq_001286.h5
# Copied: seq_001287.h5
# Copied: seq_001288.h5
# Copied: seq_001289.h5
# Copied: seq_001290.h5
# Copied: seq_001291.h5
# Copied: seq_001292.h5
# Copied: seq_001293.h5
# Copied: seq_001294.h5
# Copied: seq_001295.h5
# Copied: seq_001296.h5
# Copied: seq_001297.h5
# Copied: seq_001298.h5
# Copied: seq_001299.h5
# Copied: seq_001300.h5
# Copied: seq_001301.h5
# Copied: seq_001302.h5
# Copied: seq_001303.h5
# Copied: seq_001304.h5
# Copied: seq_001305.h5
# Copied: seq_001306.h5
# Copied: seq_001307.h5
# Copied: seq_001308.h5
# Copied: seq_001309.h5
# Copied: seq_001310.h5
# Copied: seq_001311.h5
# Copied: seq_001312.h5
# Copied: seq_001313.h5
# Copied: seq_001314.h5
# Copied: seq_001315.h5
# Copied: seq_001316.h5
# Copied: seq_001317.h5
# Copied: seq_001318.h5
# Copied: seq_001319.h5
# Copied: seq_001320.h5
# Copied: seq_001321.h5
# Copied: seq_001322.h5
# Copied: seq_001323.h5
# Copied: seq_001324.h5
# Copied: seq_001325.h5
# Copied: seq_001326.h5
# Copied: seq_001327.h5
# Copied: seq_001328.h5
# Copied: seq_001329.h5
# Copied: seq_001330.h5
# Copied: seq_001331.h5
# Copied: seq_001332.h5
# Copied: seq_001333.h5
# Copied: seq_001334.h5
# Copied: seq_001335.h5
# Copied: seq_001336.h5
# Copied: seq_001337.h5
# Copied: seq_001338.h5
# Copied: seq_001339.h5
# Copied: seq_001340.h5
# Copied: seq_001341.h5
# Copied: seq_001342.h5
# Copied: seq_001343.h5
# Copied: seq_001344.h5
# Copied: seq_001345.h5
# Copied: seq_001346.h5
# Copied: seq_001347.h5
# Copied: seq_001348.h5
# Copied: seq_001349.h5
# Copied: seq_001350.h5
# Copied: seq_001351.h5
# Copied: seq_001352.h5
# Copied: seq_001353.h5
# Copied: seq_001354.h5
# Copied: seq_001355.h5
# Copied: seq_001356.h5
# Copied: seq_001357.h5
# Copied: seq_001358.h5
# Copied: seq_001359.h5
# Copied: seq_001360.h5
# Copied: seq_001361.h5
# Copied: seq_001362.h5
# Copied: seq_001363.h5
# Copied: seq_001364.h5
# Copied: seq_001365.h5
# Copied: seq_001366.h5
# Copied: seq_001367.h5
# Copied: seq_001368.h5
# Copied: seq_001369.h5
# Copied: seq_001370.h5
# Copied: seq_001371.h5
# Copied: seq_001372.h5
# Copied: seq_001373.h5
# Copied: seq_001374.h5
# Copied: seq_001375.h5
# Copied: seq_001376.h5
# Copied: seq_001377.h5
# Copied: seq_001378.h5
# Copied: seq_001379.h5
# Copied: seq_001380.h5
# Copied: seq_001381.h5
# Copied: seq_001382.h5
# Copied: seq_001383.h5
# Copied: seq_001384.h5
# Copied: seq_001385.h5
# Copied: seq_001386.h5
# Copied: seq_001387.h5
# Copied: seq_001388.h5
# Copied: seq_001389.h5
# Copied: seq_001390.h5
# Copied: seq_001391.h5
# Copied: seq_001392.h5
# Copied: seq_001393.h5
# Copied: seq_001394.h5
# Copied: seq_001395.h5
# Copied: seq_001396.h5
# Copied: seq_001397.h5
# Copied: seq_001398.h5
# Copied: seq_001399.h5
# Copied: seq_001400.h5
# Copied: seq_001401.h5
# Copied: seq_001402.h5
# Copied: seq_001403.h5
# Copied: seq_001404.h5
# Copied: seq_001405.h5
# Copied: seq_001406.h5
# Copied: seq_001407.h5
# Copied: seq_001408.h5
# Copied: seq_001409.h5
# Copied: seq_001410.h5
# Copied: seq_001411.h5
# Copied: seq_001412.h5
# Copied: seq_001413.h5
# Copied: seq_001414.h5
# Copied: seq_001415.h5
# Copied: seq_001416.h5
# Copied: seq_001417.h5
# Copied: seq_001418.h5
# Copied: seq_001419.h5
# Copied: seq_001420.h5
# Copied: seq_001421.h5
# Copied: seq_001422.h5
# Copied: seq_001423.h5
# Copied: seq_001424.h5
# Copied: seq_001425.h5
# Copied: seq_001426.h5
# Copied: seq_001427.h5
# Copied: seq_001428.h5
# Copied: seq_001429.h5
# Copied: seq_001430.h5
# Copied: seq_001431.h5
# Copied: seq_001432.h5
# Copied: seq_001433.h5
# Copied: seq_001434.h5
# Copied: seq_001435.h5
# Copied: seq_001436.h5
# Copied: seq_001437.h5
# Copied: seq_001438.h5
# Copied: seq_001439.h5
# Copied: seq_001440.h5
# Copied: seq_001441.h5
# Copied: seq_001442.h5
# Copied: seq_001443.h5
# Copied: seq_001444.h5
# Copied: seq_001445.h5
# Copied: seq_001446.h5
# Copied: seq_001447.h5
# Copied: seq_001448.h5
# Copied: seq_001449.h5
# Copied: seq_001450.h5
# Copied: seq_001451.h5
# Copied: seq_001452.h5
# Copied: seq_001453.h5
# Copied: seq_001454.h5
# Copied: seq_001455.h5
# Copied: seq_001456.h5
# Copied: seq_001457.h5
# Copied: seq_001458.h5
# Copied: seq_001459.h5
# Copied: seq_001460.h5
# Copied: seq_001461.h5
# Copied: seq_001462.h5
# Copied: seq_001463.h5
# Copied: seq_001464.h5
# Copied: seq_001465.h5
# Copied: seq_001466.h5
# Copied: seq_001467.h5
# Copied: seq_001468.h5
# Copied: seq_001469.h5
# Copied: seq_001470.h5
# Copied: seq_001471.h5
# Copied: seq_001472.h5
# Copied: seq_001473.h5
# Copied: seq_001474.h5
# Copied: seq_001475.h5
# Copied: seq_001476.h5
# Copied: seq_001477.h5
# Copied: seq_001478.h5
# Copied: seq_001479.h5
# Copied: seq_001480.h5
# Copied: seq_001481.h5
# Copied: seq_001482.h5
# Copied: seq_001483.h5
# Copied: seq_001484.h5
# Copied: seq_001485.h5
# Copied: seq_001486.h5
# Copied: seq_001487.h5
# Copied: seq_001488.h5
# Copied: seq_001489.h5
# Copied: seq_001490.h5
# Copied: seq_001491.h5
# Copied: seq_001492.h5
# Copied: seq_001493.h5
# Copied: seq_001494.h5
# Copied: seq_001495.h5
# Copied: seq_001496.h5
# Copied: seq_001497.h5
# Copied: seq_001498.h5
# Copied: seq_001499.h5
# Copied: seq_001500.h5
# Copied: seq_001501.h5
# Copied: seq_001502.h5
# Copied: seq_001503.h5
# Copied: seq_001504.h5
# Copied: seq_001505.h5
# Copied: seq_001506.h5
# Copied: seq_001507.h5
# Copied: seq_001508.h5
# Copied: seq_001509.h5
# Copied: seq_001510.h5
# Copied: seq_001511.h5
# Copied: seq_001512.h5
# Copied: seq_001513.h5
# Copied: seq_001514.h5
# Copied: seq_001515.h5
# Copied: seq_001516.h5
# Copied: seq_001517.h5
# Copied: seq_001518.h5
# Copied: seq_001519.h5
# Copied: seq_001520.h5
# Copied: seq_001521.h5
# Copied: seq_001522.h5
# Copied: seq_001523.h5
# Copied: seq_001524.h5
# Copied: seq_001525.h5
# Copied: seq_001526.h5
# Copied: seq_001527.h5
# Copied: seq_001528.h5
# Copied: seq_001529.h5
# Copied: seq_001530.h5
# Copied: seq_001531.h5
# Copied: seq_001532.h5
# Copied: seq_001533.h5
# Copied: seq_001534.h5
# Copied: seq_001535.h5
# Copied: seq_001536.h5
# Copied: seq_001537.h5
# Copied: seq_001538.h5
# Copied: seq_001539.h5
# Copied: seq_001540.h5
# Copied: seq_001541.h5
# Copied: seq_001542.h5
# Copied: seq_001543.h5
# Copied: seq_001544.h5
# Copied: seq_001545.h5
# Copied: seq_001546.h5
# Copied: seq_001547.h5
# Copied: seq_001548.h5
# Copied: seq_001549.h5
# Copied: seq_001550.h5
# Copied: seq_001551.h5
# Copied: seq_001552.h5
# Copied: seq_001553.h5
# Copied: seq_001554.h5
# Copied: seq_001555.h5
# Copied: seq_001556.h5
# Copied: seq_001557.h5
# Copied: seq_001558.h5
# Copied: seq_001559.h5
# Copied: seq_001560.h5
# Copied: seq_001561.h5
# Copied: seq_001562.h5
# Copied: seq_001563.h5
# Copied: seq_001564.h5
# Copied: seq_001565.h5
# Copied: seq_001566.h5
# Copied: seq_001567.h5
# Copied: seq_001568.h5
# Copied: seq_001569.h5
# Copied: seq_001570.h5
# Copied: seq_001571.h5
# Copied: seq_001572.h5
# Copied: seq_001573.h5
# Copied: seq_001574.h5
# Copied: seq_001575.h5
# Copied: seq_001576.h5
# Copied: seq_001577.h5
# Copied: seq_001578.h5
# Copied: seq_001579.h5
# Copied: seq_001580.h5
# Copied: seq_001581.h5
# Copied: seq_001582.h5
# Copied: seq_001583.h5
# Copied: seq_001584.h5
# Copied: seq_001585.h5
# Copied: seq_001586.h5
# Copied: seq_001587.h5
# Copied: seq_001588.h5
# Copied: seq_001589.h5
# Copied: seq_001590.h5
# Copied: seq_001591.h5
# Copied: seq_001592.h5
# Copied: seq_001593.h5
# Copied: seq_001594.h5
# Copied: seq_001595.h5
# Copied: seq_001596.h5
# Copied: seq_001597.h5
# Copied: seq_001598.h5
# Copied: seq_001599.h5
# Copied: seq_001600.h5
# Copied: seq_001601.h5
# Copied: seq_001602.h5
# Copied: seq_001603.h5
# Copied: seq_001604.h5
# Copied: seq_001605.h5
# Copied: seq_001606.h5
# Copied: seq_001607.h5
# Copied: seq_001608.h5
# Copied: seq_001609.h5
# Copied: seq_001610.h5
# Copied: seq_001611.h5
# Copied: seq_001612.h5
# Copied: seq_001613.h5
# Copied: seq_001614.h5
# Copied: seq_001615.h5
# Copied: seq_001616.h5
# Copied: seq_001617.h5
# Copied: seq_001618.h5
# Copied: seq_001619.h5
# Copied: seq_001620.h5
# Copied: seq_001621.h5
# Copied: seq_001622.h5
# Copied: seq_001623.h5
# Copied: seq_001624.h5
# Copied: seq_001625.h5
# Copied: seq_001626.h5
# Copied: seq_001627.h5
# Copied: seq_001628.h5
# Copied: seq_001629.h5
# Copied: seq_001630.h5
# Copied: seq_001631.h5
# Copied: seq_001632.h5
# Copied: seq_001633.h5
# Copied: seq_001634.h5
# Copied: seq_001635.h5
# Copied: seq_001636.h5
# Copied: seq_001637.h5
# Copied: seq_001638.h5
# Copied: seq_001639.h5
# Copied: seq_001640.h5
# Copied: seq_001641.h5
# Copied: seq_001642.h5
# Copied: seq_001643.h5
# Copied: seq_001644.h5
# Copied: seq_001645.h5
# Copied: seq_001646.h5
# Copied: seq_001647.h5
# Copied: seq_001648.h5
# Copied: seq_001649.h5
# Copied: seq_001650.h5
# Copied: seq_001651.h5
# Copied: seq_001652.h5
# Copied: seq_001653.h5
# Copied: seq_001654.h5
# Copied: seq_001655.h5
# Copied: seq_001656.h5
# Copied: seq_001657.h5
# Copied: seq_001658.h5
# Copied: seq_001659.h5
# Copied: seq_001660.h5
# Copied: seq_001661.h5
# Copied: seq_001662.h5
# Copied: seq_001663.h5
# Copied: seq_001664.h5
# Copied: seq_001665.h5
# Copied: seq_001666.h5
# Copied: seq_001667.h5
# Copied: seq_001668.h5
# Copied: seq_001669.h5
# Copied: seq_001670.h5
# Copied: seq_001671.h5
# Copied: seq_001672.h5
# Copied: seq_001673.h5
# Copied: seq_001674.h5
# Copied: seq_001675.h5
# Copied: seq_001676.h5
# Copied: seq_001677.h5
# Copied: seq_001678.h5
# Copied: seq_001679.h5
# Copied: seq_001680.h5
# Copied: seq_001681.h5
# Copied: seq_001682.h5
# Copied: seq_001683.h5
# Copied: seq_001684.h5
# Copied: seq_001685.h5
# Copied: seq_001686.h5
# Copied: seq_001687.h5
# Copied: seq_001688.h5
# Copied: seq_001689.h5
# Copied: seq_001690.h5
# Copied: seq_001691.h5
# Copied: seq_001692.h5
# Copied: seq_001693.h5
# Copied: seq_001694.h5
# Copied: seq_001695.h5
# Copied: seq_001696.h5
# Copied: seq_001697.h5
# Copied: seq_001698.h5
# Copied: seq_001699.h5
# Copied: seq_001700.h5
# Copied: seq_001701.h5
# Copied: seq_001702.h5
# Copied: seq_001703.h5
# Copied: seq_001704.h5
# Copied: seq_001705.h5
# Copied: seq_001706.h5
# Copied: seq_001707.h5
# Copied: seq_001708.h5
# Copied: seq_001709.h5
# Copied: seq_001710.h5
# Copied: seq_001711.h5
# Copied: seq_001712.h5
# Copied: seq_001713.h5
# Copied: seq_001714.h5
# Copied: seq_001715.h5
# Copied: seq_001716.h5
# Copied: seq_001717.h5
# Copied: seq_001718.h5
# Copied: seq_001719.h5
# Copied: seq_001720.h5
# Copied: seq_001721.h5
# Copied: seq_001722.h5
# Copied: seq_001723.h5
# Copied: seq_001724.h5
# Copied: seq_001725.h5
# Copied: seq_001726.h5
# Copied: seq_001727.h5
# Copied: seq_001728.h5
# Copied: seq_001729.h5
# Copied: seq_001730.h5
# Copied: seq_001731.h5
# Copied: seq_001732.h5
# Copied: seq_001733.h5
# Copied: seq_001734.h5
# Copied: seq_001735.h5
# Copied: seq_001736.h5
# Copied: seq_001737.h5
# Copied: seq_001738.h5
# Copied: seq_001739.h5
# Copied: seq_001740.h5
# Copied: seq_001741.h5
# Copied: seq_001742.h5
# Copied: seq_001743.h5
# Copied: seq_001744.h5
# Copied: seq_001745.h5
# Copied: seq_001746.h5
# Copied: seq_001747.h5
# Copied: seq_001748.h5
# Copied: seq_001749.h5
# Copied: seq_001750.h5
# Copied: seq_001751.h5
# Copied: seq_001752.h5
# Copied: seq_001753.h5
# Copied: seq_001754.h5
# Copied: seq_001755.h5
# Copied: seq_001756.h5
# Copied: seq_001757.h5
# Copied: seq_001758.h5
# Copied: seq_001759.h5
# Copied: seq_001760.h5
# Copied: seq_001761.h5
# Copied: seq_001762.h5
# Copied: seq_001763.h5
# Copied: seq_001764.h5
# Copied: seq_001765.h5
# Copied: seq_001766.h5
# Copied: seq_001767.h5
# Copied: seq_001768.h5
# Copied: seq_001769.h5
# Copied: seq_001770.h5
# Copied: seq_001771.h5
# Copied: seq_001772.h5
# Copied: seq_001773.h5
# Copied: seq_001774.h5
# Copied: seq_001775.h5
# Copied: seq_001776.h5
# Copied: seq_001777.h5
# Copied: seq_001778.h5
# Copied: seq_001779.h5
# Copied: seq_001780.h5
# Copied: seq_001781.h5
# Copied: seq_001782.h5
# Copied: seq_001783.h5
# Copied: seq_001784.h5
# Copied: seq_001785.h5
# Copied: seq_001786.h5
# Copied: seq_001787.h5
# Copied: seq_001788.h5
# Copied: seq_001789.h5
# Copied: seq_001790.h5
# Copied: seq_001791.h5
# Copied: seq_001792.h5
# Copied: seq_001793.h5
# Copied: seq_001794.h5
# Copied: seq_001795.h5
# Copied: seq_001796.h5
# Copied: seq_001797.h5
# Copied: seq_001798.h5
# Copied: seq_001799.h5
# Copied: seq_001800.h5
# Copied: seq_001801.h5
# Copied: seq_001802.h5
# Copied: seq_001803.h5
# Copied: seq_001804.h5
# Copied: seq_001805.h5
# Copied: seq_001806.h5
# Copied: seq_001807.h5
# Copied: seq_001808.h5
# Copied: seq_001809.h5
# Copied: seq_001810.h5
# Copied: seq_001811.h5
# Copied: seq_001812.h5
# Copied: seq_001813.h5
# Copied: seq_001814.h5
# Copied: seq_001815.h5
# Copied: seq_001816.h5
# Copied: seq_001817.h5
# Copied: seq_001818.h5
# Copied: seq_001819.h5
# Copied: seq_001820.h5
# Copied: seq_001821.h5
# Copied: seq_001822.h5
# Copied: seq_001823.h5
# Copied: seq_001824.h5
# Copied: seq_001825.h5
# Copied: seq_001826.h5
# Copied: seq_001827.h5
# Copied: seq_001828.h5
# Copied: seq_001829.h5
# Copied: seq_001830.h5
# Copied: seq_001831.h5
# Copied: seq_001832.h5
# Copied: seq_001833.h5
# Copied: seq_001834.h5
# Copied: seq_001835.h5
# Copied: seq_001836.h5
# Copied: seq_001837.h5
# Copied: seq_001838.h5
# Copied: seq_001839.h5
# Copied: seq_001840.h5
# Copied: seq_001841.h5
# Copied: seq_001842.h5
# Copied: seq_001843.h5
# Copied: seq_001844.h5
# Copied: seq_001845.h5
# Copied: seq_001846.h5
# Copied: seq_001847.h5
# Copied: seq_001848.h5
# Copied: seq_001849.h5
# Copied: seq_001850.h5
# Copied: seq_001851.h5
# Copied: seq_001852.h5
# Copied: seq_001853.h5
# Copied: seq_001854.h5
# Copied: seq_001855.h5
# Copied: seq_001856.h5
# Copied: seq_001857.h5
# Copied: seq_001858.h5
# Copied: seq_001859.h5
# Copied: seq_001860.h5
# Copied: seq_001861.h5
# Copied: seq_001862.h5
# Copied: seq_001863.h5
# Copied: seq_001864.h5
# Copied: seq_001865.h5
# Copied: seq_001866.h5
# Copied: seq_001867.h5
# Copied: seq_001868.h5
# Copied: seq_001869.h5
# Copied: seq_001870.h5
# Copied: seq_001871.h5
# Copied: seq_001872.h5
# Copied: seq_001873.h5
# Copied: seq_001874.h5
# Copied: seq_001875.h5
# Copied: seq_001876.h5
# Copied: seq_001877.h5
# Copied: seq_001878.h5
# Copied: seq_001879.h5
# Copied: seq_001880.h5
# Copied: seq_001881.h5
# Copied: seq_001882.h5
# Copied: seq_001883.h5
# Copied: seq_001884.h5
# Copied: seq_001885.h5
# Copied: seq_001886.h5
# Copied: seq_001887.h5
# Copied: seq_001888.h5
# Copied: seq_001889.h5
# Copied: seq_001890.h5
# Copied: seq_001891.h5
# Copied: seq_001892.h5
# Copied: seq_001893.h5
# Copied: seq_001894.h5
# Copied: seq_001895.h5
# Copied: seq_001896.h5
# Copied: seq_001897.h5
# Copied: seq_001898.h5
# Copied: seq_001899.h5
# Copied: seq_001900.h5
# Copied: seq_001901.h5
# Copied: seq_001902.h5
# Copied: seq_001903.h5
# Copied: seq_001904.h5
# Copied: seq_001905.h5
# Copied: seq_001906.h5
# Copied: seq_001907.h5
# Copied: seq_001908.h5
# Copied: seq_001909.h5
# Copied: seq_001910.h5
# Copied: seq_001911.h5
# Copied: seq_001912.h5
# Copied: seq_001913.h5
# Copied: seq_001914.h5
# Copied: seq_001915.h5
# Copied: seq_001916.h5
# Copied: seq_001917.h5
# Copied: seq_001918.h5
# Copied: seq_001919.h5
# Copied: seq_001920.h5
# Copied: seq_001921.h5
# Copied: seq_001922.h5
# Copied: seq_001923.h5
# Copied: seq_001924.h5
# Copied: seq_001925.h5
# Copied: seq_001926.h5
# Copied: seq_001927.h5
# Copied: seq_001928.h5
# Copied: seq_001929.h5
# Copied: seq_001930.h5
# Copied: seq_001931.h5
# Copied: seq_001932.h5
# Copied: seq_001933.h5
# Copied: seq_001934.h5
# Copied: seq_001935.h5
# Copied: seq_001936.h5
# Copied: seq_001937.h5
# Copied: seq_001938.h5
# Copied: seq_001939.h5
# Copied: seq_001940.h5
# Copied: seq_001941.h5
# Copied: seq_001942.h5
# Copied: seq_001943.h5
# Copied: seq_001944.h5
# Copied: seq_001945.h5
# Copied: seq_001946.h5
# Copied: seq_001947.h5
# Copied: seq_001948.h5
# Copied: seq_001949.h5
# Copied: seq_001950.h5
# Copied: seq_001951.h5
# Copied: seq_001952.h5
# Copied: seq_001953.h5
# Copied: seq_001954.h5
# Copied: seq_001955.h5
# Copied: seq_001956.h5
# Copied: seq_001957.h5
# Copied: seq_001958.h5
# Copied: seq_001959.h5
# Copied: seq_001960.h5
# Copied: seq_001961.h5
# Copied: seq_001962.h5
# Copied: seq_001963.h5
# Copied: seq_001964.h5
# Copied: seq_001965.h5
# Copied: seq_001966.h5
# Copied: seq_001967.h5
# Copied: seq_001968.h5
# Copied: seq_001969.h5
# Copied: seq_001970.h5
# Copied: seq_001971.h5
# Copied: seq_001972.h5
# Copied: seq_001973.h5
# Copied: seq_001974.h5
# Copied: seq_001975.h5
# Copied: seq_001976.h5
# Copied: seq_001977.h5
# Copied: seq_001978.h5
# Copied: seq_001979.h5
# Copied: seq_001980.h5
# Copied: seq_001981.h5
# Copied: seq_001982.h5
# Copied: seq_001983.h5
# Copied: seq_001984.h5
# Copied: seq_001985.h5
# Copied: seq_001986.h5
# Copied: seq_001987.h5
# Copied: seq_001988.h5
# Copied: seq_001989.h5
# Copied: seq_001990.h5
# Copied: seq_001991.h5
# Copied: seq_001992.h5
# Copied: seq_001993.h5
# Copied: seq_001994.h5
# Copied: seq_001995.h5
# Copied: seq_001996.h5
# Copied: seq_001997.h5
# Copied: seq_001998.h5
# Copied: seq_001999.h5
# Copied: seq_002000.h5
# Copied: seq_000001.h5
# Copied: seq_000002.h5
# Copied: seq_000003.h5
# Copied: seq_000004.h5
# Copied: seq_000005.h5
# Copied: seq_000006.h5
# Copied: seq_000007.h5
# Copied: seq_000008.h5
# Copied: seq_000009.h5
# Copied: seq_000010.h5
# Copied: seq_000011.h5
# Copied: seq_000012.h5
# Copied: seq_000013.h5
# Copied: seq_000014.h5
# Copied: seq_000015.h5
# Copied: seq_000016.h5
# Copied: seq_000017.h5
# Copied: seq_000018.h5
# Copied: seq_000019.h5
# Copied: seq_000020.h5
# Copied: seq_000021.h5
# Copied: seq_000022.h5
# Copied: seq_000023.h5
# Copied: seq_000024.h5
# Copied: seq_000025.h5
# Copied: seq_000026.h5
# Copied: seq_000027.h5
# Copied: seq_000028.h5
# Copied: seq_000029.h5
# Copied: seq_000030.h5
# Copied: seq_000031.h5
# Copied: seq_000032.h5
# Copied: seq_000033.h5
# Copied: seq_000034.h5
# Copied: seq_000035.h5
# Copied: seq_000036.h5
# Copied: seq_000037.h5
# Copied: seq_000038.h5
# Copied: seq_000039.h5
# Copied: seq_000040.h5
# Copied: seq_000041.h5
# Copied: seq_000042.h5
# Copied: seq_000043.h5
# Copied: seq_000044.h5
# Copied: seq_000045.h5
# Copied: seq_000046.h5
# Copied: seq_000047.h5
# Copied: seq_000048.h5
# Copied: seq_000049.h5
# Copied: seq_000050.h5
# Copied: seq_000051.h5
# Copied: seq_000052.h5
# Copied: seq_000053.h5
# Copied: seq_000054.h5
# Copied: seq_000055.h5
# Copied: seq_000056.h5
# Copied: seq_000057.h5
# Copied: seq_000058.h5
# Copied: seq_000059.h5
# Copied: seq_000060.h5
# Copied: seq_000061.h5
# Copied: seq_000062.h5
# Copied: seq_000063.h5
# Copied: seq_000064.h5
# Copied: seq_000065.h5
# Copied: seq_000066.h5
# Copied: seq_000067.h5
# Copied: seq_000068.h5
# Copied: seq_000069.h5
# Copied: seq_000070.h5
# Copied: seq_000071.h5
# Copied: seq_000072.h5
# Copied: seq_000073.h5
# Copied: seq_000074.h5
# Copied: seq_000075.h5
# Copied: seq_000076.h5
# Copied: seq_000077.h5
# Copied: seq_000078.h5
# Copied: seq_000079.h5
# Copied: seq_000080.h5
# Copied: seq_000081.h5
# Copied: seq_000082.h5
# Copied: seq_000083.h5
# Copied: seq_000084.h5
# Copied: seq_000085.h5
# Copied: seq_000086.h5
# Copied: seq_000087.h5
# Copied: seq_000088.h5
# Copied: seq_000089.h5
# Copied: seq_000090.h5
# Copied: seq_000091.h5
# Copied: seq_000092.h5
# Copied: seq_000093.h5
# Copied: seq_000094.h5
# Copied: seq_000095.h5
# Copied: seq_000096.h5
# Copied: seq_000097.h5
# Copied: seq_000098.h5
# Copied: seq_000099.h5
# Copied: seq_000100.h5
# Copied: seq_000101.h5
# Copied: seq_000102.h5
# Copied: seq_000103.h5
# Copied: seq_000104.h5
# Copied: seq_000105.h5
# Copied: seq_000106.h5
# Copied: seq_000107.h5
# Copied: seq_000108.h5
# Copied: seq_000109.h5
# Copied: seq_000110.h5
# Copied: seq_000111.h5
# Copied: seq_000112.h5
# Copied: seq_000113.h5
# Copied: seq_000114.h5
# Copied: seq_000115.h5
# Copied: seq_000116.h5
# Copied: seq_000117.h5
# Copied: seq_000118.h5
# Copied: seq_000119.h5
# Copied: seq_000120.h5
# Copied: seq_000121.h5
# Copied: seq_000122.h5
# Copied: seq_000123.h5
# Copied: seq_000124.h5
# Copied: seq_000125.h5
# Copied: seq_000126.h5
# Copied: seq_000127.h5
# Copied: seq_000128.h5
# Copied: seq_000129.h5
# Copied: seq_000130.h5
# Copied: seq_000131.h5
# Copied: seq_000132.h5
# Copied: seq_000133.h5
# Copied: seq_000134.h5
# Copied: seq_000135.h5
# Copied: seq_000136.h5
# Copied: seq_000137.h5
# Copied: seq_000138.h5
# Copied: seq_000139.h5
# Copied: seq_000140.h5
# Copied: seq_000141.h5
# Copied: seq_000142.h5
# Copied: seq_000143.h5
# Copied: seq_000144.h5
# Copied: seq_000145.h5
# Copied: seq_000146.h5
# Copied: seq_000147.h5
# Copied: seq_000148.h5
# Copied: seq_000149.h5
# Copied: seq_000150.h5
# Copied: seq_000151.h5
# Copied: seq_000152.h5
# Copied: seq_000153.h5
# Copied: seq_000154.h5
# Copied: seq_000155.h5
# Copied: seq_000156.h5
# Copied: seq_000157.h5
# Copied: seq_000158.h5
# Copied: seq_000159.h5
# Copied: seq_000160.h5
# Copied: seq_000161.h5
# Copied: seq_000162.h5
# Copied: seq_000163.h5
# Copied: seq_000164.h5
# Copied: seq_000165.h5
# Copied: seq_000166.h5
# Copied: seq_000167.h5
# Copied: seq_000168.h5
# Copied: seq_000169.h5
# Copied: seq_000170.h5
# Copied: seq_000171.h5
# Copied: seq_000172.h5
# Copied: seq_000173.h5
# Copied: seq_000174.h5
# Copied: seq_000175.h5
# Copied: seq_000176.h5
# Copied: seq_000177.h5
# Copied: seq_000178.h5
# Copied: seq_000179.h5
# Copied: seq_000180.h5
# Copied: seq_000181.h5
# Copied: seq_000182.h5
# Copied: seq_000183.h5
# Copied: seq_000184.h5
# Copied: seq_000185.h5
# Copied: seq_000186.h5
# Copied: seq_000187.h5
# Copied: seq_000188.h5
# Copied: seq_000189.h5
# Copied: seq_000190.h5
# Copied: seq_000191.h5
# Copied: seq_000192.h5
# Copied: seq_000193.h5
# Copied: seq_000194.h5
# Copied: seq_000195.h5
# Copied: seq_000196.h5
# Copied: seq_000197.h5
# Copied: seq_000198.h5
# Copied: seq_000199.h5
# Copied: seq_000200.h5
# Copied: seq_000201.h5
# Copied: seq_000202.h5
# Copied: seq_000203.h5
# Copied: seq_000204.h5
# Copied: seq_000205.h5
# Copied: seq_000206.h5
# Copied: seq_000207.h5
# Copied: seq_000208.h5
# Copied: seq_000209.h5
# Copied: seq_000210.h5
# Copied: seq_000211.h5
# Copied: seq_000212.h5
# Copied: seq_000213.h5
# Copied: seq_000214.h5
# Copied: seq_000215.h5
# Copied: seq_000216.h5
# Copied: seq_000217.h5
# Copied: seq_000218.h5
# Copied: seq_000219.h5
# Copied: seq_000220.h5
# Copied: seq_000221.h5
# Copied: seq_000222.h5
# Copied: seq_000223.h5
# Copied: seq_000224.h5
# Copied: seq_000225.h5
# Copied: seq_000226.h5
# Copied: seq_000227.h5
# Copied: seq_000228.h5
# Copied: seq_000229.h5
# Copied: seq_000230.h5
# Copied: seq_000231.h5
# Copied: seq_000232.h5
# Copied: seq_000233.h5
# Copied: seq_000234.h5
# Copied: seq_000235.h5
# Copied: seq_000236.h5
# Copied: seq_000237.h5
# Copied: seq_000238.h5
# Copied: seq_000239.h5
# Copied: seq_000240.h5
# Copied: seq_000241.h5
# Copied: seq_000242.h5
# Copied: seq_000243.h5
# Copied: seq_000244.h5
# Copied: seq_000245.h5
# Copied: seq_000246.h5
# Copied: seq_000247.h5
# Copied: seq_000248.h5
# Copied: seq_000249.h5
# Copied: seq_000250.h5
# Copied: seq_000251.h5
# Copied: seq_000252.h5
# Copied: seq_000253.h5
# Copied: seq_000254.h5
# Copied: seq_000255.h5
# Copied: seq_000256.h5
# Copied: seq_000257.h5
# Copied: seq_000258.h5
# Copied: seq_000259.h5
# Copied: seq_000260.h5
# Copied: seq_000261.h5
# Copied: seq_000262.h5
# Copied: seq_000263.h5
# Copied: seq_000264.h5
# Copied: seq_000265.h5
# Copied: seq_000266.h5
# Copied: seq_000267.h5
# Copied: seq_000268.h5
# Copied: seq_000269.h5
# Copied: seq_000270.h5
# Copied: seq_000271.h5
# Copied: seq_000272.h5
# Copied: seq_000273.h5
# Copied: seq_000274.h5
# Copied: seq_000275.h5
# Copied: seq_000276.h5
# Copied: seq_000277.h5
# Copied: seq_000278.h5
# Copied: seq_000279.h5
# Copied: seq_000280.h5
# Copied: seq_000281.h5
# Copied: seq_000282.h5
# Copied: seq_000283.h5
# Copied: seq_000284.h5
# Copied: seq_000285.h5
# Copied: seq_000286.h5
# Copied: seq_000287.h5
# Copied: seq_000288.h5
# Copied: seq_000289.h5
# Copied: seq_000290.h5
# Copied: seq_000291.h5
# Copied: seq_000292.h5
# Copied: seq_000293.h5
# Copied: seq_000294.h5
# Copied: seq_000295.h5
# Copied: seq_000296.h5
# Copied: seq_000297.h5
# Copied: seq_000298.h5
# Copied: seq_000299.h5
# Copied: seq_000300.h5
# Copied: seq_000301.h5
# Copied: seq_000302.h5
# Copied: seq_000303.h5
# Copied: seq_000304.h5
# Copied: seq_000305.h5
# Copied: seq_000306.h5
# Copied: seq_000307.h5
# Copied: seq_000308.h5
# Copied: seq_000309.h5
# Copied: seq_000310.h5
# Copied: seq_000311.h5
# Copied: seq_000312.h5
# Copied: seq_000313.h5
# Copied: seq_000314.h5
# Copied: seq_000315.h5
# Copied: seq_000316.h5
# Copied: seq_000317.h5
# Copied: seq_000318.h5
# Copied: seq_000319.h5
# Copied: seq_000320.h5
# Copied: seq_000321.h5
# Copied: seq_000322.h5
# Copied: seq_000323.h5
# Copied: seq_000324.h5
# Copied: seq_000325.h5
# Copied: seq_000326.h5
# Copied: seq_000327.h5
# Copied: seq_000328.h5
# Copied: seq_000329.h5
# Copied: seq_000330.h5
# Copied: seq_000331.h5
# Copied: seq_000332.h5
# Copied: seq_000333.h5
# Copied: seq_000334.h5
# Copied: seq_000335.h5
# Copied: seq_000336.h5
# Copied: seq_000337.h5
# Copied: seq_000338.h5
# Copied: seq_000339.h5
# Copied: seq_000340.h5
# Copied: seq_000341.h5
# Copied: seq_000342.h5
# Copied: seq_000343.h5
# Copied: seq_000344.h5
# Copied: seq_000345.h5
# Copied: seq_000346.h5
# Copied: seq_000347.h5
# Copied: seq_000348.h5
# Copied: seq_000349.h5
# Copied: seq_000350.h5
# Copied: seq_000351.h5
# Copied: seq_000352.h5
# Copied: seq_000353.h5
# Copied: seq_000354.h5
# Copied: seq_000355.h5
# Copied: seq_000356.h5
# Copied: seq_000357.h5
# Copied: seq_000358.h5
# Copied: seq_000359.h5
# Copied: seq_000360.h5
# Copied: seq_000361.h5
# Copied: seq_000362.h5
# Copied: seq_000363.h5
# Copied: seq_000364.h5
# Copied: seq_000365.h5
# Copied: seq_000366.h5
# Copied: seq_000367.h5
# Copied: seq_000368.h5
# Copied: seq_000369.h5
# Copied: seq_000370.h5
# Copied: seq_000371.h5
# Copied: seq_000372.h5
# Copied: seq_000373.h5
# Copied: seq_000374.h5
# Copied: seq_000375.h5
# Copied: seq_000376.h5
# Copied: seq_000377.h5
# Copied: seq_000378.h5
# Copied: seq_000379.h5
# Copied: seq_000380.h5
# Copied: seq_000381.h5
# Copied: seq_000382.h5
# Copied: seq_000383.h5
# Copied: seq_000384.h5
# Copied: seq_000385.h5
# Copied: seq_000386.h5
# Copied: seq_000387.h5
# Copied: seq_000388.h5
# Copied: seq_000389.h5
# Copied: seq_000390.h5
# Copied: seq_000391.h5
# Copied: seq_000392.h5
# Copied: seq_000393.h5
# Copied: seq_000394.h5
# Copied: seq_000395.h5
# Copied: seq_000396.h5
# Copied: seq_000397.h5
# Copied: seq_000398.h5
# Copied: seq_000399.h5
# Copied: seq_000400.h5
# Copied: seq_000401.h5
# Copied: seq_000402.h5
# Copied: seq_000403.h5
# Copied: seq_000404.h5
# Copied: seq_000405.h5
# Copied: seq_000406.h5
# Copied: seq_000407.h5
# Copied: seq_000408.h5
# Copied: seq_000409.h5
# Copied: seq_000410.h5
# Copied: seq_000411.h5
# Copied: seq_000412.h5
# Copied: seq_000413.h5
# Copied: seq_000414.h5
# Copied: seq_000415.h5
# Copied: seq_000416.h5
# Copied: seq_000417.h5
# Copied: seq_000418.h5
# Copied: seq_000419.h5
# Copied: seq_000420.h5
# Copied: seq_000421.h5
# Copied: seq_000422.h5
# Copied: seq_000423.h5
# Copied: seq_000424.h5
# Copied: seq_000425.h5
# Copied: seq_000426.h5
# Copied: seq_000427.h5
# Copied: seq_000428.h5
# Copied: seq_000429.h5
# Copied: seq_000430.h5
# Copied: seq_000431.h5
# Copied: seq_000432.h5
# Copied: seq_000433.h5
# Copied: seq_000434.h5
# Copied: seq_000435.h5
# Copied: seq_000436.h5
# Copied: seq_000437.h5
# Copied: seq_000438.h5
# Copied: seq_000439.h5
# Copied: seq_000440.h5
# Copied: seq_000441.h5
# Copied: seq_000442.h5
# Copied: seq_000443.h5
# Copied: seq_000444.h5
# Copied: seq_000445.h5
# Copied: seq_000446.h5
# Copied: seq_000447.h5
# Copied: seq_000448.h5
# Copied: seq_000449.h5
# Copied: seq_000450.h5
# Copied: seq_000451.h5
# Copied: seq_000452.h5
# Copied: seq_000453.h5
# Copied: seq_000454.h5
# Copied: seq_000455.h5
# Copied: seq_000456.h5
# Copied: seq_000457.h5
# Copied: seq_000458.h5
# Copied: seq_000459.h5
# Copied: seq_000460.h5
# Copied: seq_000461.h5
# Copied: seq_000462.h5
# Copied: seq_000463.h5
# Copied: seq_000464.h5
# Copied: seq_000465.h5
# Copied: seq_000466.h5
# Copied: seq_000467.h5
# Copied: seq_000468.h5
# Copied: seq_000469.h5
# Copied: seq_000470.h5
# Copied: seq_000471.h5
# Copied: seq_000472.h5
# Copied: seq_000473.h5
# Copied: seq_000474.h5
# Copied: seq_000475.h5
# Copied: seq_000476.h5
# Copied: seq_000477.h5
# Copied: seq_000478.h5
# Copied: seq_000479.h5
# Copied: seq_000480.h5
# Copied: seq_000481.h5
# Copied: seq_000482.h5
# Copied: seq_000483.h5
# Copied: seq_000484.h5
# Copied: seq_000485.h5
# Copied: seq_000486.h5
# Copied: seq_000487.h5
# Copied: seq_000488.h5
# Copied: seq_000489.h5
# Copied: seq_000490.h5
# Copied: seq_000491.h5
# Copied: seq_000492.h5
# Copied: seq_000493.h5
# Copied: seq_000494.h5
# Copied: seq_000495.h5
# Copied: seq_000496.h5
# Copied: seq_000497.h5
# Copied: seq_000498.h5
# Copied: seq_000499.h5
# Copied: seq_000500.h5
# Copied: seq_000501.h5
# Copied: seq_000502.h5
# Copied: seq_000503.h5
# Copied: seq_000504.h5
# Copied: seq_000505.h5
# Copied: seq_000506.h5
# Copied: seq_000507.h5
# Copied: seq_000508.h5
# Copied: seq_000509.h5
# Copied: seq_000510.h5
# Copied: seq_000511.h5
# Copied: seq_000512.h5
# Copied: seq_000513.h5
# Copied: seq_000514.h5
# Copied: seq_000515.h5
# Copied: seq_000516.h5
# Copied: seq_000517.h5
# Copied: seq_000518.h5
# Copied: seq_000519.h5
# Copied: seq_000520.h5
# Copied: seq_000521.h5
# Copied: seq_000522.h5
# Copied: seq_000523.h5
# Copied: seq_000524.h5
# Copied: seq_000525.h5
# Copied: seq_000526.h5
# Copied: seq_000527.h5
# Copied: seq_000528.h5
# Copied: seq_000529.h5
# Copied: seq_000530.h5
# Copied: seq_000531.h5
# Copied: seq_000532.h5
# Copied: seq_000533.h5
# Copied: seq_000534.h5
# Copied: seq_000535.h5
# Copied: seq_000536.h5
# Copied: seq_000537.h5
# Copied: seq_000538.h5
# Copied: seq_000539.h5
# Copied: seq_000540.h5
# Copied: seq_000541.h5
# Copied: seq_000542.h5
# Copied: seq_000543.h5
# Copied: seq_000544.h5
# Copied: seq_000545.h5
# Copied: seq_000546.h5
# Copied: seq_000547.h5
# Copied: seq_000548.h5
# Copied: seq_000549.h5
# Copied: seq_000550.h5
# Copied: seq_000551.h5
# Copied: seq_000552.h5
# Copied: seq_000553.h5
# Copied: seq_000554.h5
# Copied: seq_000555.h5
# Copied: seq_000556.h5
# Copied: seq_000557.h5
# Copied: seq_000558.h5
# Copied: seq_000559.h5
# Copied: seq_000560.h5
# Copied: seq_000561.h5
# Copied: seq_000562.h5
# Copied: seq_000563.h5
# Copied: seq_000564.h5
# Copied: seq_000565.h5
# Copied: seq_000566.h5
# Copied: seq_000567.h5
# Copied: seq_000568.h5
# Copied: seq_000569.h5
# Copied: seq_000570.h5
# Copied: seq_000571.h5
# Copied: seq_000572.h5
# Copied: seq_000573.h5
# Copied: seq_000574.h5
# Copied: seq_000575.h5
# Copied: seq_000576.h5
# Copied: seq_000577.h5
# Copied: seq_000578.h5
# Copied: seq_000579.h5
# Copied: seq_000580.h5
# Copied: seq_000581.h5
# Copied: seq_000582.h5
# Copied: seq_000583.h5
# Copied: seq_000584.h5
# Copied: seq_000585.h5
# Copied: seq_000586.h5
# Copied: seq_000587.h5
# Copied: seq_000588.h5
# Copied: seq_000589.h5
# Copied: seq_000590.h5
# Copied: seq_000591.h5
# Copied: seq_000592.h5
# Copied: seq_000593.h5
# Copied: seq_000594.h5
# Copied: seq_000595.h5
# Copied: seq_000596.h5
# Copied: seq_000597.h5
# Copied: seq_000598.h5
# Copied: seq_000599.h5
# Copied: seq_000600.h5
# Copied: seq_000601.h5
# Copied: seq_000602.h5
# Copied: seq_000603.h5
# Copied: seq_000604.h5
# Copied: seq_000605.h5
# Copied: seq_000606.h5
# Copied: seq_000607.h5
# Copied: seq_000608.h5
# Copied: seq_000609.h5
# Copied: seq_000610.h5
# Copied: seq_000611.h5
# Copied: seq_000612.h5
# Copied: seq_000613.h5
# Copied: seq_000614.h5
# Copied: seq_000615.h5
# Copied: seq_000616.h5
# Copied: seq_000617.h5
# Copied: seq_000618.h5
# Copied: seq_000619.h5
# Copied: seq_000620.h5
# Copied: seq_000621.h5
# Copied: seq_000622.h5
# Copied: seq_000623.h5
# Copied: seq_000624.h5
# Copied: seq_000625.h5
# Copied: seq_000626.h5
# Copied: seq_000627.h5
# Copied: seq_000628.h5
# Copied: seq_000629.h5
# Copied: seq_000630.h5
# Copied: seq_000631.h5
# Copied: seq_000632.h5
# Copied: seq_000633.h5
# Copied: seq_000634.h5
# Copied: seq_000635.h5
# Copied: seq_000636.h5
# Copied: seq_000637.h5
# Copied: seq_000638.h5
# Copied: seq_000639.h5
# Copied: seq_000640.h5
# Copied: seq_000641.h5
# Copied: seq_000642.h5
# Copied: seq_000643.h5
# Copied: seq_000644.h5
# Copied: seq_000645.h5
# Copied: seq_000646.h5
# Copied: seq_000647.h5
# Copied: seq_000648.h5
# Copied: seq_000649.h5
# Copied: seq_000650.h5
# Copied: seq_000651.h5
# Copied: seq_000652.h5
# Copied: seq_000653.h5
# Copied: seq_000654.h5
# Copied: seq_000655.h5
# Copied: seq_000656.h5
# Copied: seq_000657.h5
# Copied: seq_000658.h5
# Copied: seq_000659.h5
# Copied: seq_000660.h5
# Copied: seq_000661.h5
# Copied: seq_000662.h5
# Copied: seq_000663.h5
# Copied: seq_000664.h5
# Copied: seq_000665.h5
# Copied: seq_000666.h5
# Copied: seq_000667.h5
# Copied: seq_000668.h5
# Copied: seq_000669.h5
# Copied: seq_000670.h5
# Copied: seq_000671.h5
# Copied: seq_000672.h5
# Copied: seq_000673.h5
# Copied: seq_000674.h5
# Copied: seq_000675.h5
# Copied: seq_000676.h5
# Copied: seq_000677.h5
# Copied: seq_000678.h5
# Copied: seq_000679.h5
# Copied: seq_000680.h5
# Copied: seq_000681.h5
# Copied: seq_000682.h5
# Copied: seq_000683.h5
# Copied: seq_000684.h5
# Copied: seq_000685.h5
# Copied: seq_000686.h5
# Copied: seq_000687.h5
# Copied: seq_000688.h5
# Copied: seq_000689.h5
# Copied: seq_000690.h5
# Copied: seq_000691.h5
# Copied: seq_000692.h5
# Copied: seq_000693.h5
# Copied: seq_000694.h5
# Copied: seq_000695.h5
# Copied: seq_000696.h5
# Copied: seq_000697.h5
# Copied: seq_000698.h5
# Copied: seq_000699.h5
# Copied: seq_000700.h5
# Copied: seq_000701.h5
# Copied: seq_000702.h5
# Copied: seq_000703.h5
# Copied: seq_000704.h5
# Copied: seq_000705.h5
# Copied: seq_000706.h5
# Copied: seq_000707.h5
# Copied: seq_000708.h5
# Copied: seq_000709.h5
# Copied: seq_000710.h5
# Copied: seq_000711.h5
# Copied: seq_000712.h5
# Copied: seq_000713.h5
# Copied: seq_000714.h5
# Copied: seq_000715.h5
# Copied: seq_000716.h5
# Copied: seq_000717.h5
# Copied: seq_000718.h5
# Copied: seq_000719.h5
# Copied: seq_000720.h5
# Copied: seq_000721.h5
# Copied: seq_000722.h5
# Copied: seq_000723.h5
# Copied: seq_000724.h5
# Copied: seq_000725.h5
# Copied: seq_000726.h5
# Copied: seq_000727.h5
# Copied: seq_000728.h5
# Copied: seq_000729.h5
# Copied: seq_000730.h5
# Copied: seq_000731.h5
# Copied: seq_000732.h5
# Copied: seq_000733.h5
# Copied: seq_000734.h5
# Copied: seq_000735.h5
# Copied: seq_000736.h5
# Copied: seq_000737.h5
# Copied: seq_000738.h5
# Copied: seq_000739.h5
# Copied: seq_000740.h5
# Copied: seq_000741.h5
# Copied: seq_000742.h5
# Copied: seq_000743.h5
# Copied: seq_000744.h5
# Copied: seq_000745.h5
# Copied: seq_000746.h5
# Copied: seq_000747.h5
# Copied: seq_000748.h5
# Copied: seq_000749.h5
# Copied: seq_000750.h5
# Copied: seq_000751.h5
# Copied: seq_000752.h5
# Copied: seq_000753.h5
# Copied: seq_000754.h5
# Copied: seq_000755.h5
# Copied: seq_000756.h5
# Copied: seq_000757.h5
# Copied: seq_000758.h5
# Copied: seq_000759.h5
# Copied: seq_000760.h5
# Copied: seq_000761.h5
# Copied: seq_000762.h5
# Copied: seq_000763.h5
# Copied: seq_000764.h5
# Copied: seq_000765.h5
# Copied: seq_000766.h5
# Copied: seq_000767.h5
# Copied: seq_000768.h5
# Copied: seq_000769.h5
# Copied: seq_000770.h5
# Copied: seq_000771.h5
# Copied: seq_000772.h5
# Copied: seq_000773.h5
# Copied: seq_000774.h5
# Copied: seq_000775.h5
# Copied: seq_000776.h5
# Copied: seq_000777.h5
# Copied: seq_000778.h5
# Copied: seq_000779.h5
# Copied: seq_000780.h5
# Copied: seq_000781.h5
# Copied: seq_000782.h5
# Copied: seq_000783.h5
# Copied: seq_000784.h5
# Copied: seq_000785.h5
# Copied: seq_000786.h5
# Copied: seq_000787.h5
# Copied: seq_000788.h5
# Copied: seq_000789.h5
# Copied: seq_000790.h5
# Copied: seq_000791.h5
# Copied: seq_000792.h5
# Copied: seq_000793.h5
# Copied: seq_000794.h5
# Copied: seq_000795.h5
# Copied: seq_000796.h5
# Copied: seq_000797.h5
# Copied: seq_000798.h5
# Copied: seq_000799.h5
# Copied: seq_000800.h5
# Copied: seq_000801.h5
# Copied: seq_000802.h5
# Copied: seq_000803.h5
# Copied: seq_000804.h5
# Copied: seq_000805.h5
# Copied: seq_000806.h5
# Copied: seq_000807.h5
# Copied: seq_000808.h5
# Copied: seq_000809.h5
# Copied: seq_000810.h5
# Copied: seq_000811.h5
# Copied: seq_000812.h5
# Copied: seq_000813.h5
# Copied: seq_000814.h5
# Copied: seq_000815.h5
# Copied: seq_000816.h5
# Copied: seq_000817.h5
# Copied: seq_000818.h5
# Copied: seq_000819.h5
# Copied: seq_000820.h5
# Copied: seq_000821.h5
# Copied: seq_000822.h5
# Copied: seq_000823.h5
# Copied: seq_000824.h5
# Copied: seq_000825.h5
# Copied: seq_000826.h5
# Copied: seq_000827.h5
# Copied: seq_000828.h5
# Copied: seq_000829.h5
# Copied: seq_000830.h5
# Copied: seq_000831.h5
# Copied: seq_000832.h5
# Copied: seq_000833.h5
# Copied: seq_000834.h5
# Copied: seq_000835.h5
# Copied: seq_000836.h5
# Copied: seq_000837.h5
# Copied: seq_000838.h5
# Copied: seq_000839.h5
# Copied: seq_000840.h5
# Copied: seq_000841.h5
# Copied: seq_000842.h5
# Copied: seq_000843.h5
# Copied: seq_000844.h5
# Copied: seq_000845.h5
# Copied: seq_000846.h5
# Copied: seq_000847.h5
# Copied: seq_000848.h5
# Copied: seq_000849.h5
# Copied: seq_000850.h5
# Copied: seq_000851.h5
# Copied: seq_000852.h5
# Copied: seq_000853.h5
# Copied: seq_000854.h5
# Copied: seq_000855.h5
# Copied: seq_000856.h5
# Copied: seq_000857.h5
# Copied: seq_000858.h5
# Copied: seq_000859.h5
# Copied: seq_000860.h5
# Copied: seq_000861.h5
# Copied: seq_000862.h5
# Copied: seq_000863.h5
# Copied: seq_000864.h5
# Copied: seq_000865.h5
# Copied: seq_000866.h5
# Copied: seq_000867.h5
# Copied: seq_000868.h5
# Copied: seq_000869.h5
# Copied: seq_000870.h5
# Copied: seq_000871.h5
# Copied: seq_000872.h5
# Copied: seq_000873.h5
# Copied: seq_000874.h5
# Copied: seq_000875.h5
# Copied: seq_000876.h5
# Copied: seq_000877.h5
# Copied: seq_000878.h5
# Copied: seq_000879.h5
# Copied: seq_000880.h5
# Copied: seq_000881.h5
# Copied: seq_000882.h5
# Copied: seq_000883.h5
# Copied: seq_000884.h5
# Copied: seq_000885.h5
# Copied: seq_000886.h5
# Copied: seq_000887.h5
# Copied: seq_000888.h5
# Copied: seq_000889.h5
# Copied: seq_000890.h5
# Copied: seq_000891.h5
# Copied: seq_000892.h5
# Copied: seq_000893.h5
# Copied: seq_000894.h5
# Copied: seq_000895.h5
# Copied: seq_000896.h5
# Copied: seq_000897.h5
# Copied: seq_000898.h5
# Copied: seq_000899.h5
# Copied: seq_000900.h5
# Copied: seq_000901.h5
# Copied: seq_000902.h5
# Copied: seq_000903.h5
# Copied: seq_000904.h5
# Copied: seq_000905.h5
# Copied: seq_000906.h5
# Copied: seq_000907.h5
# Copied: seq_000908.h5
# Copied: seq_000909.h5
# Copied: seq_000910.h5
# Copied: seq_000911.h5
# Copied: seq_000912.h5
# Copied: seq_000913.h5
# Copied: seq_000914.h5
# Copied: seq_000915.h5
# Copied: seq_000916.h5
# Copied: seq_000917.h5
# Copied: seq_000918.h5
# Copied: seq_000919.h5
# Copied: seq_000920.h5
# Copied: seq_000921.h5
# Copied: seq_000922.h5
# Copied: seq_000923.h5
# Copied: seq_000924.h5
# Copied: seq_000925.h5
# Copied: seq_000926.h5
# Copied: seq_000927.h5
# Copied: seq_000928.h5
# Copied: seq_000929.h5
# Copied: seq_000930.h5
# Copied: seq_000931.h5
# Copied: seq_000932.h5
# Copied: seq_000933.h5
# Copied: seq_000934.h5
# Copied: seq_000935.h5
# Copied: seq_000936.h5
# Copied: seq_000937.h5
# Copied: seq_000938.h5
# Copied: seq_000939.h5
# Copied: seq_000940.h5
# Copied: seq_000941.h5
# Copied: seq_000942.h5
# Copied: seq_000943.h5
# Copied: seq_000944.h5
# Copied: seq_000945.h5
# Copied: seq_000946.h5
# Copied: seq_000947.h5
# Copied: seq_000948.h5
# Copied: seq_000949.h5
# Copied: seq_000950.h5
# Copied: seq_000951.h5
# Copied: seq_000952.h5
# Copied: seq_000953.h5
# Copied: seq_000954.h5
# Copied: seq_000955.h5
# Copied: seq_000956.h5
# Copied: seq_000957.h5
# Copied: seq_000958.h5
# Copied: seq_000959.h5
# Copied: seq_000960.h5
# Copied: seq_000961.h5
# Copied: seq_000962.h5
# Copied: seq_000963.h5
# Copied: seq_000964.h5
# Copied: seq_000965.h5
# Copied: seq_000966.h5
# Copied: seq_000967.h5
# Copied: seq_000968.h5
# Copied: seq_000969.h5
# Copied: seq_000970.h5
# Copied: seq_000971.h5
# Copied: seq_000972.h5
# Copied: seq_000973.h5
# Copied: seq_000974.h5
# Copied: seq_000975.h5
# Copied: seq_000976.h5
# Copied: seq_000977.h5
# Copied: seq_000978.h5
# Copied: seq_000979.h5
# Copied: seq_000980.h5
# Copied: seq_000981.h5
# Copied: seq_000982.h5
# Copied: seq_000983.h5
# Copied: seq_000984.h5
# Copied: seq_000985.h5
# Copied: seq_000986.h5
# Copied: seq_000987.h5
# Copied: seq_000988.h5
# Copied: seq_000989.h5
# Copied: seq_000990.h5
# Copied: seq_000991.h5
# Copied: seq_000992.h5
# Copied: seq_000993.h5
# Copied: seq_000994.h5
# Copied: seq_000995.h5
# Copied: seq_000996.h5
# Copied: seq_000997.h5
# Copied: seq_000998.h5
# Copied: seq_000999.h5
# Copied: seq_001000.h5
# Completed copying all .h5 files back to frames!

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")  # Automatically select GPU or CPU
model = model.to(device)  # Move the model to GPU

to_print = 3
plt.figure(figsize=(9, 3 * to_print))

for i, test_path in enumerate(test_paths):
    if i == to_print: break

    # Load and transfer the image to GPU
    img = transform(Image.open(test_path).convert('RGB')).to(device)
    output = model(img.unsqueeze(0))  # Make predictions

    # Transfer the output back to CPU for visualization
    estimated_den_map = output.squeeze().detach().cpu().numpy()

    # Display the original image
    img = Image.open(test_path).convert('RGB')

    # Load the ground truth density map
    gt_file = h5py.File(test_path.replace('.jpg', '.h5').replace('images', 'ground_truth'), 'r')
    den_map = np.asarray(gt_file['density'])

    # Display the test image
    plt.subplot(to_print, 3, i * 3 + 1)
    plt.axis("off")
    plt.title("Test image:")
    plt.imshow(img)

    # Display the ground truth density map
    plt.subplot(to_print, 3, i * 3 + 2)
    plt.axis("off")
    plt.title("GT density map")
    plt.imshow(den_map, cmap=cm.jet)

    # Display the estimated density map
    estimated_count = np.sum(estimated_den_map)
    plt.subplot(to_print, 3, i * 3 + 3)
    plt.axis("off")
    plt.title(f"Estimated density map")
    plt.imshow(estimated_den_map, cmap=cm.jet)

plt.tight_layout()
plt.show()

# %%
mae = 0

for test_path in tqdm(test_paths, desc='Calculating MAE', unit='image'):
    img = transform(Image.open(test_path).convert('RGB'))
    img = img.to(device)

    gt_file = h5py.File(test_path.replace('.jpg','.h5').replace('images','ground_truth'),'r')
    groundtruth = np.asarray(gt_file['density'])

    output = model(img.unsqueeze(0))

    mae += abs(output.detach().cpu().sum().numpy() - np.sum(groundtruth))

print('\nMAE:', mae / len(test_paths))
# Out:
# Calculating MAE: 100%|██████████| 200/200 [02:48<00:00,  1.19image/s]
# MAE: 5.069474248886109

# %% [markdown]
# **Analysis**:
#
# > Concidering that we trained using just 15% of the available training set, the obtained MAE is decent. It's evident that **data augmentation** helps. Also, more epochs are needed. We did only 20, which still took a long time to train.
#
# > **We expect that longer training and more training data would improve the performance** drastically, but we are dealing with limited resources, so let's utilize **Transfer learning**.

# %% [markdown]
# ## (2) Transfer learning
#
# We will be reusing the weights from: https://github.com/pschaus/csrnet_pip/blob/main/csrnet.

# %% [markdown]
# First upload the weights to Google Drive.
# > /content/drive/MyDrive/CrowdCounting/Models/weights_pschaus.npz

# %%
# %ls /content/drive/MyDrive/CrowdCounting/Models/weights_pschaus.npz
# Out:
# /content/drive/MyDrive/CrowdCounting/Models/weights_pschaus.npz

# %%
model = CSRNet()
model.cuda()

checkpoint = np.load("/content/drive/MyDrive/CrowdCounting/Models/weights_pschaus.npz")

checkpoint = { layer: torch.from_numpy(mat) for layer,mat in checkpoint.items() }
model.load_state_dict(checkpoint)
# Out:
# <All keys matched successfully>

# %% [markdown]
# Let's check if the code works for a single image:

# %%
filepath = '/content/drive/MyDrive/CrowdCounting/Data/mall_dataset/frames/seq_000001.jpg' # Path to image

transform = transforms.Compose([
    transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                std=[0.229, 0.224, 0.225]),])

img = transform(Image.open(filepath).convert('RGB')).cuda()
output = model(img.unsqueeze(0))

print(int(output.detach().cpu().sum().numpy()))
# Out:
# 32

# %% [markdown]
# Since it works, let's try **inference** on the test dataset.
#
# First, let's do train-val-test split:

# %%
# Load images and density maps
path_dataset = '/content/drive/MyDrive/CrowdCounting/Data/mall_dataset/frames/'

img_names = sorted([file for file in os.listdir(path=path_dataset) if file.lower().endswith('.jpg')])
den_names = sorted([file for file in os.listdir(path=path_dataset) if file.lower().endswith('.h5')])

random_state = 42

# Train_val - test split:
test_proportion = 0.2
train_val_img_names, test_img_names = train_test_split(img_names, test_size=test_proportion, random_state=random_state)
train_val_den_names, test_den_names = train_test_split(den_names, test_size=test_proportion, random_state=random_state)

# Train - val split
val_proportion = 0.1
train_img_names, val_img_names = train_test_split(train_val_img_names, test_size=val_proportion, random_state=random_state)
train_den_names, val_den_names = train_test_split(train_val_den_names, test_size=val_proportion, random_state=random_state)

# %% [markdown]
# Let's load the targets:

# %%
mall_dataset_folder = '/content/drive/MyDrive/CrowdCounting/Data/mall_dataset/'

mall_gt = io.loadmat(os.path.join(mall_dataset_folder, 'mall_gt.mat'))
mall_head_positions_gt = mall_gt['frame'][0]

num_heads_list = []
for gt in mall_head_positions_gt:
  n_heads = len(gt[0][0][0])
  num_heads_list.append(n_heads)

test_indices = [img_names.index(name) for name in test_img_names]
Test_labels = [num_heads_list[idx] for idx in test_indices]

print(f'{len(Test_labels)} test targets loaded.')
# Out:
# 400 test targets loaded.

# %% [markdown]
# **Testing**
#
# Let's see whether how efficient are these weights for a new dataset, i.e., the test partition of the Mall dataset.

# %%
mse_error = 0
mae_error = 0
mape_error = 0
N = len(Test_labels)

for (img_name, target) in tqdm(zip(test_img_names, Test_labels), total=len(Test_labels)):
    img = transform(Image.open(path_dataset + img_name).convert('RGB')).cuda()
    output = model(img.unsqueeze(0))
    prediction = int(output.detach().cpu().sum().numpy())
    mse_error += np.mean(np.square(np.sum(prediction) - target))
    mae_error += np.mean(np.abs(np.sum(prediction) - target))
    mape_error += np.mean(np.abs((np.sum(prediction) - target) / target)) * 100

mse = round(mse_error / N, 2)
mae = round(mae_error / N, 2)
mape = round(mape_error / N, 2)

print(f'\n\nMSE: {mse}, MAE: {mae}, MAPE: {mape}')
# MSE: 17.95, MAE: 3.44, MAPE: 11.52
# Out:
# 100%|██████████| 400/400 [01:28<00:00,  4.53it/s]
# MSE: 17.95, MAE: 3.44, MAPE: 11.52

# %% [markdown]
# Finally, let's visualize some predictions:

# %%
to_print = 3
plt.figure(figsize=(9, 3 * to_print))

for i, (img_name, den_map_name) in enumerate(zip(test_img_names, test_den_names)):
    if i == to_print: break

    img = transform(Image.open(path_dataset + img_name).convert('RGB')).cuda()
    output = model(img.unsqueeze(0))
    estimated_den_map = output.squeeze().detach().cpu().numpy()

    img = cv2.imread(path_dataset + img_name)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    den_map = h5py.File(path_dataset + den_map_name)
    den_map = np.asarray(den_map['density'])

    plt.subplot(to_print, 3, i * 3 + 1)
    plt.axis("off")
    plt.title("Test image:")
    plt.imshow(img)

    plt.subplot(to_print, 3, i * 3 + 2)
    plt.axis("off")
    plt.title("GT density map:")
    plt.title(f"GT density map\nGT count: {Test_labels[i]:.2f}")
    plt.imshow(den_map , cmap = cm.jet)
    print()

    estimated_count = np.sum(estimated_den_map)
    plt.subplot(to_print, 3, i * 3 + 3)
    plt.axis("off")
    plt.title(f"Estimated density map\nEstimated count: {estimated_count:.2f}")
    plt.imshow(estimated_den_map, cmap = cm.jet)

# %% [markdown]
# **Analysis**:
#
# > The model works well, yielding a **very low MAE**.\
# > Also, the generated density maps look decent.
#
# Next, let's see if **fine-tunning** these weights on the training portion of the Mall dataset will improve its performance. Again as in (1), we will use a small portion of the data.

# %% [markdown]
# ## (3) Training a Regressor

# %% [markdown]
# Here, we will attempt to use the **CSRNet as a feature extractor**, and train a **Dense layer** on top of it, in order **to perform regression**.
#
# We will try just two configurations: just one Dense layer, and two Dense layers + Dropout.

# %%
class FeatureExtractor(nn.Module):
    def __init__(self, pretrained_model):
        super(FeatureExtractor, self).__init__()
        self.csrnet = pretrained_model  # Use the entire CSRNet as the feature extractor

    def forward(self, x):
        x = self.csrnet(x)
        return x

class CustomDataset(Dataset):
    def __init__(self, img_names, targets, transform=None):
        self.img_names = img_names
        self.targets = targets
        self.transform = transform

    def __len__(self):
        return len(self.img_names)

    def __getitem__(self, idx):
        img_path = os.path.join(path_dataset, self.img_names[idx])
        img = Image.open(img_path).convert('RGB')

        if self.transform:
            img = self.transform(img)

        target = self.targets[idx]
        return img, target

# %%
# Load data
train_indices = [img_names.index(name) for name in train_img_names]
Train_labels = [num_heads_list[idx] for idx in train_indices]

val_indices = [img_names.index(name) for name in val_img_names]
Val_labels = [num_heads_list[idx] for idx in val_indices]

# Create custom datasets
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                     std=[0.229, 0.224, 0.225]),])
train_dataset = CustomDataset(train_img_names, Train_labels, transform=transform)
val_dataset = CustomDataset(val_img_names, Val_labels, transform=transform)
test_dataset = CustomDataset(test_img_names, Test_labels, transform=transform)

# Create data loaders
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

checkpoint_dir = '/content/drive/MyDrive/CrowdCounting/Models/'

# %% [markdown]
# ### (3.1) One Dense layer

# %%
class CustomRegressionModel(nn.Module):
    def __init__(self, feature_extractor):
        super(CustomRegressionModel, self).__init__()
        self.feature_extractor = feature_extractor
        self.flatten = nn.Flatten()
        self.dense = nn.Linear(60 * 80, 1)

    def forward(self, x):
        x = self.feature_extractor(x)
        x = self.flatten(x)
        x = self.dense(x)
        return x

# %%
# Load CSRNet model
model = CSRNet().cuda()

# Load weights
checkpoint = np.load("/content/drive/MyDrive/CrowdCounting/Models/weights_pschaus.npz")
checkpoint = {layer: torch.from_numpy(mat) for layer, mat in checkpoint.items()}
model.load_state_dict(checkpoint)

# Freeze the layers in the feature extractor
feature_extractor = FeatureExtractor(model)
for param in feature_extractor.parameters():
    param.requires_grad = False

# Create custom regression model
regression_model = CustomRegressionModel(feature_extractor).cuda()

# Initialize dense layer with RandomNormal
nn.init.normal_(regression_model.dense.weight, mean=1., std=0.001)
nn.init.constant_(regression_model.dense.bias, 0)
# Xavier/Glorot initialization for the dense layer
#nn.init.xavier_uniform_(regression_model.dense.weight)
#nn.init.constant_(regression_model.dense.bias, 0)

regression_model
# Out:
# CustomRegressionModel(
#   (feature_extractor): FeatureExtractor(
#     (csrnet): CSRNet(
#       (frontend): Sequential(
#         (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): ReLU(inplace=True)
#         (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (6): ReLU(inplace=True)
#         (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (8): ReLU(inplace=True)
#         (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (11): ReLU(inplace=True)
#         (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (13): ReLU(inplace=True)
#         (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (15): ReLU(inplace=True)
#         (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (18): ReLU(inplace=True)
#         (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (20): ReLU(inplace=True)
#         (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (22): ReLU(inplace=True)
#       )
#       (backend): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#         (1): ReLU(inplace=True)
#         (2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#         (3): ReLU(inplace=True)
#         (4): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#         (5): ReLU(inplace=True)
#         (6): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#         (9): ReLU(inplace=True)
#         (10): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#         (11): ReLU(inplace=True)
#       )
#       (output_layer): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (dense): Linear(in_features=4800, out_features=1, bias=True)
# )

# %%
# Define the optimizer, loss function, and metrics
optimizer = Adam(regression_model.parameters(), lr=1e-2)
loss_fn = nn.L1Loss()  # MAE loss for regression
mse_metric = nn.MSELoss()

num_epochs = 20

for epoch in range(num_epochs):
    start_time = time.time()
    # Training
    regression_model.train()
    total_train_loss = 0.0
    for batch_idx, (batch_img, batch_target) in enumerate(train_loader):
        optimizer.zero_grad()

        # Move input and target tensors to GPU
        batch_img = torch.stack(tuple(img.cuda() for img in batch_img))
        batch_target = batch_target.unsqueeze(1).cuda()

        # Forward pass
        output = regression_model(batch_img)
        loss = loss_fn(output, batch_target)

        # Backward pass and optimization
        loss.backward()
        optimizer.step()

        total_train_loss += loss.item()

        if batch_idx % 10 == 0:
            print(f'Train Epoch [{epoch+1}/{num_epochs}], Batch [{batch_idx}/{len(train_loader)}], Loss: {loss.item():.4f}')

    average_train_loss = total_train_loss / len(train_loader)
    print(f'Train Epoch [{epoch+1}/{num_epochs}], Average Training Loss: {average_train_loss:.4f}')

    # Validation
    regression_model.eval()
    with torch.no_grad():
        total_val_loss = 0.0
        for batch_idx, (batch_img, batch_target) in enumerate(val_loader):
            # Move input and target tensors to GPU
            batch_img = torch.stack([img.cuda() for img in batch_img])
            batch_target = batch_target.unsqueeze(1).cuda()

            # Forward pass
            output = regression_model(batch_img)
            val_loss = loss_fn(output, batch_target)

            total_val_loss += val_loss.item()

            if batch_idx % 10 == 0:
                print(f'Validation Epoch [{epoch+1}/{num_epochs}], Batch [{batch_idx}/{len(val_loader)}], Loss: {val_loss.item():.4f}')

        average_val_loss = total_val_loss / len(val_loader)
        print(f'Validation Epoch [{epoch+1}/{num_epochs}], Average Validation Loss: {average_val_loss:.4f}')

    epoch_time = time.time() - start_time

    # Print metrics
    print(f'Epoch [{epoch+1}/{num_epochs}], Average Training Loss: {average_train_loss:.4f}, Average Validation Loss: {average_val_loss:.4f}')
    print(f'Time taken for epoch: {epoch_time:.2f} seconds\n')

    # Save model and optimizer state
    checkpoint_path = os.path.join(checkpoint_dir, f'checkpoint_regression_one_dense.pth')
    torch.save({
        'epoch': epoch,
        'model_state_dict': regression_model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'train_loss': average_train_loss,
        'val_loss': average_val_loss,
    }, checkpoint_path)
# Out:
# Train Epoch [1/20], Batch [0/45], Loss: 2.6693
# Train Epoch [1/20], Batch [10/45], Loss: 3.4311
# Train Epoch [1/20], Batch [20/45], Loss: 3.1473
# Train Epoch [1/20], Batch [30/45], Loss: 3.1505
# Train Epoch [1/20], Batch [40/45], Loss: 2.8896
# Train Epoch [1/20], Average Training Loss: 3.1994
# Validation Epoch [1/20], Batch [0/5], Loss: 3.3424
# Validation Epoch [1/20], Average Validation Loss: 3.7872
# Epoch [1/20], Average Training Loss: 3.1994, Average Validation Loss: 3.7872
# Time taken for epoch: 95.69 seconds
#
# Train Epoch [2/20], Batch [0/45], Loss: 2.6474
# Train Epoch [2/20], Batch [10/45], Loss: 3.1688
# Train Epoch [2/20], Batch [20/45], Loss: 2.8646
# Train Epoch [2/20], Batch [30/45], Loss: 2.2053
# Train Epoch [2/20], Batch [40/45], Loss: 3.3740
# Train Epoch [2/20], Average Training Loss: 3.0332
# Validation Epoch [2/20], Batch [0/5], Loss: 3.2527
# Validation Epoch [2/20], Average Validation Loss: 3.4907
# Epoch [2/20], Average Training Loss: 3.0332, Average Validation Loss: 3.4907
# Time taken for epoch: 95.81 seconds
#
# Train Epoch [3/20], Batch [0/45], Loss: 3.0822
# Train Epoch [3/20], Batch [10/45], Loss: 3.0464
# Train Epoch [3/20], Batch [20/45], Loss: 2.5055
# Train Epoch [3/20], Batch [30/45], Loss: 2.0879
# Train Epoch [3/20], Batch [40/45], Loss: 2.9970
# Train Epoch [3/20], Average Training Loss: 2.9068
# Validation Epoch [3/20], Batch [0/5], Loss: 3.1092
# Validation Epoch [3/20], Average Validation Loss: 3.4156
# Epoch [3/20], Average Training Loss: 2.9068, Average Validation Loss: 3.4156
# Time taken for epoch: 95.71 seconds
#
# Train Epoch [4/20], Batch [0/45], Loss: 3.5398
# Train Epoch [4/20], Batch [10/45], Loss: 3.0639
# Train Epoch [4/20], Batch [20/45], Loss: 2.8801
# Train Epoch [4/20], Batch [30/45], Loss: 2.2576
# Train Epoch [4/20], Batch [40/45], Loss: 3.3213
# Train Epoch [4/20], Average Training Loss: 2.8079
# Validation Epoch [4/20], Batch [0/5], Loss: 3.0145
# Validation Epoch [4/20], Average Validation Loss: 3.3405
# Epoch [4/20], Average Training Loss: 2.8079, Average Validation Loss: 3.3405
# Time taken for epoch: 102.85 seconds
#
# Train Epoch [5/20], Batch [0/45], Loss: 3.1219
# Train Epoch [5/20], Batch [10/45], Loss: 2.8349
# Train Epoch [5/20], Batch [20/45], Loss: 1.9662
# Train Epoch [5/20], Batch [30/45], Loss: 3.1475
# Train Epoch [5/20], Batch [40/45], Loss: 2.5038
# Train Epoch [5/20], Average Training Loss: 2.7321
# Validation Epoch [5/20], Batch [0/5], Loss: 2.9594
# Validation Epoch [5/20], Average Validation Loss: 3.2448
# Epoch [5/20], Average Training Loss: 2.7321, Average Validation Loss: 3.2448
# Time taken for epoch: 101.28 seconds
#
# Train Epoch [6/20], Batch [0/45], Loss: 2.6740
# Train Epoch [6/20], Batch [10/45], Loss: 2.4526
# Train Epoch [6/20], Batch [20/45], Loss: 2.2703
# Train Epoch [6/20], Batch [30/45], Loss: 2.3724
# Train Epoch [6/20], Batch [40/45], Loss: 2.5877
# Train Epoch [6/20], Average Training Loss: 2.6646
# Validation Epoch [6/20], Batch [0/5], Loss: 2.8857
# Validation Epoch [6/20], Average Validation Loss: 3.1864
# Epoch [6/20], Average Training Loss: 2.6646, Average Validation Loss: 3.1864
# Time taken for epoch: 98.17 seconds
#
# Train Epoch [7/20], Batch [0/45], Loss: 2.6681
# Train Epoch [7/20], Batch [10/45], Loss: 2.5475
# Train Epoch [7/20], Batch [20/45], Loss: 2.3005
# Train Epoch [7/20], Batch [30/45], Loss: 2.1913
# Train Epoch [7/20], Batch [40/45], Loss: 2.4046
# Train Epoch [7/20], Average Training Loss: 2.5923
# Validation Epoch [7/20], Batch [0/5], Loss: 2.8835
# Validation Epoch [7/20], Average Validation Loss: 3.1224
# Epoch [7/20], Average Training Loss: 2.5923, Average Validation Loss: 3.1224
# Time taken for epoch: 95.29 seconds
#
# Train Epoch [8/20], Batch [0/45], Loss: 2.9383
# Train Epoch [8/20], Batch [10/45], Loss: 2.5825
# Train Epoch [8/20], Batch [20/45], Loss: 2.2669
# Train Epoch [8/20], Batch [30/45], Loss: 2.6578
# Train Epoch [8/20], Batch [40/45], Loss: 2.8412
# Train Epoch [8/20], Average Training Loss: 2.5392
# Validation Epoch [8/20], Batch [0/5], Loss: 2.7356
# Validation Epoch [8/20], Average Validation Loss: 3.1612
# Epoch [8/20], Average Training Loss: 2.5392, Average Validation Loss: 3.1612
# Time taken for epoch: 96.06 seconds
#
# Train Epoch [9/20], Batch [0/45], Loss: 2.2444
# Train Epoch [9/20], Batch [10/45], Loss: 2.6436
# Train Epoch [9/20], Batch [20/45], Loss: 2.4825
# Train Epoch [9/20], Batch [30/45], Loss: 2.2797
# Train Epoch [9/20], Batch [40/45], Loss: 2.7994
# Train Epoch [9/20], Average Training Loss: 2.5284
# Validation Epoch [9/20], Batch [0/5], Loss: 2.8357
# Validation Epoch [9/20], Average Validation Loss: 3.0356
# Epoch [9/20], Average Training Loss: 2.5284, Average Validation Loss: 3.0356
# Time taken for epoch: 96.44 seconds
#
# Train Epoch [10/20], Batch [0/45], Loss: 3.3336
# Train Epoch [10/20], Batch [10/45], Loss: 2.7523
# Train Epoch [10/20], Batch [20/45], Loss: 1.8016
# Train Epoch [10/20], Batch [30/45], Loss: 2.5658
# Train Epoch [10/20], Batch [40/45], Loss: 2.0653
# Train Epoch [10/20], Average Training Loss: 2.4702
# Validation Epoch [10/20], Batch [0/5], Loss: 2.7630
# Validation Epoch [10/20], Average Validation Loss: 3.0106
# Epoch [10/20], Average Training Loss: 2.4702, Average Validation Loss: 3.0106
# Time taken for epoch: 96.46 seconds
#
# Train Epoch [11/20], Batch [0/45], Loss: 2.0569
# Train Epoch [11/20], Batch [10/45], Loss: 2.5607
# Train Epoch [11/20], Batch [20/45], Loss: 2.8858
# Train Epoch [11/20], Batch [30/45], Loss: 2.7057
# Train Epoch [11/20], Batch [40/45], Loss: 2.4332
# Train Epoch [11/20], Average Training Loss: 2.4091
# Validation Epoch [11/20], Batch [0/5], Loss: 2.7087
# Validation Epoch [11/20], Average Validation Loss: 2.9955
# Epoch [11/20], Average Training Loss: 2.4091, Average Validation Loss: 2.9955
# Time taken for epoch: 96.30 seconds
#
# Train Epoch [12/20], Batch [0/45], Loss: 1.9852
# Train Epoch [12/20], Batch [10/45], Loss: 2.4172
# Train Epoch [12/20], Batch [20/45], Loss: 1.9447
# Train Epoch [12/20], Batch [30/45], Loss: 2.9841
# Train Epoch [12/20], Batch [40/45], Loss: 2.4086
# Train Epoch [12/20], Average Training Loss: 2.3874
# Validation Epoch [12/20], Batch [0/5], Loss: 2.6620
# Validation Epoch [12/20], Average Validation Loss: 2.9692
# Epoch [12/20], Average Training Loss: 2.3874, Average Validation Loss: 2.9692
# Time taken for epoch: 96.18 seconds
#
# Train Epoch [13/20], Batch [0/45], Loss: 2.1126
# Train Epoch [13/20], Batch [10/45], Loss: 2.4147
# Train Epoch [13/20], Batch [20/45], Loss: 1.9629
# Train Epoch [13/20], Batch [30/45], Loss: 2.7916
# Train Epoch [13/20], Batch [40/45], Loss: 2.2493
# Train Epoch [13/20], Average Training Loss: 2.3502
# Validation Epoch [13/20], Batch [0/5], Loss: 2.6317
# Validation Epoch [13/20], Average Validation Loss: 2.9487
# Epoch [13/20], Average Training Loss: 2.3502, Average Validation Loss: 2.9487
# Time taken for epoch: 95.97 seconds
#
# Train Epoch [14/20], Batch [0/45], Loss: 2.2818
# Train Epoch [14/20], Batch [10/45], Loss: 2.3696
# Train Epoch [14/20], Batch [20/45], Loss: 2.1819
# Train Epoch [14/20], Batch [30/45], Loss: 1.7742
# Train Epoch [14/20], Batch [40/45], Loss: 3.1592
# Train Epoch [14/20], Average Training Loss: 2.3173
# Validation Epoch [14/20], Batch [0/5], Loss: 2.6504
# Validation Epoch [14/20], Average Validation Loss: 2.9123
# Epoch [14/20], Average Training Loss: 2.3173, Average Validation Loss: 2.9123
# Time taken for epoch: 96.12 seconds
#
# Train Epoch [15/20], Batch [0/45], Loss: 2.5577
# Train Epoch [15/20], Batch [10/45], Loss: 1.8880
# Train Epoch [15/20], Batch [20/45], Loss: 2.0995
# Train Epoch [15/20], Batch [30/45], Loss: 1.8084
# Train Epoch [15/20], Batch [40/45], Loss: 2.2102
# Train Epoch [15/20], Average Training Loss: 2.2827
# Validation Epoch [15/20], Batch [0/5], Loss: 2.6063
# Validation Epoch [15/20], Average Validation Loss: 2.9057
# Epoch [15/20], Average Training Loss: 2.2827, Average Validation Loss: 2.9057
# Time taken for epoch: 95.78 seconds
#
# Train Epoch [16/20], Batch [0/45], Loss: 2.0851
# Train Epoch [16/20], Batch [10/45], Loss: 2.3682
# Train Epoch [16/20], Batch [20/45], Loss: 2.5603
# Train Epoch [16/20], Batch [30/45], Loss: 2.3616
# Train Epoch [16/20], Batch [40/45], Loss: 2.5004
# Train Epoch [16/20], Average Training Loss: 2.2776
# Validation Epoch [16/20], Batch [0/5], Loss: 2.7530
# Validation Epoch [16/20], Average Validation Loss: 2.8797
# Epoch [16/20], Average Training Loss: 2.2776, Average Validation Loss: 2.8797
# Time taken for epoch: 95.76 seconds
#
# Train Epoch [17/20], Batch [0/45], Loss: 2.2794
# Train Epoch [17/20], Batch [10/45], Loss: 2.5491
# Train Epoch [17/20], Batch [20/45], Loss: 2.1328
# Train Epoch [17/20], Batch [30/45], Loss: 2.8493
# Train Epoch [17/20], Batch [40/45], Loss: 1.9545
# Train Epoch [17/20], Average Training Loss: 2.2503
# Validation Epoch [17/20], Batch [0/5], Loss: 2.6312
# Validation Epoch [17/20], Average Validation Loss: 2.8547
# Epoch [17/20], Average Training Loss: 2.2503, Average Validation Loss: 2.8547
# Time taken for epoch: 95.79 seconds
#
# Train Epoch [18/20], Batch [0/45], Loss: 2.0553
# Train Epoch [18/20], Batch [10/45], Loss: 2.2526
# Train Epoch [18/20], Batch [20/45], Loss: 2.1795
# Train Epoch [18/20], Batch [30/45], Loss: 2.5443
# Train Epoch [18/20], Batch [40/45], Loss: 3.1369
# Train Epoch [18/20], Average Training Loss: 2.2121
# Validation Epoch [18/20], Batch [0/5], Loss: 2.5692
# Validation Epoch [18/20], Average Validation Loss: 2.8401
# Epoch [18/20], Average Training Loss: 2.2121, Average Validation Loss: 2.8401
# Time taken for epoch: 95.92 seconds
#
# Train Epoch [19/20], Batch [0/45], Loss: 2.1080
# Train Epoch [19/20], Batch [10/45], Loss: 2.2404
# Train Epoch [19/20], Batch [20/45], Loss: 2.4759
# Train Epoch [19/20], Batch [30/45], Loss: 2.1808
# Train Epoch [19/20], Batch [40/45], Loss: 2.0166
# Train Epoch [19/20], Average Training Loss: 2.1908
# Validation Epoch [19/20], Batch [0/5], Loss: 2.5374
# Validation Epoch [19/20], Average Validation Loss: 2.8299
# Epoch [19/20], Average Training Loss: 2.1908, Average Validation Loss: 2.8299
# Time taken for epoch: 95.83 seconds
#
# Train Epoch [20/20], Batch [0/45], Loss: 1.9877
# Train Epoch [20/20], Batch [10/45], Loss: 1.8976
# Train Epoch [20/20], Batch [20/45], Loss: 1.9591
# Train Epoch [20/20], Batch [30/45], Loss: 2.4061
# Train Epoch [20/20], Batch [40/45], Loss: 2.0464
# Train Epoch [20/20], Average Training Loss: 2.1749
# Validation Epoch [20/20], Batch [0/5], Loss: 2.5233
# Validation Epoch [20/20], Average Validation Loss: 2.8189
# Epoch [20/20], Average Training Loss: 2.1749, Average Validation Loss: 2.8189
# Time taken for epoch: 95.32 seconds

# %%
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

regression_model.eval()

with torch.no_grad():
    test_loss = 0.0
    predictions = []

    for batch_img, batch_target in test_loader:
        batch_img = torch.stack(tuple(batch_img)).cuda()
        batch_target = batch_target.clone().detach().unsqueeze(1).to(torch.float32).cuda()

        # Forward pass
        output = regression_model(batch_img)
        test_loss += loss_fn(output, batch_target).item()

        # Collect predictions
        predictions.append(output.squeeze().cpu().numpy())

test_loss /= len(test_loader)

predictions_final = np.concatenate(predictions, axis=0)

mae = mean_absolute_error(Test_labels, predictions_final)
mse = mean_squared_error(Test_labels, predictions_final)

print(f'Test Loss: {test_loss:.4f}')
print(f'MAE: {mae:.4f}')
print(f'MSE: {mse:.4f}')
# Out:
# Test Loss: 2.7171
# MAE: 2.7384
# MSE: 11.4843

# %% [markdown]
# **Analysis**:
#
# > The regressor outperformed the pre-trained CSRNet. For the transfer learning case the results were:\
# MAE: 3.44,  MSE: 17.95.\
# > Here the MAE and MSE are much lower:\
# > **MAE: 2.72**,  MSE: 11.32.

# %% [markdown]
# # Results

# %% [markdown]
# | Model                                | MAE  |
# |--------------------------------------|------|
# | Authors' code                        | 5.18 |
# | Transfer Learning                    | 3.44 |
# | 1 Dense layer Regressor              | **2.72** |
